# %%
import numpy as np
import pandas as pd
import matlab.engine
import yaml
import time
import importlib
import pathlib
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
from scipy.stats import pearsonr
from loguru import logger
from functools import partial, wraps
from itertools import product
import os
from numbers import Number

# %%
def BF_zscore(input_data):
    """
    Z-score the input data vector.

    Parameters:
    input_data (array-like): The input time series (or any vector).

    Returns:
    numpy.ndarray: The z-scored transformation of the input.

    Raises:
    ValueError: If input_data contains NaN values.
    """
    # Convert input to numpy array
    input_data = np.array(input_data)

    # Check for NaNs
    if np.isnan(input_data).any():
        raise ValueError('input_data contains NaNs')

    # Z-score twice to reduce numerical error
    zscored_data = (input_data - np.mean(input_data)) / np.std(input_data, ddof=1)
    zscored_data = (zscored_data - np.mean(zscored_data)) / np.std(zscored_data, ddof=1)

    return zscored_data

# %%
eng = matlab.engine.start_matlab()

# %%
proj_root = pathlib.Path("/Users/jmoo2880/Documents/hctsa")
eng.addpath(eng.genpath(str(proj_root)), nargout=0)

# %%
def zscore_decorator(func):
    @wraps(func)
    def wrapper(y, *args, **kwargs):
        y = BF_zscore(y)
        return func(y, *args, **kwargs)
    return wrapper

def range_constructor(loader, node):
    start, end = loader.construct_sequence(node)
    return list(range(start, end+1))
yaml.add_constructor("!range", range_constructor)

# %%
def load_yaml(file):
    print(f"Loading configuration file: {file.split('/')[-1]}")
    funcs = {}
    with open(file) as f:
        yf = yaml.load(f, Loader=yaml.FullLoader)

    for module_name in yf:
        print(f"\n*** Importing module {module_name} *** \n")
        module = importlib.import_module(module_name)
        for function_name in yf[module_name]:
            # Get the function's configuration dictionary
            function_config = yf[module_name][function_name]
            # If no configs section exists or if it's empty, use a list with single empty dict
            if ('configs' not in function_config or function_config.get('configs') is None or 
                function_config.get('configs') == []):
                configs = [{}]
            else:
                configs = function_config.get('configs', [{}])

            for params in configs:
                # Handle the case where params is None
                if params is None:
                    params = {}
                    
                zscore_first = params.pop("zscore", False)
                param_keys, param_vals = zip(*params.items()) if params else ([], [])
                
                param_combinations = [dict(zip(param_keys, values)) 
                                   for values in product(*[v if isinstance(v, list) 
                                                        else [v] for v in param_vals])]
                
                # If no parameter combinations were generated, add empty dict
                if not param_combinations:
                    param_combinations = [{}]
                
                # create a function for each parameter combination
                for param_set in param_combinations:
                    feature_name = (f"{module_name}_{function_name}_" + 
                                  "_".join(f"{v}" for k, v in param_set.items())
                                  if param_set else f"{module_name}_{function_name}")
                    if not zscore_first:
                        feature_name += "_raw"
                    
                    print(f"Adding operation {feature_name} with params {param_set} "
                          f"(Z-score={zscore_first})")
                    
                    base_func = partial(getattr(module, function_name), **param_set)
                    if zscore_first:
                        base_func = zscore_decorator(base_func)
                    
                    # return the MATLAB callable corresponding to the python implementation for direct comparison
                    # make sure to check whethe the data needs to be zscored when calling the MATLAB func, cannot be wrapped as it is not a python function
                    # so needs to be done manually when calling the function.
                    hctsa_name = function_config.get('hctsa_name')
                    hctsa_callable = eval(f"eng.{hctsa_name}")

                    # keep ordered args only for testing YAML otherwise bloats
                    funcs[feature_name] = {'callable': base_func, 'params': param_set, 'hctsa_name': function_config.get('hctsa_name'), 
                                           'matlab_callable': hctsa_callable, 'isZscore': zscore_first, 'ordered_args': function_config.get('ordered_args')}
                    
    return funcs

# %%
funcs = load_yaml("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/criticality.yaml")
# Out:
# Loading configuration file: criticality.yaml
#
# *** Importing module Criticality ***
#
# Adding operation Criticality_RAD_1 with params {'tau': 1} (Z-score=True)
# Adding operation Criticality_RAD_2 with params {'tau': 2} (Z-score=True)
# Adding operation Criticality_RAD_tau with params {'tau': 'tau'} (Z-score=True)

# %%
empirical1000 = []
with open("../../../empirical1000/hctsa_timeseries-data.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        # Convert each element from string to float (or int if appropriate)
        try:
            time_series = [float(value) for value in row if value != '']
            empirical1000.append(time_series)
        except ValueError as e:
            print(f"Skipping row due to conversion error: {row}")
            continue

# %%
def eval_comparison(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = data[i]
            matlab_eval = matlab_func(BF_zscore(matlab.double(x)), *ordered_args) if isZscore else matlab_func(matlab.double(x), *ordered_args)
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
out = eval_comparison("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/criticality.yaml", empirical1000)
# Out:
# Loading configuration file: criticality.yaml
#
# *** Importing module Criticality ***
#
# Adding operation Criticality_RAD_1 with params {'tau': 1} (Z-score=True)
# Adding operation Criticality_RAD_2 with params {'tau': 2} (Z-score=True)
# Adding operation Criticality_RAD_tau with params {'tau': 'tau'} (Z-score=True)
# Evalutating Criticality_RAD_1
# Comparing to CR_RAD
#
# sigma_dx =
#
#     0.9131
#
# 0.6147442178582068
# 0.19397150795009535
# 0.49630454655667594
# 0.1983454036404054
# 0.4167212032367406
# 0.21056486501273491
# 0.4462390986662703
# 0.2059569625625757
# 0.4482167941829026
# 0.2019043584301299
# 0.5227624318383141
# 0.20124255005096545
# 1.04139658163176
# 0.09610739681049035
# 0.9129484036785128
# 0.12830514482362904
# 0.811366974670785
# 0.15908862084446976
# 0.4416024238762775
# 0.0
# 0.6028274907702723
# 0.0
# 0.6948081756835145
# 0.16863539384185738
# 0.909782664261281
# 0.13699656201389074
# 0.6678687215696919
# 0.169588664094011
# 1.0957924809126975
# 0.10132476142287457
# 0.35673833254636933
# 0.0
# 0.3833831192747302
# 0.0
# 0.5097293545424673
# 0.19234507872554038
# 0.4999626506089526
# 0.18632616908983468
# 0.6939594595955458
# 0.1579553334046817
# 0.47509345984110213
# 0.19339990122209083
# 0.5636955008648927
# 0.1670083658406373
# 0.29412857197482506
# 0.2565611988834058
# 0.8008952745852693
# 0.1415918538028388
# 1.04405011733706
# 0.05346371328117108
# 0.5686395271665795
# 0.22940983137997178
# 0.8885624740866207
# nan

# %%
def compare_outputs(outputs):
    """
    Compare MATLAB and Python feature outputs, computing relative errors
    and Pearson correlations.

    Parameters
    ----------
    outputs : dict
        Nested dictionary of feature values with structure:
        {
            feature_name: {
                ts_id: {
                    'matlab': scalar_or_dict,
                    'python': scalar_or_dict
                }
            }
        }

    Returns
    -------
    results : dict
        Dictionary mapping feature (or subfeature) names to correlation and stats:
        {
            'feature.subkey': {
                'r': float,
                'pval': float,
                'res_py': ndarray,
                'res_matlab': ndarray
            }
        }
    """
    flat = {}
    for feat, ts_dict in outputs.items():
        for ts, run in ts_dict.items():
            ml = run['matlab']
            py = run['python']
            if isinstance(ml, dict) and isinstance(py, dict):
                for k, mlv in ml.items():
                    pyv = py[k]
                    slot = f"{feat}.{k}"
                    flat.setdefault(slot, {})[ts] = (mlv, pyv)
            elif isinstance(ml, Number) and isinstance(py, Number):
                flat.setdefault(feat, {})[ts] = (ml, py)
            else:
                raise ValueError(f"Feature {feat}@{ts} is neither both scalars nor both dicts.")

    results = {}
    for slot, tsmap in flat.items():
        ml_vals, py_vals = [], []
        for ts, (mlv, pyv) in tsmap.items():
            ml_vals.append(mlv)
            py_vals.append(pyv)
            
            both_finite = np.isfinite(mlv) and np.isfinite(pyv)
            both_nan = np.isnan(mlv) and np.isnan(pyv)
            both_posinf = (mlv == np.inf) and (pyv == np.inf)
            both_neginf = (mlv == -np.inf) and (pyv == -np.inf)

            if both_finite:
                if mlv == 0:
                    rel_err = np.nan
                else:
                    rel_err = abs(mlv - pyv) / abs(mlv) * 100
                print(f"[{slot} | ts={ts}]  RelErr% = {rel_err:.2f}")
            elif both_nan or both_posinf or both_neginf:
                print(f"[{slot} | ts={ts}]  RelErr% = MATCH (both non-finite)")
            else:
                print(f"[{slot} | ts={ts}]  RelErr% = NaN (mismatch in finiteness)")

        ml_arr = np.array(ml_vals, dtype=float)
        py_arr = np.array(py_vals, dtype=float)
        finite_mask = np.isfinite(ml_arr) & np.isfinite(py_arr)

        if finite_mask.sum() > 1 and ml_arr[finite_mask].std() and py_arr[finite_mask].std():
            r, p = pearsonr(ml_arr[finite_mask], py_arr[finite_mask])
        else:
            r, p = np.nan, np.nan

        results[slot] = {
            'r': r,
            'pval': p,
            'res_py': py_arr,
            'res_matlab': ml_arr
        }

    return results

# %%
results = compare_outputs(out)
# Out:
# [Criticality_RAD_1 | ts=0]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=1]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=2]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=3]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=4]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=5]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=6]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=7]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=8]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=9]  RelErr% = MATCH (both non-finite)
# [Criticality_RAD_1 | ts=10]  RelErr% = MATCH (both non-finite)
# [Criticality_RAD_1 | ts=11]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=12]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=13]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=14]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=15]  RelErr% = MATCH (both non-finite)
# [Criticality_RAD_1 | ts=16]  RelErr% = MATCH (both non-finite)
# [Criticality_RAD_1 | ts=17]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=18]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=19]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=20]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=21]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=22]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=23]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=24]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=25]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=26]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=27]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=28]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=29]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=30]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=31]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=32]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=33]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=34]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=35]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=36]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=37]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=38]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=39]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=40]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=41]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=42]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=43]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=44]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=45]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=46]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=47]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=48]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=49]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=50]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=51]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=52]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=53]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=54]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=55]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=56]  RelErr% = 0.00
# [Criticality_RAD_1 | ts=57]  RelErr% = 0.00
# [Criticality_RAD_1 | ts
  RelErr% = 0.00
# [Criticality_RAD_tau | ts=746]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=747]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=748]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=749]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=750]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=751]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=752]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=753]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=754]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=755]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=756]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=757]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=758]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=759]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=760]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=761]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=762]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=763]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=764]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=765]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=766]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=767]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=768]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=769]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=770]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=771]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=772]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=773]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=774]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=775]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=776]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=777]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=778]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=779]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=780]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=781]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=782]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=783]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=784]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=785]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=786]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=787]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=788]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=789]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=790]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=791]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=792]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=793]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=794]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=795]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=796]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=797]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=798]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=799]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=800]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=801]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=802]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=803]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=804]  RelErr% = MATCH (both non-finite)
# [Criticality_RAD_tau | ts=805]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=806]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=807]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=808]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=809]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=810]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=811]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=812]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=813]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=814]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=815]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=816]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=817]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=818]  RelErr% = MATCH (both non-finite)
# [Criticality_RAD_tau | ts=819]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=820]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=821]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=822]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=823]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=824]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=825]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=826]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=827]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=828]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=829]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=830]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=831]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=832]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=833]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=834]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=835]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=836]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=837]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=838]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=839]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=840]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=841]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=842]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=843]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=844]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=845]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=846]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=847]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=848]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=849]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=850]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=851]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=852]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=853]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=854]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=855]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=856]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=857]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=858]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=859]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=860]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=861]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=862]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=863]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=864]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=865]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=866]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=867]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=868]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=869]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=870]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=871]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=872]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=873]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=874]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=875]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=876]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=877]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=878]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=879]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=880]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=881]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=882]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=883]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=884]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=885]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=886]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=887]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=888]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=889]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=890]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=891]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=892]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=893]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=894]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=895]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=896]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=897]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=898]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=899]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=900]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=901]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=902]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=903]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=904]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=905]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=906]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=907]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=908]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=909]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=910]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=911]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=912]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=913]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=914]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=915]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=916]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=917]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=918]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=919]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=920]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=921]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=922]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=923]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=924]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=925]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=926]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=927]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=928]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=929]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=930]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=931]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=932]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=933]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=934]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=935]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=936]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=937]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=938]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=939]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=940]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=941]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=942]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=943]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=944]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=945]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=946]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=947]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=948]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=949]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=950]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=951]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=952]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=953]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=954]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=955]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=956]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=957]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=958]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=959]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=960]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=961]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=962]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=963]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=964]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=965]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=966]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=967]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=968]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=969]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=970]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=971]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=972]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=973]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=974]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=975]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=976]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=977]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=978]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=979]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=980]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=981]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=982]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=983]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=984]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=985]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=986]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=987]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=988]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=989]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=990]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=991]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=992]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=993]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=994]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=995]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=996]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=997]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=998]  RelErr% = 0.00
# [Criticality_RAD_tau | ts=999]  RelErr% = MATCH (both non-finite)

# %% [markdown]
# Non-matching outputs due to MATLAB division by near-zero, but finite value and python rounding to zero, giving an inf

# %%
mask_py = np.isfinite(results['Criticality_RAD_1']['res_py'])
mask_ml = np.isfinite(results['Criticality_RAD_1']['res_matlab'])

# %%
pearsonr(results['Criticality_RAD_1']['res_py'][mask_py], results['Criticality_RAD_1']['res_matlab'][mask_ml])
# Out:
# PearsonRResult(statistic=np.float64(-0.0010131712259358896), pvalue=np.float64(0.9746266305486396))

# %%
np.mean(results['Criticality_RAD_1']['res_py'][mask_py])
# Out:
# np.float64(-134602099160264.56)

# %%
eng.CR_RAD(matlab.double(BF_zscore(empirical1000[601])), 1)
# Out:
# -inf

# %%
from Criticality import RAD

# %%
RAD(BF_zscore(empirical1000[601]))
# Out:
# 1.3283286473948586
# 6.964931120730528e-18
# np.float64(-1.3298687397033098e+17)
