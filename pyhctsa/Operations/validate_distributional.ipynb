# %%
import numpy as np
import pandas as pd
import matlab.engine
import yaml
import time
import importlib
import pathlib
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
from scipy.stats import pearsonr
from loguru import logger
from Entropy import ApproximateEntropy
from functools import partial, wraps
from itertools import product
import os
from typing import Union
from numbers import Number
from utilities import ZScore

# %%
import importlib
import Distributional
importlib.reload(Distributional)
# Out:
# <module 'Distributional' from '/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Operations/Distributional.py'>

# %%
def compare_outputs(outputs, exclude_keys=None):
    """
    Compare MATLAB and Python feature outputs, computing relative errors
    and Pearson correlations.

    Parameters
    ----------
    outputs : dict
        Nested dictionary of feature values with structure:
        {
            feature_name: {
                ts_id: {
                    'matlab': scalar_or_dict,
                    'python': scalar_or_dict
                }
            }
        }
    exclude_keys : set or list, optional
        Set or list of keys (feature names or feature.subkey) to exclude from comparison.

    Returns
    -------
    results : dict
        Dictionary mapping feature (or subfeature) names to correlation and stats:
        {
            'feature.subkey': {
                'r': float,
                'pval': float,
                'res_py': ndarray,
                'res_matlab': ndarray,
                'max_rel_err': float
            }
        }
    """
    if exclude_keys is None:
        exclude_keys = set()
    else:
        exclude_keys = set(exclude_keys)

    flat = {}
    for feat, ts_dict in outputs.items():
        for ts, run in ts_dict.items():
            ml = run['matlab']
            py = run['python']
            if isinstance(ml, dict) and isinstance(py, dict):
                for k, mlv in ml.items():
                    slot = f"{feat}.{k}"
                    if slot in exclude_keys or k not in py:
                        continue
                    pyv = py[k]
                    flat.setdefault(slot, {})[ts] = (mlv, pyv)
            elif isinstance(ml, Number) and isinstance(py, Number):
                if feat in exclude_keys:
                    continue
                flat.setdefault(feat, {})[ts] = (ml, py)
            else:
                raise ValueError(f"Feature {feat}@{ts} is neither both scalars nor both dicts.")

    results = {}
    for slot, tsmap in flat.items():
        ml_vals, py_vals = [], []
        rel_errors = []

        for ts, (mlv, pyv) in tsmap.items():
            ml_vals.append(mlv)
            py_vals.append(pyv)

            both_finite = np.isfinite(mlv) and np.isfinite(pyv)
            both_nan = np.isnan(mlv) and np.isnan(pyv)
            both_posinf = (mlv == np.inf) and (pyv == np.inf)
            both_neginf = (mlv == -np.inf) and (pyv == -np.inf)

            if both_finite:
                if mlv == 0:
                    rel_err = np.nan
                else:
                    rel_err = abs(mlv - pyv) / abs(mlv) * 100
                    rel_errors.append(rel_err)
                print(f"[{slot} | ts={ts}]  RelErr% = {rel_err:.2f}")
            elif both_nan or both_posinf or both_neginf:
                print(f"[{slot} | ts={ts}]  RelErr% = MATCH (both non-finite)")
            else:
                print(f"[{slot} | ts={ts}]  RelErr% = NaN (mismatch in finiteness)")

        ml_arr = np.array(ml_vals, dtype=float)
        py_arr = np.array(py_vals, dtype=float)
        finite_mask = np.isfinite(ml_arr) & np.isfinite(py_arr)

        if finite_mask.sum() > 1 and ml_arr[finite_mask].std() and py_arr[finite_mask].std():
            r, p = pearsonr(ml_arr[finite_mask], py_arr[finite_mask])
        else:
            r, p = np.nan, np.nan

        max_rel_err = np.nanmax(rel_errors) if rel_errors else np.nan

        results[slot] = {
            'r': r,
            'pval': p,
            'res_py': py_arr,
            'res_matlab': ml_arr,
            'max_rel_err': max_rel_err
        }

    return results

# %%
empirical1000 = []
with open("../../../empirical1000/hctsa_timeseries-data.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        # Convert each element from string to float (or int if appropriate)
        try:
            time_series = [float(value) for value in row if value != '']
            empirical1000.append(time_series)
        except ValueError as e:
            print(f"Skipping row due to conversion error: {row}")
            continue

# %%
def load_yaml(file):
    print(f"Loading configuration file: {file.split('/')[-1]}")
    funcs = {}
    with open(file) as f:
        yf = yaml.load(f, Loader=yaml.FullLoader)

    for module_name in yf:
        print(f"\n*** Importing module {module_name} *** \n")
        module = importlib.import_module(module_name)
        for function_name in yf[module_name]:
            # Get the function's configuration dictionary
            function_config = yf[module_name][function_name]
            # If no configs section exists or if it's empty, use a list with single empty dict
            if ('configs' not in function_config or function_config.get('configs') is None or 
                function_config.get('configs') == []):
                configs = [{}]
            else:
                configs = function_config.get('configs', [{}])

            for params in configs:
                # Handle the case where params is None
                if params is None:
                    params = {}
                    
                zscore_first = params.pop("zscore", False)
                param_keys, param_vals = zip(*params.items()) if params else ([], [])
                
                param_combinations = [dict(zip(param_keys, values)) 
                                   for values in product(*[v if isinstance(v, list) 
                                                        else [v] for v in param_vals])]
                
                # If no parameter combinations were generated, add empty dict
                if not param_combinations:
                    param_combinations = [{}]
                
                # create a function for each parameter combination
                for param_set in param_combinations:
                    feature_name = (f"{module_name}_{function_name}_" + 
                                  "_".join(f"{v}" for k, v in param_set.items())
                                  if param_set else f"{module_name}_{function_name}")
                    if not zscore_first:
                        feature_name += "_raw"
                    
                    print(f"Adding operation {feature_name} with params {param_set} "
                          f"(Z-score={zscore_first})")
                    
                    base_func = partial(getattr(module, function_name), **param_set)
                    if zscore_first:
                        base_func = zscore_decorator(base_func)
                    
                    # return the MATLAB callable corresponding to the python implementation for direct comparison
                    # make sure to check whethe the data needs to be zscored when calling the MATLAB func, cannot be wrapped as it is not a python function
                    # so needs to be done manually when calling the function.
                    hctsa_name = function_config.get('hctsa_name')
                    hctsa_callable = eval(f"eng.{hctsa_name}")

                    # keep ordered args only for testing YAML otherwise bloats
                    funcs[feature_name] = {'callable': base_func, 'params': param_set, 'hctsa_name': function_config.get('hctsa_name'), 
                                           'matlab_callable': hctsa_callable, 'isZscore': zscore_first, 'ordered_args': function_config.get('ordered_args')}
                    
    return funcs

# %%
def eval_comparison(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i])
            matlab_eval = matlab_func(ZScore(matlab.double(x)), *ordered_args) if isZscore else matlab_func(matlab.double(x), *ordered_args)
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
eng = matlab.engine.start_matlab()

# %%
proj_root = pathlib.Path("/Users/jmoo2880/Documents/hctsa")
eng.addpath(eng.genpath(str(proj_root)), nargout=0)
def zscore_decorator(func):
    @wraps(func)
    def wrapper(y, *args, **kwargs):
        y = ZScore(y)
        return func(y, *args, **kwargs)
    return wrapper

def range_constructor(loader, node):
    start, end = loader.construct_sequence(node)
    return list(range(start, end+1))
yaml.add_constructor("!range", range_constructor)

# %%
funcs = load_yaml("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml")
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_Burstiness_raw with params {} (Z-score=False)

# %%
burstiness_evals = eval_comparison("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
burstiness_compares = compare_outputs(burstiness_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_Burstiness_raw with params {} (Z-score=False)
# Evalutating Distributional_Burstiness_raw
# Comparing to DN_Burstiness
# [Distributional_Burstiness_raw.B | ts=0]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=1]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=2]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=3]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=4]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=5]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=6]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=7]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=8]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=9]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=10]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=11]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=12]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=13]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=14]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=15]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=16]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=17]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=18]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=19]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=20]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=21]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=22]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=23]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=24]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=25]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=26]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=27]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=28]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=29]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=30]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=31]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=32]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=33]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=34]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=35]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=36]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=37]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=38]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=39]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=40]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=41]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=42]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=43]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=44]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=45]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=46]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=47]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=48]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=49]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=50]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=51]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=52]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=53]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=54]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=55]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=56]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=57]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=58]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=59]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=60]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=61]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=62]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=63]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=64]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=65]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=66]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=67]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=68]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=69]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=70]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=71]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=72]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=73]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=74]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=75]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=76]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=77]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=78]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=79]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=80]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=81]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=82]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=83]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=84]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=85]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=86]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=87]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=88]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=89]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=90]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=91]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=92]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=93]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=94]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=95]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=96]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=97]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=98]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=99]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=100]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=101]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=102]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=103]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=104]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=105]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=106]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=107]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=108]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=109]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=110]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=111]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=112]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=113]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=114]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=115]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=116]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=117]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=118]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=119]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=120]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=121]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=122]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=123]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=124]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=125]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=126]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=127]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=128]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=129]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=130]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=131]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=132]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=133]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=134]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=135]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=136]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=137]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=138]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=139]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=140]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=141]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=142]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=143]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=144]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=145]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=146]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=147]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=148]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=149]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=150]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=151]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=152]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=153]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=154]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=155]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=156]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=157]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=158]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=159]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=160]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=161]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=162]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=163]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=164]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=165]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=166]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=167]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=168]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=169]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=170]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=171]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=172]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=173]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=174]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=175]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=176]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=177]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=178]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=179]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=180]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=181]  RelErr% = NaN (mismatch in finiteness)
# [Distributional_Burstiness_raw.B | ts=182]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=183]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=184]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=185]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=186]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=187]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=188]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=189]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=190]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=191]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=192]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=193]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=194]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=195]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=196]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=197]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=198]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=199]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=200]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=201]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=202]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=203]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=204]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=205]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=206]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=207]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=208]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=209]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=210]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=211]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=212]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=213]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=214]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=215]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=216]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=217]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=218]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=219]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=220]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=221]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=222]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=223]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=224]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=225]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=226]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=227]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts=228]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B | ts
  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=920]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=921]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=922]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=923]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=924]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=925]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=926]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=927]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=928]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=929]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=930]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=931]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=932]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=933]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=934]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=935]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=936]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=937]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=938]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=939]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=940]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=941]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=942]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=943]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=944]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=945]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=946]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=947]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=948]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=949]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=950]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=951]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=952]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=953]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=954]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=955]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=956]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=957]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=958]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=959]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=960]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=961]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=962]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=963]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=964]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=965]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=966]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=967]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=968]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=969]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=970]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=971]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=972]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=973]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=974]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=975]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=976]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=977]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=978]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=979]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=980]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=981]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=982]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=983]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=984]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=985]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=986]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=987]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=988]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=989]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=990]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=991]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=992]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=993]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=994]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=995]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=996]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=997]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=998]  RelErr% = 0.00
# [Distributional_Burstiness_raw.B_Kim | ts=999]  RelErr% = 0.00

# %%
[burstiness_compares[p]['r'] for p in burstiness_compares]
# Out:
# [np.float64(0.9999999999999999), np.float64(0.9999999999999998)]

# %%
eval_comparison("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_CustomSkewness_pearson_raw with params {'whatSkew': 'pearson'} (Z-score=False)
# Adding operation Distributional_CustomSkewness_bowley with params {'whatSkew': 'bowley'} (Z-score=True)
# Evalutating Distributional_CustomSkewness_pearson_raw
# Comparing to DN_CustomSkewness
# Evalutating Distributional_CustomSkewness_bowley
# Comparing to DN_CustomSkewness
# /Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Operations/Distributional.py:30: RuntimeWarning: invalid value encountered in scalar divide
# {'Distributional_CustomSkewness_pearson_raw': {0: {'matlab': 2.80227524712231,
#    'python': np.float64(2.8022752471223074)},
#   1: {'matlab': 4.987335820206696, 'python': np.float64(4.987335820206694)},
#   2: {'matlab': 6.486031817338214, 'python': np.float64(6.486031817338227)},
#   3: {'matlab': 4.65384516088154, 'python': np.float64(4.653845160881544)},
#   4: {'matlab': 5.919211569991916, 'python': np.float64(5.919211569991916)},
#   5: {'matlab': 8.714220888450903, 'python': np.float64(8.714220888450905)},
#   6: {'matlab': 1.886521531653141, 'python': np.float64(1.8865215316531396)},
#   7: {'matlab': 2.0993113649965904, 'python': np.float64(2.099311364996592)},
#   8: {'matlab': 2.4760577684416916, 'python': np.float64(2.4760577684416916)},
#   9: {'matlab': 38.210952920293984, 'python': np.float64(38.210952920293984)},
#   10: {'matlab': 3.5622426447085838, 'python': np.float64(3.5622426447085767)},
#   11: {'matlab': -1.0828983715968739,
#    'python': np.float64(-1.0828983715968756)},
#   12: {'matlab': 2.2022920075973405, 'python': np.float64(2.2022920075973422)},
#   13: {'matlab': 1.1210478217468185, 'python': np.float64(1.1210478217468187)},
#   14: {'matlab': 1.8228461702445045, 'python': np.float64(1.822846170244505)},
#   15: {'matlab': 9.34676875220821, 'python': np.float64(9.34676875220819)},
#   16: {'matlab': 9.22672068178416, 'python': np.float64(9.226720681784146)},
#   17: {'matlab': 0.08783693819854678,
#    'python': np.float64(0.08783693819854681)},
#   18: {'matlab': 14.147320025562108, 'python': np.float64(14.147320025562115)},
#   19: {'matlab': -0.024823381706060216,
#    'python': np.float64(-0.02482338170606022)},
#   20: {'matlab': 91.21302105483542, 'python': np.float64(91.21302105483537)},
#   21: {'matlab': 3.5961687265726594, 'python': np.float64(3.5961687265726585)},
#   22: {'matlab': 3.4963035352896745, 'python': np.float64(3.4963035352896705)},
#   23: {'matlab': 7.819376364236808, 'python': np.float64(7.8193763642367875)},
#   24: {'matlab': 0.8735830198627197, 'python': np.float64(0.8735830198627202)},
#   25: {'matlab': 5.705267480066785, 'python': np.float64(5.7052674800667775)},
#   26: {'matlab': 3.024660362882554, 'python': np.float64(3.0246603628825546)},
#   27: {'matlab': -1.3349683681829025,
#    'python': np.float64(-1.334968368182903)},
#   28: {'matlab': -1.2421095090564236,
#    'python': np.float64(-1.2421095090564234)},
#   29: {'matlab': 3.572014883132138, 'python': np.float64(3.572014883132138)},
#   30: {'matlab': 5.69361930079612, 'python': np.float64(5.693619300796122)},
#   31: {'matlab': 11.931737580894856, 'python': np.float64(11.931737580894854)},
#   32: {'matlab': 2.3475850190783487, 'python': np.float64(2.347585019078348)},
#   33: {'matlab': 1.959416131794778, 'python': np.float64(1.9594161317947791)},
#   34: {'matlab': 4.59784011358256, 'python': np.float64(4.597840113582556)},
#   35: {'matlab': 2.9742868318383957, 'python': np.float64(2.974286831838396)},
#   36: {'matlab': 2.54618150402603, 'python': np.float64(2.5461815040260327)},
#   37: {'matlab': 2.144958098106927, 'python': np.float64(2.1449580981069274)},
#   38: {'matlab': 6.597970767703718, 'python': np.float64(6.597970767703712)},
#   39: {'matlab': -2.0049825473681935,
#    'python': np.float64(-2.0049825473681935)},
#   40: {'matlab': 2.5697195345770085, 'python': np.float64(2.5697195345770085)},
#   41: {'matlab': 0.8728299579612177, 'python': np.float64(0.872829957961218)},
#   42: {'matlab': 1.1149194294664728, 'python': np.float64(1.1149194294664726)},
#   43: {'matlab': -7.259203168732399e-05,
#    'python': np.float64(-7.259203168734154e-05)},
#   44: {'matlab': -0.0043724369470795905,
#    'python': np.float64(-0.004372436947079581)},
#   45: {'matlab': 0.0020885330244946577,
#    'python': np.float64(0.002088533024494659)},
#   46: {'matlab': -0.36967135783993244,
#    'python': np.float64(-0.3696713578399323)},
#   47: {'matlab': -0.5504283748849593,
#    'python': np.float64(-0.5504283748849587)},
#   48: {'matlab': 0.0622083003470664,
#    'python': np.float64(0.062208300347066536)},
#   49: {'matlab': 2.5749533179921653, 'python': np.float64(2.574953317992167)},
#   50: {'matlab': 2.969506135468061, 'python': np.float64(2.9695061354680625)},
#   51: {'matlab': 2.5963035610963368, 'python': np.float64(2.5963035610963363)},
#   52: {'matlab': -0.015433850314382748,
#    'python': np.float64(-0.015433850314383745)},
#   53: {'matlab': 4.216185260985842, 'python': np.float64(4.216185260985838)},
#   54: {'matlab': -1.3753808762062212,
#    'python': np.float64(-1.3753808762062212)},
#   55: {'matlab': -0.35863220353283476,
#    'python': np.float64(-0.3586322035328344)},
#   56: {'matlab': -2.3290018057467754,
#    'python': np.float64(-2.3290018057467736)},
#   57: {'matlab': 0.19180807898539218,
#    'python': np.float64(0.19180807898539287)},
#   58: {'matlab': 0.02324970470990963,
#    'python': np.float64(0.023249704709909592)},
#   59: {'matlab': 0.0037352503553829664,
#    'python': np.float64(0.003735250355382956)},
#   60: {'matlab': 0.04582925167970806,
#    'python': np.float64(0.04582925167970811)},
#   61: {'matlab': -0.02077384080105249,
#    'python': np.float64(-0.020773840801052428)},
#   62: {'matlab': -0.005112925556156772,
#    'python': np.float64(-0.0051129255561567855)},
#   63: {'matlab': 0.000825723350660921,
#    'python': np.float64(0.0008257233506608385)},
#   64: {'matlab': -0.5327999172902071,
#    'python': np.float64(-0.5327999172902071)},
#   65: {'matlab': 0.024789420880647325,
#    'python': np.float64(0.024789420880647412)},
#   66: {'matlab': 0.10205321322268697,
#    'python': np.float64(0.1020532132226869)},
#   67: {'matlab': 0.060495607888050286,
#    'python': np.float64(0.06049560788805028)},
#   68: {'matlab': 0.0015920676163963003,
#    'python': np.float64(0.001592067616396252)},
#   69: {'matlab': -0.01031049816628788,
#    'python': np.float64(-0.010310498166287874)},
#   70: {'matlab': 1.9667662807374275, 'python': np.float64(1.966766280737428)},
#   71: {'matlab': 2.410292405082093, 'python': np.float64(2.4102924050820915)},
#   72: {'matlab': 0.14155613176233478,
#    'python': np.float64(0.14155613176233484)},
#   73: {'matlab': -10.995869350200813,
#    'python': np.float64(-10.99586935020082)},
#   74: {'matlab': -0.24083774586273063,
#    'python': np.float64(-0.24083774586273046)},
#   75: {'matlab': 2.617838993640978, 'python': np.float64(2.617838993640978)},
#   76: {'matlab': 0.008539923989751511,
#    'python': np.float64(0.008539923989751416)},
#   77: {'matlab': -0.009432165140544978,
#    'python': np.float64(-0.009432165140544974)},
#   78: {'matlab': 0.016603616554067228,
#    'python': np.float64(0.016603616554067297)},
#   79: {'matlab': 0.03425582698880684,
#    'python': np.float64(0.03425582698880677)},
#   80: {'matlab': 0.04242208467754089,
#    'python': np.float64(0.04242208467754088)},
#   81: {'matlab': -0.03411818242850314,
#    'python': np.float64(-0.0341181824285031)},
#   82: {'matlab': 0.0025781673477912187,
#    'python': np.float64(0.002578167347791222)},
#   83: {'matlab': 0.03395657003864401,
#    'python': np.float64(0.03395657003864407)},
#   84: {'matlab': -0.09948034240258491,
#    'python': np.float64(-0.09948034240258496)},
#   85: {'matlab': 0.005203467958328376,
#    'python': np.float64(0.005203467958328361)},
#   86: {'matlab': 0.003333926834480614,
#    'python': np.float64(0.003333926834480608)},
#   87: {'matlab': -0.002540459801449418,
#    'python': np.float64(-0.002540459801449424)},
#   88: {'matlab': 0.009295704977166629,
#    'python': np.float64(0.009295704977166646)},
#   89: {'matlab': -0.0038640762227531537,
#    'python': np.float64(-0.003864076222753137)},
#   90: {'matlab': 0.0011070672732630272,
#    'python': np.float64(0.001107067273263031)},
#   91: {'matlab': -0.009851641774552142,
#    'python': np.float64(-0.009851641774552142)},
#   92: {'matlab': -0.003399660522822953,
#    'python': np.float64(-0.003399660522822954)},
#   93: {'matlab': -0.014891287773751625,
#    'python': np.float64(-0.014891287773751634)},
#   94: {'matlab': -0.05519215720005536,
#    'python': np.float64(-0.055192157200055346)},
#   95: {'matlab': 0.0612193612539734,
#    'python': np.float64(0.061219361253973405)},
#   96: {'matlab': 0.00938745327607837,
#    'python': np.float64(0.009387453276078416)},
#   97: {'matlab': -0.04411902405487079,
#    'python': np.float64(-0.04411902405487073)},
#   98: {'matlab': -0.031050828639452382,
#    'python': np.float64(-0.031050828639452365)},
#   99: {'matlab': 5.355269358386358, 'python': np.float64(5.355269358386361)},
#   100: {'matlab': 13.032595116173265, 'python': np.float64(13.03259511617325)},
#   101: {'matlab': 5.354290712672927, 'python': np.float64(5.354290712672924)},
#   102: {'matlab': 13.03169588268785, 'python': np.float64(13.031695882687856)},
#   103: {'matlab': 5.3088895971370675, 'python': np.float64(5.308889597137065)},
#   104: {'matlab': -0.016671101386529705,
#    'python': np.float64(-0.016671101386529753)},
#   105: {'matlab': -0.04004141766280009,
#    'python': np.float64(-0.04004141766280014)},
#   106: {'matlab': -0.02668177743354638,
#    'python': np.float64(-0.02668177743354642)},
#   107: {'matlab': 0.012845594409892393,
#    'python': np.float64(0.012845594409892415)},
#   108: {'matlab': -0.011368540470212884,
#    'python': np.float64(-0.011368540470212971)},
#   109: {'matlab': -0.04420186411874841,
#    'python': np.float64(-0.04420186411874841)},
#   110: {'matlab': 0.004703427318208194,
#    'python': np.float64(0.004703427318208222)},
#   111: {'matlab': 0.014958861624819877,
#    'python': np.float64(0.014958861624819905)},
#   112: {'matlab': -0.0011264193532400926,
#    'python': np.float64(-0.0011264193532400926)},
#   113: {'matlab': 0.0373334282070581,
#    'python': np.float64(0.037333428207058074)},
#   114: {'matlab': 0.0383296526795601,
#    'python': np.float64(0.03832965267956008)},
#   115: {'matlab': -0.00463186371494589,
#    'python': np.float64(-0.0046318637149459435)},
#   116: {'matlab': 0.012506506967744876,
#    'python': np.float64(0.012506506967744543)},
#   117: {'matlab': 0.007620631610828942,
#    'python': np.float64(0.007620631610828951)},
#   118: {'matlab': 0.19094811642670415,
#    'python': np.float64(0.190948116426704)},
#   119: {'matlab': 0.013092971432491522,
#    'python': np.float64(0.013092971432491529)},
#   120: {'matlab': -0.023625602436963797,
#    'python': np.float64(-0.02362560243696381)},
#   121: {'matlab': 0.030927189910927976,
#    'python': np.float64(0.030927189910928018)},
#   122: {'matlab': 0.007180726950543365,
#    'python': np.float64(0.007180726950543356)},
#   123: {'matlab': -0.0037359864695790178,
#    'python': np.float64(-0.0037359864695790264)},
#   124: {'matlab': -0.016031677377246773,
#    'python': np.float64(-0.01603167737724676)},
#   125: {'matlab': -0.01263652990947424,
#    'python': np.float64(-0.012636529909474229)},
#   126: {'matlab': -0.014745340433329207,
#    'python': np.float64(-0.014745340433329241)},
#   127: {'matlab': 0.03066717698980414,
#    'python': np.float64(0.030667176989804246)},
#   128: {'matlab': -0.003115662877256746,
#    'python': np.float64(-0.003115662877256751)},
#   129: {'matlab': 0.031686781673156736,
#    'python': np.float64(0.03168678167315685)},
#   130: {'matlab': -0.002562158587197997,
#    'python': np.float64(-0.0025621585871979913)},
#   131: {'matlab': 0.0552977895526654,
#    'python': np.float64(0.055297789552665184)},
#   132: {'matlab': -0.016558119187087248,
#    'python': np.float64(-0.01655811918708725)},
#   133: {'matlab': 0.03941385988183173,
#    'python': np.float64(0.03941385988183174)},
#   134: {'matlab': 0.029688824086247134,
#    'python': np.float64(0.02968882408624711)},
#   135: {'matlab': 0.008105107967789713,
#    'python': np.float64(0.008105107967789712)},
#   136: {'matlab': -0.5467568889673129,
#    'python': np.float64(-0.5467568889673132)},
#   137: {'matlab': -0.5249391105496692,
#    'python': np.float64(-0.5249391105496696)},
#   138: {'matlab': -0.5571906647672547,
#    'python': np.float64(-0.5571906647672549)},
#   139: {'matlab': -0.6879534622889637,
#    'python': np.float64(-0.6879534622889646)},
#   140: {'matlab': -0.6025646721459336,
#    'python': np.float64(-0.6025646721459336)},
#   141: {'matlab': -0.45590243827396615,
#    'python': np.float64(-0.45590243827396604)},
#   142: {'matlab': -0.6312872292271896,
#    'python': np.float64(-0.6312872292271895)},
#   143: {'matlab': -0.36156031467002503,
#    'python': np.float64(-0.3615603146700251)},
#   144: {'matlab': -0.5197886955119686,
#    'python': np.float64(-0.5197886955119688)},
#   145: {'matlab': 0.10740036592744258,
#    'python': np.float64(0.10740036592744258)},
#   146: {'matlab': 0.01798895918178646,
#    'python': np.float64(0.017988959181786477)},
#   147: {'matlab': -0.0038884930207014456,
#    'python': np.float64(-0.0038884930207013914)},
#   148: {'matlab': 0.026559511048117716,
#    'python': np.float64(0.026559511048117698)},
#   149: {'matlab': -0.005428563200998303,
#    'python': np.float64(-0.005428563200998367)},
#   150: {'matlab': -0.012206192208151768,
#    'python': np.float64(-0.012206192208151848)},
#   151: {'matlab': -0.00142274203463547,
#    'python': np.float64(-0.0014227420346355228)},
#   152: {'matlab': -2.2210565046367376,
#    'python': np.float64(-2.2210565046367368)},
#   153: {'matlab': -2.214625569215833,
#    'python': np.float64(-2.214625569215831)},
#   154: {'matlab': -0.14749954021137607,
#    'python': np.float64(-0.14749954021137615)},
#   155: {'matlab': -2.2180279699621686,
#    'python': np.float64(-2.2180279699621694)},
#   156: {'matlab': -0.06539658494438462,
#    'python': np.float64(-0.06539658494438458)},
#   157: {'matlab': -2.208469833558941,
#    'python': np.float64(-2.2084698335589406)},
#   158: {'matlab': -2.211167964237507,
#    'python': np.float64(-2.2111679642375055)},
#   159: {'matlab': 0.08455424125650511,
#    'python': np.float64(0.08455424125650506)},
#   160: {'matlab': -0.0017711779449868397,
#    'python': np.float64(-0.001771177944987215)},
#   161: {'matlab': 0.0013047073565028708,
#    'python': np.float64(0.001304707356502807)},
#   162: {'matlab': 0.0034934036504094823,
#    'python': np.float64(0.0034934036504101046)},
#   163: {'matlab': 0.00961724106682734,
#    'python': np.float64(0.009617241066827186)},
#   164: {'matlab': -0.00014400965772294955,
#    'python': np.float64(-0.00014400965772212862)},
#   165: {'matlab': 3.1481264708531205,
#    'python': np.float64(3.1481264708531245)},
#   166: {'matlab': 2.8903735297390214,
#    'python': np.float64(2.8903735297390205)},
#   167: {'matlab': 3.014514691043576, 'python': np.float64(3.0145146910435767)},
#   168: {'matlab': 2.921327562414063, 'python': np.float64(2.921327562414062)},
#   169: {'matlab': 2.5324197508827977, 'python': np.float64(2.532419750882799)},
#   170: {'matlab': 2.9220358754880307, 'python': np.float64(2.92203587548803)},
#   171: {'matlab': 2.7847806340055676, 'python': np.float64(2.784780634005567)},
#   172: {'matlab': 2.887479059969796, 'python': np.float64(2.8874790599697975)},
#   173: {'matlab': 2.771213336502018, 'python': np.float64(2.7712133365020195)},
#   174: {'matlab': 2.7430557270421376,
#    'python': np.float64(2.7430557270421367)},
#   175: {'matlab': 2.9806148333605016, 'python': np.float64(2.980614833360505)},
#   176: {'matlab': 2.9662069743149484,
#    'python': np.float64(2.9662069743149475)},
#   177: {'matlab': 9.31599540939919e-05,
#    'python': np.float64(9.31599540939082e-05)},
#   178: {'matlab': -0.0035015338577869377,
#    'python': np.float64(-0.0035015338577869377)},
#   179: {'matlab': 4.8570061955049075, 'python': np.float64(4.857006195504905)},
#   180: {'matlab': 0.919132053844395, 'python': np.float64(0.919132053844395)},
#   181: {'matlab': 0.0, 'python': np.float64(2.382227303238568e-18)},
#   182: {'matlab': 0.3200156942891392,
#    'python': np.float64(0.32001569428913995)},
#   183: {'matlab': 0.010953443328122148,
#    'python': np.float64(0.010953443328122075)},
#   184: {'matlab': -0.35991789669810187,
#    'python': np.float64(-0.3599178966981019)},
#   185: {'matlab': -0.30453442047218665,
#    'python': np.float64(-0.3045344204721866)},
#   186: {'matlab': 0.05846768747332461,
#    'python': np.float64(0.05846768747332467)},
#   187: {'matlab': -0.9257610927132105,
#    'python': np.float64(-0.9257610927132114)},
#   188: {'matlab': -0.24381619313320027,
#    'python': np.float64(-0.24381619313320027)},
#   189: {'matlab': 0.0061496466321048935,
#    'python': np.float64(0.006149646632104858)},
#   190: {'matlab': -0.9191427140785215,
#    'python': np.float64(-0.9191427140785217)},
#   191: {'matlab': -1.5915780507264767,
#    'python': np.float64(-1.5915780507264763)},
#   192: {'matlab': 3.5663688589995677, 'python': np.float64(3.566368858999568)},
#   193: {'matlab': 4.129774089249894, 'python': np.float64(4.1297740892498975)},
#   194: {'matlab': 4.254750506625102, 'python': np.float64(4.254750506625103)},
#   195: {'matlab': 3.2189688235098575,
#    'python': np.float64(3.2189688235098575)},
#   196: {'matlab': 4.205002115962565, 'python': np.float64(4.205002115962566)},
#   197: {'matlab': 3.5736098214135232, 'python': np.float64(3.573609821413518)},
#   198: {'matlab': 4.250110175626563, 'python': np.float64(4.25011017562656)},
#   199: {'matlab': 3.5313855815434705,
#    'python': np.float64(3.5313855815434723)},
#   200: {'matlab': 1.3918451711466975, 'python': np.float64(1.3918451711467)},
#   201: {'matlab': 1.375609250421688, 'python': np.float64(1.3756092504216884)},
#   202: {'matlab': 1.39154682969371, 'python': np.float64(1.3915468296937108)},
#   203: {'matlab': 1.7250518063540228,
#    'python': np.float64(1.7250518063540219)},
#   204: {'matlab': 1.3519216597310044, 'python': np.float64(1.351921659731004)},
#   205: {'matlab': 1.4947171263360133,
#    'python': np.float64(1.4947171263360128)},
#   206: {'matlab': 1.330839638692054, 'python': np.float64(1.3308396386920536)},
#   207: {'matlab': 1.3885723956570595,
#    'python': np.float64(1.3885723956570577)},
#   208: {'matlab': 1.4097033395204601,
#    'python': np.float64(1.4097033395204617)},
#   209: {'matlab': 0.5077029911416675,
#    'python': np.float64(0.5077029911416672)},
#   210: {'matlab': 0.5380184521845154,
#    'python': np.float64(0.5380184521845153)},
#   211: {'matlab': 0.45461408055671004,
#    'python': np.float64(0.45461408055670977)},
#   212: {'matlab': 0.5100763264927801,
#    'python': np.float64(0.5100763264927801)},
#   213: {'matlab': 0.5221587645834032,
#    'python': np.float64(0.5221587645834029)},
#   214: {'matlab': 0.4665682822710254,
#    'python': np.float64(0.4665682822710255)},
#   215: {'matlab': 0.1857175619353077,
#    'python': np.float64(0.1857175619353074)},
#   216: {'matlab': 0.2801531695599346,
#    'python': np.float64(0.2801531695599346)},
#   217: {'matlab': 0.18057521591115994,
#    'python': np.float64(0.1805752159111598)},
#   218: {'matlab': 0.2515412370146505,
#    'python': np.float64(0.2515412370146505)},
#   219: {'matlab': 0.16694928429117462,
#    'python': np.float64(0.16694928429117456)},
#   220: {'matlab': -0.008165739605267255,
#    'python': np.float64(-0.0081657396052674)},
#   221: {'matlab': 0.08063138740531277,
#    'python': np.float64(0.08063138740531275)},
#   222: {'matlab': -0.27536069645672495,
#    'python': np.float64(-0.27536069645672495)},
#   223: {'matlab': -0.0035229454242918395,
#    'python': np.float64(-0.0035229454242918885)},
#   224: {'matlab': 0.024766640874411747,
#    'python': np.float64(0.024766640874411598)},
#   225: {'matlab': -0.3824679495227078,
#    'python': np.float64(-0.382467949522708)},
#   226: {'matlab': 0.024783751209662638,
#    'python': np.float64(0.024783751209662565)},
#   227: {'matlab': -0.03136252713648865,
#    'python': np.float64(-0.03136252713648875)},
#   228: {'matlab': -1.2951314343598537,
#    'python': np.float64(-1.2951314343598548)},
#   229: {'matlab': -1.3231330635118717,
#    'python': np.float64(-1.3231330635118692)},
#   230: {'matlab': 2.627395335471317, 'python': np.float64(2.6273953354713164)},
#   231: {'matlab': 2.6362551395654403,
#    'python': np.float64(2.6362551395654408)},
#   232: {'matlab': -1.2759574464205687,
#    'python': np.float64(-1.2759574464205683)},
#   233: {'matlab': 2.7505008051456397, 'python': np.float64(2.750500805145639)},
#   234: {'matlab': 2.6243413943319083, 'python': np.float64(2.62434139433191)},
#   235: {'matlab': -1.3089974460958742,
#    'python': np.float64(-1.3089974460958747)},
#   236: {'matlab': 3.4712023185614447, 'python': np.float64(3.471202318561444)},
#   237: {'matlab': 3.067476208938629, 'python': np.float64(3.0674762089386274)},
#   238: {'matlab': 3.5767943876724115, 'python': np.float64(3.576794387672413)},
#   239: {'matlab': 3.6145493507231703, 'python': np.float64(3.614549350723171)},
#   240: {'matlab': 3.0102178013396226,
#    'python': np.float64(3.0102178013396217)},
#   241: {'matlab': 3.48443986472185, 'python': np.float64(3.4844398647218453)},
#   242: {'matlab': 3.1003531142597773, 'python': np.float64(3.100353114259779)},
#   243: {'matlab': 3.446912874998069, 'python': np.float64(3.446912874998069)},
#   244: {'matlab': 3.483070713052609, 'python': np.float64(3.483070713052609)},
#   245: {'matlab': 3.4255220269078097, 'python': np.float64(3.425522026907809)},
#   246: {'matlab': 3.3213215474985036,
#    'python': np.float64(3.3213215474985036)},
#   247: {'matlab': 3.441089992257626, 'python': np.float64(3.441089992257626)},
#   248: {'matlab': 3.2914087755144297,
#    'python': np.float64(3.2914087755144306)},
#   249: {'matlab': 3.427618839055463, 'python': np.float64(3.427618839055463)},
#   250: {'matlab': 3.4938387252675724,
#    'python': np.float64(3.4938387252675716)},
#   251: {'matlab': 3.5600061055131595,
#    'python': np.float64(3.5600061055131595)},
#   252: {'matlab': 3.4495702780990274,
#    'python': np.float64(3.4495702780990265)},
#   253: {'matlab': 0.0009959679304092405,
#    'python': np.float64(0.0009959679304092184)},
#   254: {'matlab': 0.005178448808949886,
#    'python': np.float64(0.005178448808949879)},
#   255: {'matlab': -0.014786711237561742,
#    'python': np.float64(-0.014786711237561867)},
#   256: {'matlab': 0.00977341035110346,
#    'python': np.float64(0.009773410351103224)},
#   257: {'matlab': -0.03489113532549265,
#    'python': np.float64(-0.03489113532549234)},
#   258: {'matlab': -0.02013317945115285,
#    'python': np.float64(-0.02013317945115301)},
#   259: {'matlab': -0.0056251274133529055,
#    'python': np.float64(-0.0056251274133528794)},
#   260: {'matlab': -0.0076616878035084025,
#    'python': np.float64(-0.007661687803508424)},
#   261: {'matlab': -0.0022471420558129486,
#    'python': np.float64(-0.0022471420558128783)},
#   262: {'matlab': 0.015421995979631538,
#    'python': np.float64(0.015421995979631556)},
#   263: {'matlab': -0.033922238704115204,
#    'python': np.float64(-0.03392223870411498)},
#   264: {'matlab': 0.524362054756169, 'python': np.float64(0.524362054756169)},
#   265: {'matlab': 0.5270939413755699,
#    'python': np.float64(0.5270939413755695)},
#   266: {'matlab': 0.5247434007884926,
#    'python': np.float64(0.5247434007884926)},
#   267: {'matlab': 0.5223785742269313,
#    'python': np.float64(0.5223785742269311)},
#   268: {'matlab': 0.5012545494002751,
#    'python': np.float64(0.5012545494002754)},
#   269: {'matlab': 0.5221485020684773,
#    'python': np.float64(0.5221485020684775)},
#   270: {'matlab': 3.2298231770725536, 'python': np.float64(3.229823177072553)},
#   271: {'matlab': 3.3337749714898006,
#    'python': np.float64(3.3337749714897944)},
#   272: {'matlab': 3.7527234267834197,
#    'python': np.float64(3.7527234267834197)},
#   273: {'matlab': 3.5988158483934933,
#    'python': np.float64(3.5988158483934933)},
#   274: {'matlab': 3.7346274311259067, 'python': np.float64(3.734627431125908)},
#   275: {'matlab': 3.563181373188221, 'python': np.float64(3.5631813731882205)},
#   276: {'matlab': 3.6069663072610636, 'python': np.float64(3.606966307261062)},
#   277: {'matlab': 2.527281484776414, 'python': np.float64(2.5272814847764185)},
#   278: {'matlab': 2.3781691370555884, 'python': np.float64(2.378169137055589)},
#   279: {'matlab': 2.501839841170893, 'python': np.float64(2.5018398411708938)},
#   280: {'matlab': 2.412070903518815, 'python': np.float64(2.412070903518814)},
#   281: {'matlab': 2.385658890603857, 'python': np.float64(2.3856588906038576)},
#   282: {'matlab': 2.526740501796863, 'python': np.float64(2.5267405017968625)},
#   283: {'matlab': 2.3903950884165774,
#    'python': np.float64(2.3903950884165766)},
#   284: {'matlab': 2.9667622563283724,
#    'python': np.float64(2.9667622563283658)},
#   285: {'matlab': 2.6299982838565388,
#    'python': np.float64(2.6299982838565388)},
#   286: {'matlab': 2.5537111505247476,
#    'python': np.float64(2.5537111505247476)},
#   287: {'matlab': 2.9655478228539196, 'python': np.float64(2.965547822853921)},
#   288: {'matlab': 2.2504827299112358,
#    'python': np.float64(2.2504827299112686)},
#   289: {'matlab': 2.4123457050336037,
#    'python': np.float64(2.4123457050336055)},
#   290: {'matlab': 3.4628930940912186, 'python': np.float64(3.46289309409122)},
#   291: {'matlab': 3.4918343954193927,
#    'python': np.float64(3.4918343954193896)},
#   292: {'matlab': 3.4522014584142298,
#    'python': np.float64(3.4522014584142307)},
#   293: {'matlab': 3.4621689447404966, 'python': np.float64(3.462168944740497)},
#   294: {'matlab': 3.480573478213981, 'python': np.float64(3.480573478213981)},
#   295: {'matlab': 3.4641996280750127,
#    'python': np.float64(3.4641996280750127)},
#   296: {'matlab': 3.510256468515584, 'python': np.float64(3.510256468515584)},
#   297: {'matlab': 3.3188547688694245, 'python': np.float64(3.318854768869423)},
#   298: {'matlab': 3.5061899012614135,
#    'python': np.float64(3.5061899012614144)},
#   299: {'matlab': 3.449572331766564, 'python': np.float64(3.449572331766566)},
#   300: {'matlab': 3.450808762281153, 'python': np.float64(3.4508087622811585)},
#   301: {'matlab': 3.967454152789922, 'python': np.float64(3.967454152789924)},
#   302: {'matlab': 3.981971844500678, 'python': np.float64(3.981971844500677)},
#   303: {'matlab': 3.9372160915575023,
#    'python': np.float64(3.9372160915575014)},
#   304: {'matlab': 3.916298169843747, 'python': np.float64(3.916298169843748)},
#   305: {'matlab': 4.017455173724649, 'python': np.float64(4.017455173724649)},
#   306: {'matlab': 3.959772835359685, 'python': np.float64(3.959772835359686)},
#   307: {'matlab': 3.9689519145082297,
#    'python': np.float64(3.9689519145082355)},
#   308: {'matlab': 2.284565620820972, 'python': np.float64(2.284565620820971)},
#   309: {'matlab': 2.3336288583691402, 'python': np.float64(2.333628858369138)},
#   310: {'matlab': 2.314178956093447, 'python': np.float64(2.314178956093443)},
#   311: {'matlab': 2.3088366232039808,
#    'python': np.float64(2.3088366232039808)},
#   312: {'matlab': 2.348701977244993, 'python': np.float64(2.3487019772449917)},
#   313: {'matlab': 2.2856122621937636, 'python': np.float64(2.285612262193762)},
#   314: {'matlab': 2.1429361949799555,
#    'python': np.float64(2.1429361949799546)},
#   315: {'matlab': 2.357288789290297, 'python': np.float64(2.3572887892903003)},
#   316: {'matlab': 5.53583855691775, 'python': np.float64(5.535838556917749)},
#   317: {'matlab': 4.374696712817224, 'python': np.float64(4.374696712817221)},
#   318: {'matlab': 3.5841124765819807, 'python': np.float64(3.58411247658198)},
#   319: {'matlab': 4.76194384768184, 'python': np.float64(4.761943847681843)},
#   320: {'matlab': 4.158621508526738, 'python': np.float64(4.158621508526736)},
#   321: {'matlab': 4.287423296278652, 'python': np.float64(4.287423296278652)},
#   322: {'matlab': 3.5880433682292394,
#    'python': np.float64(3.5880433682292394)},
#   323: {'matlab': 5.787773823033383, 'python': np.float64(5.78777382303339)},
#   324: {'matlab': 4.798330209940955, 'python': np.float64(4.798330209940951)},
#   325: {'matlab': 4.535409762807683, 'python': np.float64(4.535409762807681)},
#   326: {'matlab': -1.3993322923408522,
#    'python': np.float64(-1.3993322923408504)},
#   327: {'matlab': -1.2917293655569528,
#    'python': np.float64(-1.2917293655569544)},
#   328: {'matlab': -1.3692439037195547,
#    'python': np.float64(-1.3692439037195543)},
#   329: {'matlab': -1.3097391289436937,
#    'python': np.float64(-1.3097391289436935)},
#   330: {'matlab': -1.3003942357148681,
#    'python': np.float64(-1.300394235714867)},
#   331: {'matlab': -1.3973083139832927,
#    'python': np.float64(-1.397308313983292)},
#   332: {'matlab': 2.2039988191881332, 'python': np.float64(2.203998819188132)},
#   333: {'matlab': -1.273073013877504,
#    'python': np.float64(-1.2730730138775033)},
#   334: {'matlab': -0.004463474593039989,
#    'python': np.float64(-0.004463474593039991)},
#   335: {'matlab': 0.00280285370266498,
#    'python': np.float64(0.0028028537026649767)},
#   336: {'matlab': -0.4129283227509586,
#    'python': np.float64(-0.4129283227509586)},
#   337: {'matlab': -0.0009357318836052305,
#    'python': np.float64(-0.0009357318836052282)},
#   338: {'matlab': -0.0023761083158289403,
#    'python': np.float64(-0.0023761083158289403)},
#   339: {'matlab': -0.5012288134704176,
#    'python': np.float64(-0.5012288134704176)},
#   340: {'matlab': -0.013455236499066507,
#    'python': np.float64(-0.013455236499066502)},
#   341: {'matlab': 0.02879126434542543,
#    'python': np.float64(0.02879126434542542)},
#   342: {'matlab': -0.0029665495864409377,
#    'python': np.float64(-0.002966549586440935)},
#   343: {'matlab': -0.002621273779331059,
#    'python': np.float64(-0.0026212737793310575)},
#   344: {'matlab': -0.09117856539373863,
#    'python': np.float64(-0.09117856539373864)},
#   345: {'matlab': 0.0008388733455993203,
#    'python': np.float64(0.0008388733455993194)},
#   346: {'matlab': -0.0012325165985170067,
#    'python': np.float64(-0.001232516598517009)},
#   347: {'matlab': 1.0851943088383658,
#    'python': np.float64(1.0851943088383664)},
#   348: {'matlab': -11.900185837871604,
#    'python': np.float64(-11.900185837871671)},
#   349: {'matlab': -0.0026335324770211826,
#    'python': np.float64(-0.0026335324770211835)},
#   350: {'matlab': -0.0010175852785583495,
#    'python': np.float64(-0.0010175852785583468)},
#   351: {'matlab': -1.7458429794394335,
#    'python': np.float64(-1.7458429794394332)},
#   352: {'matlab': -0.28521772791712713,
#    'python': np.float64(-0.2852177279171271)},
#   353: {'matlab': -1.306621864852625,
#    'python': np.float64(-1.306621864852625)},
#   354: {'matlab': -1.3909125760338563,
#    'python': np.float64(-1.3909125760338563)},
#   355: {'matlab': -1.4087384030792216,
#    'python': np.float64(-1.4087384030792205)},
#   356: {'matlab': -1.4289635967235947,
#    'python': np.float64(-1.4289635967235945)},
#   357: {'matlab': -1.5534690898467716,
#    'python': np.float64(-1.553469089846776)},
#   358: {'matlab': 1.2964733714385952,
#    'python': np.float64(1.2964733714385954)},
#   359: {'matlab': 0.20569634641684414,
#    'python': np.float64(0.20569634641684406)},
#   360: {'matlab': 5.608224290718486, 'python': np.float64(5.608224290718494)},
#   361: {'matlab': -0.009577125481061976,
#    'python': np.float64(-0.009577125481061972)},
#   362: {'matlab': 0.0037949919913898367,
#    'python': np.float64(0.003794991991389917)},
#   363: {'matlab': 0.040453015141413036,
#    'python': np.float64(0.04045301514141307)},
#   364: {'matlab': -0.05133352151048076,
#    'python': np.float64(-0.05133352151048073)},
#   365: {'matlab': 0.005250748177666847,
#    'python': np.float64(0.005250748177666772)},
#   366: {'matlab': -0.04717819475759482,
#    'python': np.float64(-0.04717819475759485)},
#   367: {'matlab': 0.017815352579489817,
#    'python': np.float64(0.01781535257948978)},
#   368: {'matlab': -0.0585826557233497,
#    'python': np.float64(-0.058582655723349655)},
#   369: {'matlab': 0.04630167790534969,
#    'python': np.float64(0.04630167790534974)},
#   370: {'matlab': 0.010671073998321179,
#    'python': np.float64(0.010671073998321226)},
#   371: {'matlab': 0.0005364552591625179,
#    'python': np.float64(0.0005364552591625179)},
#   372: {'matlab': 0.012177764611011378,
#    'python': np.float64(0.012177764611011424)},
#   373: {'matlab': -0.003394556940857392,
#    'python': np.float64(-0.003394556940857411)},
#   374: {'matlab': 0.0013065822957581774,
#    'python': np.float64(0.0013065822957581796)},
#   375: {'matlab': -0.03209017930624046,
#    'python': np.float64(-0.03209017930624048)},
#   376: {'matlab': 0.03509159290535818,
#    'python': np.float64(0.035091592905358196)},
#   377: {'matlab': 0.03046516180105514,
#    'python': np.float64(0.0304651618010551)},
#   378: {'matlab': 0.013101570080310489,
#    'python': np.float64(0.013101570080310515)},
#   379: {'matlab': 0.0071667288888549565,
#    'python': np.float64(0.0071667288888549235)},
#   380: {'matlab': 0.8070251211649823, 'python': np.float64(0.807025121164982)},
#   381: {'matlab': 0.14010289888377142,
#    'python': np.float64(0.14010289888377142)},
#   382: {'matlab': 1.2032777121936145,
#    'python': np.float64(1.2032777121936156)},
#   383: {'matlab': -0.38273948184423284,
#    'python': np.float64(-0.3827394818442329)},
#   384: {'matlab': 0.15950640440131675,
#    'python': np.float64(0.1595064044013168)},
#   385: {'matlab': -0.39128192145886403,
#    'python': np.float64(-0.3912819214588643)},
#   386: {'matlab': 0.18027166030247982,
#    'python': np.float64(0.1802716603024798)},
#   387: {'matlab': -0.3926931749431071,
#    'python': np.float64(-0.3926931749431073)},
#   388: {'matlab': 0.013655441140995076,
#    'python': np.float64(0.013655441140995022)},
#   389: {'matlab': -1.4799325099266796,
#    'python': np.float64(-1.4799325099266805)},
#   390: {'matlab': -1.4712856952492102,
#    'python': np.float64(-1.4712856952492095)},
#   391: {'matlab': -0.5031222551605183,
#    'python': np.float64(-0.5031222551605185)},
#   392: {'matlab': 0.20474789126990958,
#    'python': np.float64(0.20474789126990936)},
#   393: {'matlab': -1.933670983634944,
#    'python': np.float64(-1.933670983634943)},
#   394: {'matlab': 0.9936444552123954,
#    'python': np.float64(0.9936444552123952)},
#   395: {'matlab': -0.8388568290258296,
#    'python': np.float64(-0.8388568290258301)},
#   396: {'matlab': -0.8100597642184815,
#    'python': np.float64(-0.8100597642184815)},
#   397: {'matlab': -1.5541134111227066,
#    'python': np.float64(-1.5541134111227033)},
#   398: {'matlab': -1.564731291369446,
#    'python': np.float64(-1.5647312913694456)},
#   399: {'matlab': -0.004792294917037083,
#    'python': np.float64(-0.004792294917037082)},
#   400: {'matlab': -0.0009492402027412787,
#    'python': np.float64(-0.0009492402027412796)},
#   401: {'matlab': 0.00043321398388538164,
#    'python': np.float64(0.00043321398388538283)},
#   402: {'matlab': 0.007028985660311001,
#    'python': np.float64(0.007028985660310988)},
#   403: {'matlab': 0.0077381503740237625,
#    'python': np.float64(0.007738150374023764)},
#   404: {'matlab': 0.00044265560835017793,
#    'python': np.float64(0.0004426556083501841)},
#   405: {'matlab': -0.007021636662506705,
#    'python': np.float64(-0.0070216366625066836)},
#   406: {'matlab': 0.41170590201582297,
#    'python': np.float64(0.411705902015823)},
#   407: {'matlab': 58.389822170135275, 'python': np.float64(58.38982217013529)},
#   408: {'matlab': 22.103391024120672,
#    'python': np.float64(22.103391024120683)},
#   409: {'matlab': 2.2887473330195682,
#    'python': np.float64(2.2887473330195682)},
#   410: {'matlab': 10.026743990901977,
#    'python': np.float64(10.026743990901988)},
#   411: {'matlab': 13.010750206770577,
#    'python': np.float64(13.010750206770583)},
#   412: {'matlab': 10.095477361388161,
#    'python': np.float64(10.095477361388154)},
#   413: {'matlab': 2.6015624225819907, 'python': np.float64(2.601562422581993)},
#   414: {'matlab': 3.4031677418165813,
#    'python': np.float64(3.4031677418165835)},
#   415: {'matlab': 2.1065350048166596,
#    'python': np.float64(2.1065350048166613)},
#   416: {'matlab': 3.6059993696967743,
#    'python': np.float64(3.6059993696967743)},
#   417: {'matlab': 3.7190604348770204,
#    'python': np.float64(3.7190604348770213)},
#   418: {'matlab': 1.2221895868091683,
#    'python': np.float64(1.2221895868091686)},
#   419: {'matlab': 1.1869883847956224,
#    'python': np.float64(1.1869883847956226)},
#   420: {'matlab': 2.904643119620351, 'python': np.float64(2.90464311962035)},
#   421: {'matlab': 2.233395867315149, 'python': np.float64(2.2333958673151493)},
#   422: {'matlab': 2.289164232509118, 'python': np.float64(2.289164232509118)},
#   423: {'matlab': 2.882487082806053, 'python': np.float64(2.882487082806053)},
#   424: {'matlab': 3.0869354007412193,
#    'python': np.float64(3.0869354007412197)},
#   425: {'matlab': 3.0370452659693155, 'python': np.float64(3.037045265969315)},
#   426: {'matlab': 7.42675034981154, 'python': np.float64(7.42675034981154)},
#   427: {'matlab': 4.355686945088137, 'python': np.float64(4.355686945088138)},
#   428: {'matlab': 4.072575329782643, 'python': np.float64(4.072575329782644)},
#   429: {'matlab': 5.784121982331966, 'python': np.float64(5.784121982331965)},
#   430: {'matlab': 5.61612508089173, 'python': np.float64(5.61612508089173)},
#   431: {'matlab': 7.670433257117903, 'python': np.float64(7.670433257117908)},
#   432: {'matlab': 4.088708316415982, 'python': np.float64(4.088708316415983)},
#   433: {'matlab': 16.665936712064582,
#    'python': np.float64(16.665936712064582)},
#   434: {'matlab': 1.4201890276763183, 'python': np.float64(1.420189027676318)},
#   435: {'matlab': 0.4519995941461411,
#    'python': np.float64(0.4519995941461411)},
#   436: {'matlab': 3.955705696540231, 'python': np.float64(3.9557056965402304)},
#   437: {'matlab': 0.5281361489457241,
#    'python': np.float64(0.5281361489457239)},
#   438: {'matlab': 3.277345952397334, 'python': np.float64(3.2773459523973334)},
#   439: {'matlab': 4.435615171462278, 'python': np.float64(4.435615171462278)},
#   440: {'matlab': 0.49807509339263, 'python': np.float64(0.49807509339263006)},
#   441: {'matlab': 1.3642814236674563, 'python': np.float64(1.364281423667456)},
#   442: {'matlab': 2.02046601609457, 'python': np.float64(2.0204660160945718)},
#   443: {'matlab': 0.041280949067842784,
#    'python': np.float64(0.0412809490678428)},
#   444: {'matlab': -0.015821180292871447,
#    'python': np.float64(-0.015821180292871457)},
#   445: {'matlab': 0.06291152305932672,
#    'python': np.float64(0.06291152305932672)},
#   446: {'matlab': 2.3522659999215896,
#    'python': np.float64(2.3522659999215914)},
#   447: {'matlab': 0.06309737496097126,
#    'python': np.float64(0.06309737496097126)},
#   448: {'matlab': -0.013709462810090422,
#    'python': np.float64(-0.013709462810090419)},
#   449: {'matlab': -0.038479107704240234,
#    'python': np.float64(-0.03847910770424029)},
#   450: {'matlab': 7.352668399519106, 'python': np.float64(7.352668399519109)},
#   451: {'matlab': -0.023239315890823637,
#    'python': np.float64(-0.023239315890823606)},
#   452: {'matlab': -0.016162704305539722,
#    'python': np.float64(-0.016162704305539732)},
#   453: {'matlab': 7.459522530990586, 'python': np.float64(7.4595225309905855)},
#   454: {'matlab': -0.01021298046137902,
#    'python': np.float64(-0.010212980461379004)},
#   455: {'matlab': -0.02575898291415442,
#    'python': np.float64(-0.025758982914154425)},
#   456: {'matlab': 7.359940731938452, 'python': np.float64(7.35994073193845)},
#   457: {'matlab': -0.009981259070192533,
#    'python': np.float64(-0.009981259070192464)},
#   458: {'matlab': -0.06818794091800588,
#    'python': np.float64(-0.06818794091800588)},
#   459: {'matlab': -0.0061331714512179525,
#    'python': np.float64(-0.006133171451217901)},
#   460: {'matlab': 0.0015385989815511261,
#    'python': np.float64(0.0015385989815511218)},
#   461: {'matlab': 0.024915250294004116,
#    'python': np.float64(0.02491525029400406)},
#   462: {'matlab': -0.003785635554440515,
#    'python': np.float64(-0.0037856355544403702)},
#   463: {'matlab': -0.011491281593870525,
#    'python': np.float64(-0.011491281593870513)},
#   464: {'matlab': 4.381822714211619, 'python': np.float64(4.381822714211621)},
#   465: {'matlab': -0.0049981435667023864,
#    'python': np.float64(-0.004998143566702436)},
#   466: {'matlab': 4.3841958341639975, 'python': np.float64(4.384195834163997)},
#   467: {'matlab': -0.00447297754172042,
#    'python': np.float64(-0.0044729775417204805)},
#   468: {'matlab': -0.0006992792343777469,
#    'python': np.float64(-0.0006992792343777554)},
#   469: {'matlab': -0.025505073014196186,
#    'python': np.float64(-0.02550507301419614)},
#   470: {'matlab': 3.756899557047508, 'python': np.float64(3.756899557047506)},
#   471: {'matlab': -0.016432409509994556,
#    'python': np.float64(-0.016432409509994483)},
#   472: {'matlab': -0.0070561621288521195,
#    'python': np.float64(-0.007056162128852132)},
#   473: {'matlab': 0.01944938388573693,
#    'python': np.float64(0.019449383885736932)},
#   474: {'matlab': 0.04005750527467854,
#    'python': np.float64(0.04005750527467854)},
#   475: {'matlab': 0.05653547090076727,
#    'python': np.float64(0.05653547090076712)},
#   476: {'matlab': -0.016486437399302032,
#    'python': np.float64(-0.01648643739930199)},
#   477: {'matlab': 0.03700231908365814,
#    'python': np.float64(0.03700231908365815)},
#   478: {'matlab': 0.01001618679532789,
#    'python': np.float64(0.010016186795327838)},
#   479: {'matlab': -0.005585708730439775,
#    'python': np.float64(-0.005585708730439766)},
#   480: {'matlab': 0.1401280771007664,
#    'python': np.float64(0.14012807710076683)},
#   481: {'matlab': 0.038431874621795384,
#    'python': np.float64(0.03843187462179539)},
#   482: {'matlab': 0.10210476844464407,
#    'python': np.float64(0.10210476844464411)},
#   483: {'matlab': 0.004544380730209815,
#    'python': np.float64(0.004544380730209891)},
#   484: {'matlab': 0.16675466450013718,
#    'python': np.float64(0.16675466450013765)},
#   485: {'matlab': 0.1786214241249747,
#    'python': np.float64(0.1786214241249749)},
#   486: {'matlab': 1.5236643663632008,
#    'python': np.float64(1.5236643663632032)},
#   487: {'matlab': -0.12504345947249831,
#    'python': np.float64(-0.1250434594724986)},
#   488: {'matlab': 0.38206699410453115,
#    'python': np.float64(0.3820669941045312)},
#   489: {'matlab': -13431.81473721198,
#    'python': np.float64(-13431.814737212033)},
#   490: {'matlab': -13425.104068941882,
#    'python': np.float64(-13425.10406894194)},
#   491: {'matlab': 0.001317500786043288,
#    'python': np.float64(0.0013175007860432777)},
#   492: {'matlab': -0.06387808508293231,
#    'python': np.float64(-0.06387808508293226)},
#   493: {'matlab': -13426.354220839936,
#    'python': np.float64(-13426.354220839998)},
#   494: {'matlab': -13411.39667005023,
#    'python': np.float64(-13411.396670050211)},
#   495: {'matlab': 0.014263914186823589,
#    'python': np.float64(0.014263914186823592)},
#   496: {'matlab': -0.07020841763774394,
#    'python': np.float64(-0.07020841763774391)},
#   497: {'matlab': -0.08326210832735116,
#    'python': np.float64(-0.08326210832735115)},
#   498: {'matlab': -1.3204211079160222,
#    'python': np.float64(-1.3204211079160222)},
#   499: {'matlab': -1.2924923930156789,
#    'python': np.float64(-1.29249239301568)},
#   500: {'matlab': -1.2180835531542564,
#    'python': np.float64(-1.2180835531542575)},
#   501: {'matlab': -1.2894206131064292,
#    'python': np.float64(-1.2894206131064283)},
#   502: {'matlab': -1.4867361553262268,
#    'python': np.float64(-1.486736155326226)},
#   503: {'matlab': -1.4895607902395005,
#    'python': np.float64(-1.4895607902395018)},
#   504: {'matlab': -1.1252725976457338,
#    'python': np.float64(-1.1252725976457343)},
#   505: {'matlab': -1.3051346864423692,
#    'python': np.float64(-1.3051346864423692)},
#   506: {'matlab': -1.3106603099025427,
#    'python': np.float64(-1.310660309902544)},
#   507: {'matlab': 0.0259293835648419,
#    'python': np.float64(0.025929383564841934)},
#   508: {'matlab': -0.025186222052458934,
#    'python': np.float64(-0.025186222052458934)},
#   509: {'matlab': -0.20815475245034085,
#    'python': np.float64(-0.20815475245034093)},
#   510: {'matlab': 0.1362820827435479,
#    'python': np.float64(0.1362820827435479)},
#   511: {'matlab': -0.02174395500089569,
#    'python': np.float64(-0.021743955000895713)},
#   512: {'matlab': -0.0942073405365614,
#    'python': np.float64(-0.09420734053656178)},
#   513: {'matlab': -0.029496107267377447,
#    'python': np.float64(-0.02949610726737744)},
#   514: {'matlab': -0.006466452533845587,
#    'python': np.float64(-0.006466452533845593)},
#   515: {'matlab': 0.5230402156089876,
#    'python': np.float64(0.5230402156089877)},
#   516: {'matlab': 0.8732939480722396,
#    'python': np.float64(0.8732939480722399)},
#   517: {'matlab': -2.955529620866606,
#    'python': np.float64(-2.955529620866605)},
#   518: {'matlab': -1.8523819415411886,
#    'python': np.float64(-1.8523819415411884)},
#   519: {'matlab': -5.47190337206427, 'python': np.float64(-5.471903372064271)},
#   520: {'matlab': -1.4110907048725505,
#    'python': np.float64(-1.4110907048725512)},
#   521: {'matlab': 0.42977389272841343,
#    'python': np.float64(0.42977389272841326)},
#   522: {'matlab': -2.280497201336491,
#    'python': np.float64(-2.280497201336493)},
#   523: {'matlab': 0.1296930729381675,
#    'python': np.float64(0.1296930729381674)},
#   524: {'matlab': -0.05393948622112876,
#    'python': np.float64(-0.05393948622112875)},
#   525: {'matlab': -0.06193207078526933,
#    'python': np.float64(-0.06193207078526929)},
#   526: {'matlab': -0.06050651991219398,
#    'python': np.float64(-0.06050651991219398)},
#   527: {'matlab': -0.05977960007883595,
#    'python': np.float64(-0.05977960007883593)},
#   528: {'matlab': -0.03536915319149438,
#    'python': np.float64(-0.03536915319149436)},
#   529: {'matlab': -0.03926784934756127,
#    'python': np.float64(-0.03926784934756126)},
#   530: {'matlab': -0.05729416489600499,
#    'python': np.float64(-0.05729416489600497)},
#   531: {'matlab': 0.6737774291844696,
#    'python': np.float64(0.6737774291844694)},
#   532: {'matlab': 0.6768904906313334,
#    'python': np.float64(0.6768904906313332)},
#   533: {'matlab': -0.31188517622014095,
#    'python': np.float64(-0.311885176220141)},
#   534: {'matlab': -0.012779181623718668,
#    'python': np.float64(-0.012779181623718676)},
#   535: {'matlab': 0.6584200835771101,
#    'python': np.float64(0.6584200835771107)},
#   536: {'matlab': -0.00786424713502765,
#    'python': np.float64(-0.00786424713502766)},
#   537: {'matlab': -0.005156389961761024,
#    'python': np.float64(-0.005156389961761034)},
#   538: {'matlab': 2.9158865913874217,
#    'python': np.float64(2.9158865913874195)},
#   539: {'matlab': 3.8197155777977994,
#    'python': np.float64(3.8197155777977994)},
#   540: {'matlab': -6.444144466085703,
#    'python': np.float64(-6.444144466085708)},
#   541: {'matlab': 3.5499707078505267,
#    'python': np.float64(3.5499707078505276)},
#   542: {'matlab': 3.545812503006885, 'python': np.float64(3.545812503006887)},
#   543: {'matlab': 3.683654087522352, 'python': np.float64(3.6836540875223514)},
#   544: {'matlab': 2.9157706528421494,
#    'python': np.float64(2.9157706528421525)},
#   545: {'matlab': -0.022045933011147878,
#    'python': np.float64(-0.022045933011147892)},
#   546: {'matlab': -0.06068258230165915,
#    'python': np.float64(-0.06068258230165941)},
#   547: {'matlab': 4.3404117036377565, 'python': np.float64(4.340411703637758)},
#   548: {'matlab': 4.312606346237881, 'python': np.float64(4.312606346237881)},
#   549: {'matlab': 4.358901470253348, 'python': np.float64(4.358901470253346)},
#   550: {'matlab': 4.384228560225238, 'python': np.float64(4.384228560225236)},
#   551: {'matlab': -0.08840337802543552,
#    'python': np.float64(-0.08840337802543552)},
#   552: {'matlab': -0.09028249256025349,
#    'python': np.float64(-0.09028249256025365)},
#   553: {'matlab': 0.008232589542255293,
#    'python': np.float64(0.008232589542255307)},
#   554: {'matlab': 0.00636014187824189,
#    'python': np.float64(0.00636014187824189)},
#   555: {'matlab': 0.026787094467155693,
#    'python': np.float64(0.026787094467155662)},
#   556: {'matlab': 0.024438225903864554,
#    'python': np.float64(0.02443822590386453)},
#   557: {'matlab': 0.0118321323766517,
#    'python': np.float64(0.011832132376651705)},
#   558: {'matlab': 0.003913581419889042,
#    'python': np.float64(0.0039135814198890465)},
#   559: {'matlab': 0.032893946912692595,
# ...
#   815: {'matlab': -0.0434782608695651,
#    'python': np.float64(-0.0434782608695651)},
#   816: {'matlab': -0.2173913043478264,
#    'python': np.float64(-0.2173913043478264)},
#   817: {'matlab': 0.4242424242424241,
#    'python': np.float64(0.4242424242424241)},
#   818: {'matlab': 0.0, 'python': np.float64(0.0)},
#   819: {'matlab': 0.2043010752688173,
#    'python': np.float64(0.2043010752688173)},
#   820: {'matlab': -0.09090909090909083,
#    'python': np.float64(-0.09090909090909083)},
#   821: {'matlab': 0.05882352941176479,
#    'python': np.float64(0.05882352941176479)},
#   822: {'matlab': 0.04714640198511139,
#    'python': np.float64(0.04714640198511139)},
#   823: {'matlab': -0.031431226170260854,
#    'python': np.float64(-0.031431226170260854)},
#   824: {'matlab': 0.027138661118590465,
#    'python': np.float64(0.027138661118590465)},
#   825: {'matlab': -0.08014293006636039,
#    'python': np.float64(-0.08014293006636039)},
#   826: {'matlab': -0.20805369127518042,
#    'python': np.float64(-0.20805369127518042)},
#   827: {'matlab': -0.7251732101616635,
#    'python': np.float64(-0.7251732101616635)},
#   828: {'matlab': -0.2005870807375468,
#    'python': np.float64(-0.2005870807375468)},
#   829: {'matlab': 0.16216216216216223,
#    'python': np.float64(0.16216216216216223)},
#   830: {'matlab': -0.11239928731050311,
#    'python': np.float64(-0.11239928731050311)},
#   831: {'matlab': -0.5834356636314582,
#    'python': np.float64(-0.5834356636314582)},
#   832: {'matlab': -0.5929278642149935,
#    'python': np.float64(-0.5929278642149935)},
#   833: {'matlab': 0.2146193261687752,
#    'python': np.float64(0.2146193261687752)},
#   834: {'matlab': 0.0016200111021740058,
#    'python': np.float64(0.0016200111021740058)},
#   835: {'matlab': 0.17950790344776285,
#    'python': np.float64(0.17950790344776285)},
#   836: {'matlab': -0.10416642447774369,
#    'python': np.float64(-0.10416642447774377)},
#   837: {'matlab': -1.8336588374801453e-17,
#    'python': np.float64(-1.8336588374801453e-17)},
#   838: {'matlab': 0.14285714285714302,
#    'python': np.float64(0.14285714285714302)},
#   839: {'matlab': 0.4285714285714288,
#    'python': np.float64(0.4285714285714288)},
#   840: {'matlab': 0.3333333333333332,
#    'python': np.float64(0.3333333333333332)},
#   841: {'matlab': 0.3333333333333334,
#    'python': np.float64(0.3333333333333334)},
#   842: {'matlab': 0.05263157894736832,
#    'python': np.float64(0.05263157894736832)},
#   843: {'matlab': 0.5384615384615383,
#    'python': np.float64(0.5384615384615383)},
#   844: {'matlab': -0.03703703703703717,
#    'python': np.float64(-0.03703703703703717)},
#   845: {'matlab': -0.04314912944738835,
#    'python': np.float64(-0.04314912944738835)},
#   846: {'matlab': 0.11214953271028043,
#    'python': np.float64(0.11214953271028043)},
#   847: {'matlab': 0.2631578947368421,
#    'python': np.float64(0.2631578947368421)},
#   848: {'matlab': 0.20388349514563106,
#    'python': np.float64(0.20388349514563106)},
#   849: {'matlab': 0.1588785046728971,
#    'python': np.float64(0.1588785046728971)},
#   850: {'matlab': 0.27272727272727276,
#    'python': np.float64(0.27272727272727276)},
#   851: {'matlab': 0.2698412698412698,
#    'python': np.float64(0.2698412698412698)},
#   852: {'matlab': 0.12328767123287675,
#    'python': np.float64(0.12328767123287675)},
#   853: {'matlab': 0.2112676056338028,
#    'python': np.float64(0.2112676056338028)},
#   854: {'matlab': 0.2156862745098039,
#    'python': np.float64(0.2156862745098039)},
#   855: {'matlab': 0.1058823529411764,
#    'python': np.float64(0.1058823529411764)},
#   856: {'matlab': 0.23076923076923084,
#    'python': np.float64(0.23076923076923084)},
#   857: {'matlab': 0.23809523809523822,
#    'python': np.float64(0.23809523809523822)},
#   858: {'matlab': 0.058823529411764726,
#    'python': np.float64(0.058823529411764726)},
#   859: {'matlab': 0.05263157894736843,
#    'python': np.float64(0.05263157894736843)},
#   860: {'matlab': 0.23404255319148937,
#    'python': np.float64(0.23404255319148937)},
#   861: {'matlab': 0.11627906976744203,
#    'python': np.float64(0.11627906976744191)},
#   862: {'matlab': 0.3333333333333334,
#    'python': np.float64(0.3333333333333334)},
#   863: {'matlab': 0.2307692307692307,
#    'python': np.float64(0.2307692307692307)},
#   864: {'matlab': 0.11111111111111104,
#    'python': np.float64(0.11111111111111104)},
#   865: {'matlab': -0.02701181767023074,
#    'python': np.float64(-0.02701181767023074)},
#   866: {'matlab': 0.09875000000000002,
#    'python': np.float64(0.09875000000000002)},
#   867: {'matlab': 0.12377210216110049,
#    'python': np.float64(0.12377210216110049)},
#   868: {'matlab': 0.10350727117194185,
#    'python': np.float64(0.10350727117194185)},
#   869: {'matlab': 0.06803594351732996,
#    'python': np.float64(0.06803594351732996)},
#   870: {'matlab': -0.15999999999999992,
#    'python': np.float64(-0.15999999999999992)},
#   871: {'matlab': -0.0714285714285714,
#    'python': np.float64(-0.0714285714285714)},
#   872: {'matlab': -0.05454545454545463,
#    'python': np.float64(-0.05454545454545463)},
#   873: {'matlab': -0.14285714285714288,
#    'python': np.float64(-0.14285714285714288)},
#   874: {'matlab': -0.08794788273615634,
#    'python': np.float64(-0.08794788273615634)},
#   875: {'matlab': -0.08843537414965992,
#    'python': np.float64(-0.08843537414965992)},
#   876: {'matlab': -0.09929078014184393,
#    'python': np.float64(-0.09929078014184393)},
#   877: {'matlab': 0.03820218090811582,
#    'python': np.float64(0.03820218090811582)},
#   878: {'matlab': 0.006790510295434126,
#    'python': np.float64(0.006790510295434126)},
#   879: {'matlab': 0.39340459604158495,
#    'python': np.float64(0.39340459604158495)},
#   880: {'matlab': -0.09324095802138037,
#    'python': np.float64(-0.09324095802138037)},
#   881: {'matlab': -0.03453841757304334,
#    'python': np.float64(-0.03453841757304334)},
#   882: {'matlab': 0.45006743065016985,
#    'python': np.float64(0.45006743065016985)},
#   883: {'matlab': -0.26021185933088053,
#    'python': np.float64(-0.26021185933088053)},
#   884: {'matlab': 0.013928013055748418,
#    'python': np.float64(0.013928013055748418)},
#   885: {'matlab': 0.01287979704562221,
#    'python': np.float64(0.01287979704562221)},
#   886: {'matlab': -0.355553831833696,
#    'python': np.float64(-0.355553831833696)},
#   887: {'matlab': -0.14649681528662437,
#    'python': np.float64(-0.14649681528662437)},
#   888: {'matlab': 0.06010928961748635,
#    'python': np.float64(0.06010928961748635)},
#   889: {'matlab': -0.07216494845360819,
#    'python': np.float64(-0.07216494845360819)},
#   890: {'matlab': 0.07692307692307691,
#    'python': np.float64(0.07692307692307691)},
#   891: {'matlab': 0.05154639175257732,
#    'python': np.float64(0.05154639175257732)},
#   892: {'matlab': -0.10447761194029853,
#    'python': np.float64(-0.10447761194029853)},
#   893: {'matlab': 0.17365269461077842,
#    'python': np.float64(0.17365269461077842)},
#   894: {'matlab': -0.16504854368932043,
#    'python': np.float64(-0.16504854368932043)},
#   895: {'matlab': -0.19047619047619038,
#    'python': np.float64(-0.19047619047619038)},
#   896: {'matlab': -0.047619047619047665,
#    'python': np.float64(-0.047619047619047665)},
#   897: {'matlab': -0.23076923076923075,
#    'python': np.float64(-0.23076923076923075)},
#   898: {'matlab': 0.06666666666666671,
#    'python': np.float64(0.06666666666666671)},
#   899: {'matlab': -3.377636898056569e-17,
#    'python': np.float64(-3.377636898056569e-17)},
#   900: {'matlab': -0.27272727272727265,
#    'python': np.float64(-0.27272727272727265)},
#   901: {'matlab': -0.02040816326530614,
#    'python': np.float64(-0.02040816326530614)},
#   902: {'matlab': -0.2173913043478261,
#    'python': np.float64(-0.2173913043478261)},
#   903: {'matlab': 0.0923694779116468,
#    'python': np.float64(0.0923694779116468)},
#   904: {'matlab': -0.4077960104922833,
#    'python': np.float64(-0.4077960104922833)},
#   905: {'matlab': -0.4218146718146717,
#    'python': np.float64(-0.4218146718146717)},
#   906: {'matlab': -0.5586887557278817,
#    'python': np.float64(-0.5586887557278817)},
#   907: {'matlab': -0.28371482723429076,
#    'python': np.float64(-0.28371482723429076)},
#   908: {'matlab': -0.448395217117684,
#    'python': np.float64(-0.448395217117684)},
#   909: {'matlab': 0.03070024146257274,
#    'python': np.float64(0.03070024146257274)},
#   910: {'matlab': 0.12442396313365749,
#    'python': np.float64(0.12442396313365749)},
#   911: {'matlab': -0.05735003295978749,
#    'python': np.float64(-0.05735003295978749)},
#   912: {'matlab': 0.2944369063771991,
#    'python': np.float64(0.2944369063771991)},
#   913: {'matlab': 0.2861788617886174,
#    'python': np.float64(0.2861788617886174)},
#   914: {'matlab': 0.22789115646259062,
#    'python': np.float64(0.22789115646259062)},
#   915: {'matlab': 0.13525498891352167,
#    'python': np.float64(0.13525498891352167)},
#   916: {'matlab': 0.18324607329842674,
#    'python': np.float64(0.18324607329842674)},
#   917: {'matlab': -0.14891611687088022,
#    'python': np.float64(-0.14891611687088022)},
#   918: {'matlab': 0.018918918918915086,
#    'python': np.float64(0.018918918918915086)},
#   919: {'matlab': -0.18678160919541403,
#    'python': np.float64(-0.18678160919541403)},
#   920: {'matlab': 0.3367990063026183,
#    'python': np.float64(0.3367990063026183)},
#   921: {'matlab': 0.19193427931292412,
#    'python': np.float64(0.19193427931292412)},
#   922: {'matlab': -0.15605493133583043,
#    'python': np.float64(-0.15605493133583043)},
#   923: {'matlab': -0.03225806451612897,
#    'python': np.float64(-0.03225806451612897)},
#   924: {'matlab': 0.04347826086956507,
#    'python': np.float64(0.04347826086956507)},
#   925: {'matlab': -0.24999999999999994,
#    'python': np.float64(-0.24999999999999994)},
#   926: {'matlab': -0.025806451612903188,
#    'python': np.float64(-0.025806451612903188)},
#   927: {'matlab': -0.14285714285714288,
#    'python': np.float64(-0.14285714285714288)},
#   928: {'matlab': 0.1428571428571429,
#    'python': np.float64(0.1428571428571429)},
#   929: {'matlab': 6.060965404055728e-17,
#    'python': np.float64(6.060965404055728e-17)},
#   930: {'matlab': 1.6213182677217255e-16,
#    'python': np.float64(1.6213182677217255e-16)},
#   931: {'matlab': 0.1000000000000002,
#    'python': np.float64(0.1000000000000002)},
#   932: {'matlab': -7.095761649221652e-17,
#    'python': np.float64(-7.095761649221652e-17)},
#   933: {'matlab': 0.01366742596810925,
#    'python': np.float64(0.01366742596810925)},
#   934: {'matlab': 0.09090909090909087,
#    'python': np.float64(0.09090909090909087)},
#   935: {'matlab': 0.0047998978745134036,
#    'python': np.float64(0.0047998978745134036)},
#   936: {'matlab': 0.07427055702917829,
#    'python': np.float64(0.07427055702917829)},
#   937: {'matlab': 0.08123965694682675,
#    'python': np.float64(0.08123965694682675)},
#   938: {'matlab': 0.03147305689032901,
#    'python': np.float64(0.03147305689032909)},
#   939: {'matlab': -0.006415241057542707,
#    'python': np.float64(-0.006415241057542707)},
#   940: {'matlab': -0.002516580825413792,
#    'python': np.float64(-0.002516580825413792)},
#   941: {'matlab': -0.011537190545535982,
#    'python': np.float64(-0.011537190545535982)},
#   942: {'matlab': 0.09045793200347564,
#    'python': np.float64(0.09045793200347564)},
#   943: {'matlab': -0.004629589113026774,
#    'python': np.float64(-0.004629589113026701)},
#   944: {'matlab': 0.00045733124018838497,
#    'python': np.float64(0.00045733124018838497)},
#   945: {'matlab': 0.0010506040973559854,
#    'python': np.float64(0.0010506040973559854)},
#   946: {'matlab': 0.02415284875669449,
#    'python': np.float64(0.02415284875669449)},
#   947: {'matlab': -0.01612749113060542,
#    'python': np.float64(-0.01612749113060542)},
#   948: {'matlab': -0.05968533888016436,
#    'python': np.float64(-0.05968533888016436)},
#   949: {'matlab': 0.02437541584166353,
#    'python': np.float64(0.02437541584166353)},
#   950: {'matlab': -0.010210677985902753,
#    'python': np.float64(-0.010210677985902753)},
#   951: {'matlab': 0.048938166311300706,
#    'python': np.float64(0.048938166311300706)},
#   952: {'matlab': 0.08478315277628813,
#    'python': np.float64(0.08478315277628813)},
#   953: {'matlab': -0.0022523453320659275,
#    'python': np.float64(-0.0022523453320659275)},
#   954: {'matlab': 0.08401424680494445,
#    'python': np.float64(0.08401424680494445)},
#   955: {'matlab': 0.5254590392136437,
#    'python': np.float64(0.5254590392136437)},
#   956: {'matlab': -0.08571428571428572,
#    'python': np.float64(-0.08571428571428572)},
#   957: {'matlab': -0.26779661016949163,
#    'python': np.float64(-0.26779661016949163)},
#   958: {'matlab': -0.4138613861386138,
#    'python': np.float64(-0.4138613861386138)},
#   959: {'matlab': -0.11111111111111105,
#    'python': np.float64(-0.11111111111111105)},
#   960: {'matlab': 0.14285714285714288,
#    'python': np.float64(0.14285714285714288)},
#   961: {'matlab': 0.42857142857142855,
#    'python': np.float64(0.42857142857142855)},
#   962: {'matlab': 0.4482758620689656,
#    'python': np.float64(0.4482758620689656)},
#   963: {'matlab': 0.3333333333333334,
#    'python': np.float64(0.3333333333333334)},
#   964: {'matlab': 0.3333333333333332,
#    'python': np.float64(0.3333333333333332)},
#   965: {'matlab': 0.20000000000000004,
#    'python': np.float64(0.20000000000000004)},
#   966: {'matlab': 0.24999999999999986,
#    'python': np.float64(0.24999999999999986)},
#   967: {'matlab': -9.666664653561912e-17,
#    'python': np.float64(-9.666664653561912e-17)},
#   968: {'matlab': -0.125, 'python': np.float64(-0.125)},
#   969: {'matlab': 0.06666666666666671,
#    'python': np.float64(0.06666666666666671)},
#   970: {'matlab': -0.04761904761904766,
#    'python': np.float64(-0.04761904761904766)},
#   971: {'matlab': 0.22222222222222202,
#    'python': np.float64(0.22222222222222202)},
#   972: {'matlab': 0.04000000000000014,
#    'python': np.float64(0.04000000000000014)},
#   973: {'matlab': 0.30000000000000004,
#    'python': np.float64(0.30000000000000004)},
#   974: {'matlab': 0.13333333333333333,
#    'python': np.float64(0.13333333333333333)},
#   975: {'matlab': -0.1578947368421053,
#    'python': np.float64(-0.1578947368421053)},
#   976: {'matlab': 0.3333333333333332,
#    'python': np.float64(0.3333333333333332)},
#   977: {'matlab': 0.20000000000000007,
#    'python': np.float64(0.20000000000000007)},
#   978: {'matlab': 0.49999999999999994,
#    'python': np.float64(0.49999999999999994)},
#   979: {'matlab': 1.5611330186648327e-16,
#    'python': np.float64(1.5611330186648327e-16)},
#   980: {'matlab': 0.20000000000000104,
#    'python': np.float64(0.20000000000000104)},
#   981: {'matlab': 1.262054047622708e-15,
#    'python': np.float64(1.262054047622708e-15)},
#   982: {'matlab': 0.002132196162046702,
#    'python': np.float64(0.002132196162046702)},
#   983: {'matlab': -0.09069767441860484,
#    'python': np.float64(-0.09069767441860484)},
#   984: {'matlab': -0.001599999999999858,
#    'python': np.float64(-0.001599999999999858)},
#   985: {'matlab': -0.20204603580562985,
#    'python': np.float64(-0.20204603580562985)},
#   986: {'matlab': -0.19999999999999768,
#    'python': np.float64(-0.19999999999999768)},
#   987: {'matlab': 2.618472041799089e-17,
#    'python': np.float64(2.618472041799089e-17)},
#   988: {'matlab': -0.19948849104859115,
#    'python': np.float64(-0.19948849104859115)},
#   989: {'matlab': -0.25000000000000305,
#    'python': np.float64(-0.25000000000000305)},
#   990: {'matlab': 0.1407678244972586,
#    'python': np.float64(0.1407678244972586)},
#   991: {'matlab': -0.07586206896551656,
#    'python': np.float64(-0.07586206896551656)},
#   992: {'matlab': 5.423818029799135e-17,
#    'python': np.float64(5.423818029799135e-17)},
#   993: {'matlab': -0.14285714285714343,
#    'python': np.float64(-0.14285714285714343)},
#   994: {'matlab': -0.10953058321479744,
#    'python': np.float64(-0.10953058321479744)},
#   995: {'matlab': -0.34153846153846157,
#    'python': np.float64(-0.34153846153846157)},
#   996: {'matlab': 0.16831683168316836,
#    'python': np.float64(0.16831683168316836)},
#   997: {'matlab': 0.5661375661375663,
#    'python': np.float64(0.5661375661375663)},
#   998: {'matlab': -0.33333333333333326,
#    'python': np.float64(-0.33333333333333326)},
#   999: {'matlab': -1.0, 'python': np.float64(-1.0)}}}

# %%
customSkew_evals = eval_comparison("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
customSkew_compares = compare_outputs(customSkew_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_CustomSkewness_pearson_raw with params {'whatSkew': 'pearson'} (Z-score=False)
# Adding operation Distributional_CustomSkewness_bowley with params {'whatSkew': 'bowley'} (Z-score=True)
# Evalutating Distributional_CustomSkewness_pearson_raw
# Comparing to DN_CustomSkewness
# Evalutating Distributional_CustomSkewness_bowley
# Comparing to DN_CustomSkewness
# /Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Operations/Distributional.py:30: RuntimeWarning: invalid value encountered in scalar divide
# [Distributional_CustomSkewness_pearson_raw | ts=0]  RelErr% = 0.00
# [Distributional_CustomSkewness_pearson_raw | ts
  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=798]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=799]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=800]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=801]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=802]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=803]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=804]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=805]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=806]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=807]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=808]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=809]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=810]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=811]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=812]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=813]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=814]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=815]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=816]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=817]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=818]  RelErr% = nan
# [Distributional_CustomSkewness_bowley | ts=819]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=820]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=821]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=822]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=823]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=824]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=825]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=826]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=827]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=828]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=829]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=830]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=831]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=832]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=833]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=834]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=835]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=836]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=837]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=838]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=839]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=840]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=841]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=842]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=843]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=844]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=845]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=846]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=847]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=848]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=849]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=850]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=851]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=852]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=853]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=854]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=855]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=856]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=857]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=858]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=859]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=860]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=861]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=862]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=863]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=864]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=865]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=866]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=867]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=868]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=869]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=870]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=871]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=872]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=873]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=874]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=875]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=876]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=877]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=878]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=879]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=880]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=881]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=882]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=883]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=884]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=885]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=886]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=887]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=888]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=889]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=890]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=891]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=892]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=893]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=894]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=895]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=896]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=897]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=898]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=899]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=900]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=901]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=902]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=903]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=904]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=905]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=906]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=907]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=908]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=909]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=910]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=911]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=912]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=913]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=914]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=915]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=916]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=917]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=918]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=919]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=920]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=921]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=922]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=923]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=924]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=925]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=926]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=927]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=928]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=929]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=930]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=931]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=932]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=933]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=934]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=935]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=936]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=937]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=938]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=939]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=940]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=941]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=942]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=943]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=944]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=945]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=946]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=947]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=948]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=949]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=950]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=951]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=952]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=953]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=954]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=955]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=956]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=957]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=958]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=959]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=960]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=961]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=962]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=963]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=964]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=965]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=966]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=967]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=968]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=969]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=970]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=971]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=972]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=973]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=974]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=975]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=976]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=977]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=978]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=979]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=980]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=981]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=982]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=983]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=984]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=985]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=986]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=987]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=988]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=989]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=990]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=991]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=992]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=993]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=994]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=995]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=996]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=997]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=998]  RelErr% = 0.00
# [Distributional_CustomSkewness_bowley | ts=999]  RelErr% = 0.00

# %%
def eval_comparisoncv(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i])
            matlab_eval = matlab_func(ZScore(matlab.double(x)), matlab.double(ordered_args[0])) if isZscore else matlab_func(matlab.double(x), matlab.double(ordered_args[0]))
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
cv_evals = eval_comparisoncv("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
cv_compares = compare_outputs(cv_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_CV_1_raw with params {'k': 1} (Z-score=False)
# Adding operation Distributional_CV_2_raw with params {'k': 2} (Z-score=False)
# Evalutating Distributional_CV_1_raw
# Comparing to DN_cv
# Evalutating Distributional_CV_2_raw
# Comparing to DN_cv
# [Distributional_CV_1_raw | ts=0]  RelErr% = 0.00
# [Distributional_CV_1_raw | ts=1]  RelErr% = 0.00
# [Distributional_CV_1_raw | ts=2]  RelErr% = 0.00
# [Distributional_CV_1_raw | ts
  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=878]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=879]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=880]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=881]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=882]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=883]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=884]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=885]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=886]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=887]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=888]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=889]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=890]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=891]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=892]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=893]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=894]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=895]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=896]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=897]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=898]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=899]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=900]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=901]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=902]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=903]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=904]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=905]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=906]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=907]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=908]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=909]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=910]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=911]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=912]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=913]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=914]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=915]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=916]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=917]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=918]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=919]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=920]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=921]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=922]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=923]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=924]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=925]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=926]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=927]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=928]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=929]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=930]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=931]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=932]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=933]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=934]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=935]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=936]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=937]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=938]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=939]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=940]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=941]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=942]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=943]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=944]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=945]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=946]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=947]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=948]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=949]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=950]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=951]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=952]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=953]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=954]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=955]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=956]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=957]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=958]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=959]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=960]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=961]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=962]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=963]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=964]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=965]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=966]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=967]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=968]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=969]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=970]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=971]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=972]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=973]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=974]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=975]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=976]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=977]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=978]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=979]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=980]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=981]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=982]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=983]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=984]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=985]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=986]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=987]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=988]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=989]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=990]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=991]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=992]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=993]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=994]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=995]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=996]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=997]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=998]  RelErr% = 0.00
# [Distributional_CV_2_raw | ts=999]  RelErr% = 0.00

# %%
cv_compares
# Out:
# {'Distributional_CV_1_raw': {'r': np.float64(1.0),
#   'pval': np.float64(0.0),
#   'res_py': array([ 7.77435431e-01,  4.09045447e-01,  3.06373071e-01,  4.36071746e-01,
#           3.41035255e-01,  2.25436361e-01,  1.34062846e+00,  1.16784553e+00,
#           9.14754650e-01,  5.23410134e-02,  6.17012080e-01, -2.16894836e+00,
#           1.06309175e+00,  2.10034898e+00,  1.30535471e+00,  2.13736424e-01,
#           2.16424711e-01,  2.44092001e+01,  1.41287725e-01, -8.69924738e+01,
#           2.19278066e-02,  5.41908725e-01,  5.50902045e-01,  2.63914589e-01,
#           3.43399540e+00,  3.71408579e-01,  7.12703622e-01, -2.08908337e+00,
#          -2.35322997e+00,  6.60386560e-01,  3.70440055e-01,  1.64005616e-01,
#           9.03684748e-01,  9.92144859e-01,  4.47421041e-01,  7.61480468e-01,
#           8.99539922e-01,  1.27227806e+00,  3.02168275e-01, -8.57528629e-01,
#           8.82157641e-01,  3.09386435e+00,  2.40418582e+00,  3.13458782e+02,
#          -9.60717401e+02,  1.42258732e+03, -5.32577492e+00, -3.86467274e+00,
#           3.16235749e+01,  8.26461663e-01,  6.36014691e-01,  6.84461392e-01,
#          -1.51348965e+01,  4.76317004e-01, -1.85559179e+00, -4.08211534e+00,
#          -7.69622757e-01, -2.95656077e+02,  9.82552853e+01, -9.38848170e+01,
#           8.13529141e+01, -3.25589788e+01, -3.31982391e+02, -8.74812185e+02,
#          -3.85473379e+00,  8.32279625e+01,  1.65297891e+01,  9.01369532e+01,
#          -2.80707489e+02, -1.60401402e+02,  1.03165345e+00,  9.75754615e-01,
#           1.23241759e+01, -1.81080913e-01, -7.18737086e+00,  7.54939490e-01,
#           3.61040267e+01, -4.29984660e+01,  3.43256359e+01,  4.21831059e+01,
#          -4.53831120e+02, -2.28471052e+01, -5.20541769e+02,  4.20779498e+01,
#          -8.26034139e+00,  3.17839023e+03,  9.38706585e+02,  3.68969367e+02,
#          3.80383449e-01, 2.52330524e-01, 4.60431277e-01, 4.63938999e-01,
#          4.84798872e-01, 2.64019817e+00, 3.75124030e-01, 4.08487338e-03,
#          6.09371807e-01, 6.47489167e-01, 7.29424481e-01, 8.15000287e-01,
#          7.26826353e-01, 1.19101737e-03, 4.62624704e-05, 1.10710045e-03,
#          4.34097425e-04, 2.30681851e-04, 1.77297484e-04, 4.47259238e-04,
#          1.37688837e-04, 2.68877410e-04, 1.15993600e-03, 6.31207443e-05,
#          9.78858672e-03, 2.06916427e-04, 2.50113572e-04, 1.86301487e+01,
#          7.79739914e+00, 1.24746828e+01, 3.05177187e+03, 1.45788912e+01,
#          8.78958925e+00, 1.09478275e+01, 8.11707026e+01, 9.84852151e+00,
#          1.09393642e+01, 1.56914336e+03, 1.25294657e+01, 1.75980444e+00,
#          5.56446869e-03, 1.15264621e+04, 5.90764505e+05, 1.70003020e+06,
#          1.11032439e+06, 8.19754998e+03, 5.38941908e+03, 2.27051930e+05,
#          7.44316841e+04, 4.90205836e+07, 8.56932499e+04, 1.55548351e+04,
#          8.39933214e+04, 1.38396333e+05, 1.77584557e+06, 9.04251035e+02,
#          1.15623039e+10, 2.38599779e+06, 1.53690327e+06, 2.25831005e+06,
#          9.41947957e-02, 1.10429829e+01, 1.64872033e+00, 1.64100567e+02,
#          3.38912409e+01, 5.77021924e+01, 5.38067250e+01, 2.79477998e+01,
#          5.90765715e+01, 4.57926917e+02, 2.82457582e+01, 8.59235856e+01,
#          7.87443865e+01, 8.93967795e+01, 8.50310920e+01, 3.05749072e+01,
#          4.50015103e+01, 3.18570773e+01, 1.00116140e+02, 3.63964372e+01,
#          5.29235441e+01, 4.04721725e+01, 9.00211157e+01, 4.96118860e-03,
#          2.14719330e-03, 1.00524390e-02, 2.88271339e-03, 6.21449552e-03,
#          7.08053431e-03, 1.65588264e-03, 1.78400366e-03, 4.35216159e-03,
#          6.23864783e-03, 5.12488192e-03, 3.18857178e-03, 1.22670663e-02,
#          2.49773755e-03, 3.05405885e-03, 4.12365580e-03, 7.12972786e-01,
#          1.62098482e+01, 3.06257176e-01, 1.45834617e-06, 1.35253508e-07]),
#   'max_rel_err': np.float64(1.9737292042030085e-07)}}

# %%
[cv_compares[p]['r'] for p in cv_compares]
# Out:
# [np.float64(1.0), np.float64(1.0)]

# %%
eng.DN_cv(matlab.double(empirical1000[181]), matlab.double(1))
# Out:
# inf

# %%
from Distributional import CV, FitMLE

# %%
def eval_comparison_fitmle(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i])
            matlab_eval = matlab_func(ZScore(matlab.double(x)), ordered_args[0]) if isZscore else matlab_func(matlab.double(x), ordered_args[0])
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
fitmle_evals = eval_comparison_fitmle("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
fitmle_compares = compare_outputs(fitmle_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_FitMLE_geometric_raw with params {'fitWhat': 'geometric'} (Z-score=False)
# Evalutating Distributional_FitMLE_geometric_raw
# Comparing to DN_Fit_mle
# [Distributional_FitMLE_geometric_raw | ts=0]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=1]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=2]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=3]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=4]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=5]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=6]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=7]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=8]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=9]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=10]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=11]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=12]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=13]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=14]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=15]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=16]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=17]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=18]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=19]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=20]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=21]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=22]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=23]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=24]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=25]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=26]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=27]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=28]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=29]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=30]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=31]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=32]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=33]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=34]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=35]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=36]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=37]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=38]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=39]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=40]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=41]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=42]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=43]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=44]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=45]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=46]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=47]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=48]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=49]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=50]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=51]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=52]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=53]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=54]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=55]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=56]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=57]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=58]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=59]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=60]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=61]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=62]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=63]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=64]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=65]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=66]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=67]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=68]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=69]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=70]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=71]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=72]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=73]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=74]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=75]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=76]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=77]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=78]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=79]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=80]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=81]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=82]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=83]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=84]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=85]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=86]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=87]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=88]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=89]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=90]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=91]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=92]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=93]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=94]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=95]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=96]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=97]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=98]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=99]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=100]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=101]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=102]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=103]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=104]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=105]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=106]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=107]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=108]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=109]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=110]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=111]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=112]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=113]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=114]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=115]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=116]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=117]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=118]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=119]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=120]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=121]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=122]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=123]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=124]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=125]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=126]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=127]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=128]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=129]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=130]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=131]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=132]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=133]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=134]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=135]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=136]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=137]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=138]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=139]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=140]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=141]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=142]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=143]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=144]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=145]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=146]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=147]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=148]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=149]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=150]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=151]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=152]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=153]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=154]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=155]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=156]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=157]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=158]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=159]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=160]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=161]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=162]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=163]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=164]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=165]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=166]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=167]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=168]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=169]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=170]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=171]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=172]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=173]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=174]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=175]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=176]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=177]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=178]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=179]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=180]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=181]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=182]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=183]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=184]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=185]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=186]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=187]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=188]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=189]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=190]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=191]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=192]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=193]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=194]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=195]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=196]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=197]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=198]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=199]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=200]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=201]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=202]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=203]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=204]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=205]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=206]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=207]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=208]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=209]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=210]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=211]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=212]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=213]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=214]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=215]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=216]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=217]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=218]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=219]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=220]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=221]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=222]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=223]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=224]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=225]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=226]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=227]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=228]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=229]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=230]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=231]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=232]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=233]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=234]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=235]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=236]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=237]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=238]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=239]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=240]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=241]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=242]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=243]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=244]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=245]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=246]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=247]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=248]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=249]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=250]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=251]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=252]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=253]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=254]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=255]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=256]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=257]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=258]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=259]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=260]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=261]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=262]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=263]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=264]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=265]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=266]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=267]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=268]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=269]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=270]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=271]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=272]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=273]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=274]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=275]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=276]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=277]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=278]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=279]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=280]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=281]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=282]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=283]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=284]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=285]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=286]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=287]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=288]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=289]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=290]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=291]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=292]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=293]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=294]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=295]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=296]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=297]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=298]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=299]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=300]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=301]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=302]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=303]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=304]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=305]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=306]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=307]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=308]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts
  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=691]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=692]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=693]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=694]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=695]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=696]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=697]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=698]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=699]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=700]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=701]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=702]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=703]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=704]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=705]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=706]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=707]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=708]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=709]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=710]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=711]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=712]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=713]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=714]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=715]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=716]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=717]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=718]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=719]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=720]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=721]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=722]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=723]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=724]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=725]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=726]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=727]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=728]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=729]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=730]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=731]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=732]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=733]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=734]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=735]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=736]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=737]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=738]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=739]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=740]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=741]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=742]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=743]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=744]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=745]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=746]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=747]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=748]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=749]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=750]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=751]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=752]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=753]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=754]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=755]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=756]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=757]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=758]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=759]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=760]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=761]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=762]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=763]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=764]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=765]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=766]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=767]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=768]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=769]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=770]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=771]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=772]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=773]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=774]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=775]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=776]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=777]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=778]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=779]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=780]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=781]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=782]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=783]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=784]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=785]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=786]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=787]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=788]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=789]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=790]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=791]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=792]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=793]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=794]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=795]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=796]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=797]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=798]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=799]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=800]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=801]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=802]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=803]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=804]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=805]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=806]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=807]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=808]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=809]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=810]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=811]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=812]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=813]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=814]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=815]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=816]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=817]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=818]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=819]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=820]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=821]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=822]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=823]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=824]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=825]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=826]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=827]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=828]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=829]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=830]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=831]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=832]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=833]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=834]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=835]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=836]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=837]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=838]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=839]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=840]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=841]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=842]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=843]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=844]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=845]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=846]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=847]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=848]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=849]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=850]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=851]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=852]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=853]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=854]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=855]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=856]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=857]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=858]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=859]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=860]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=861]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=862]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=863]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=864]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=865]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=866]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=867]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=868]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=869]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=870]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=871]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=872]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=873]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=874]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=875]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=876]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=877]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=878]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=879]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=880]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=881]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=882]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=883]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=884]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=885]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=886]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=887]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=888]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=889]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=890]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=891]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=892]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=893]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=894]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=895]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=896]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=897]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=898]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=899]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=900]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=901]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=902]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=903]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=904]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=905]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=906]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=907]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=908]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=909]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=910]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=911]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=912]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=913]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=914]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=915]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=916]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=917]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=918]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=919]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=920]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=921]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=922]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=923]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=924]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=925]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=926]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=927]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=928]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=929]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=930]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=931]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=932]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=933]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=934]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=935]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=936]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=937]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=938]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=939]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=940]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=941]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=942]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=943]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=944]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=945]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=946]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=947]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=948]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=949]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=950]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=951]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=952]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=953]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=954]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=955]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=956]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=957]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=958]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=959]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=960]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=961]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=962]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=963]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=964]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=965]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=966]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=967]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=968]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=969]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=970]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=971]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=972]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=973]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=974]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=975]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=976]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=977]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=978]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=979]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=980]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=981]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=982]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=983]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=984]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=985]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=986]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=987]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=988]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=989]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=990]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=991]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=992]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=993]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=994]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=995]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=996]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=997]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=998]  RelErr% = 0.00
# [Distributional_FitMLE_geometric_raw | ts=999]  RelErr% = 0.00

# %%
CV(empirical1000[181], 1)
# Out:
# np.float64(1.2593256722066732e+18)

# %%
eng.DN_Fit_mle(matlab.double(ZScore(empirical1000[0])), 'gaussian')
# Out:
# {'mean': 4.902744876744691e-17, 'std': 0.9999499987499377}

# %%
FitMLE(ZScore(empirical1000[0]), 'gaussian')
# Out:
# {'mean': np.float64(2.2026824808563105e-17),
#  'std': np.float64(0.9999499987499374)}

# %%
def eval_comparison_hlm(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i])
            matlab_eval = matlab_func(ZScore(matlab.double(x)), *ordered_args) if isZscore else matlab_func(matlab.double(x), *ordered_args)
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
hlm_evals = eval_comparison_hlm("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
hlm_compares = compare_outputs(hlm_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_HighLowMu_raw with params {} (Z-score=False)
# Evalutating Distributional_HighLowMu_raw
# Comparing to DN_HighLowMu
# [Distributional_HighLowMu_raw | ts=0]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=1]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=2]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=3]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=4]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=5]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=6]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=7]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=8]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=9]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=10]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=11]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=12]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=13]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=14]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=15]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=16]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=17]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=18]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=19]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=20]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=21]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=22]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=23]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=24]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=25]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=26]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=27]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=28]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=29]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=30]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=31]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=32]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=33]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=34]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=35]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=36]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=37]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=38]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=39]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=40]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=41]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=42]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=43]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=44]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=45]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=46]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=47]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=48]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=49]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=50]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=51]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=52]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=53]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=54]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=55]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=56]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=57]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=58]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=59]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=60]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=61]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=62]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=63]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=64]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=65]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=66]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=67]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=68]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=69]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=70]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=71]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=72]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=73]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=74]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=75]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=76]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=77]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=78]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=79]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=80]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=81]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=82]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=83]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=84]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=85]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=86]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=87]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=88]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=89]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=90]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=91]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=92]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=93]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=94]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=95]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=96]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=97]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=98]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=99]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=100]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=101]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=102]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=103]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=104]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=105]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=106]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=107]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=108]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=109]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=110]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=111]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=112]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=113]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=114]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=115]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=116]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=117]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=118]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=119]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=120]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=121]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=122]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=123]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=124]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=125]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=126]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=127]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=128]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=129]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=130]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=131]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=132]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=133]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=134]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=135]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=136]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=137]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=138]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=139]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=140]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=141]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=142]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=143]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=144]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=145]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=146]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=147]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=148]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=149]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=150]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=151]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=152]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=153]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=154]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=155]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=156]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=157]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=158]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=159]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=160]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=161]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=162]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=163]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=164]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=165]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=166]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=167]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=168]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=169]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=170]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=171]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=172]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=173]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=174]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=175]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=176]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=177]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=178]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=179]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=180]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=181]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=182]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=183]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=184]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=185]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=186]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=187]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=188]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=189]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=190]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=191]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=192]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=193]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=194]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=195]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=196]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=197]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=198]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=199]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=200]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=201]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=202]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=203]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=204]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=205]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=206]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=207]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=208]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=209]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=210]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=211]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=212]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=213]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=214]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=215]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=216]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=217]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=218]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=219]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=220]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=221]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=222]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=223]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=224]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=225]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=226]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=227]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=228]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=229]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=230]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=231]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=232]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=233]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=234]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=235]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=236]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=237]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=238]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=239]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=240]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=241]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=242]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=243]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=244]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=245]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=246]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=247]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=248]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=249]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=250]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=251]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts
  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=998]  RelErr% = 0.00
# [Distributional_HighLowMu_raw | ts=999]  RelErr% = 0.00

# %%
def eval_comparison_ha(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i])
            matlab_eval = matlab_func(ZScore(matlab.double(x)), ordered_args[0], ordered_args[1]) if isZscore else matlab_func(matlab.double(x), ordered_args[0], ordered_args[1])
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
ha_evals = eval_comparison_ha("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
ha_compares = compare_outputs(ha_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_HistogramAsymmetry_11_False with params {'numBins': 11, 'doSimple': False} (Z-score=True)
# Evalutating Distributional_HistogramAsymmetry_11_False
# Comparing to DN_HistogramAsymmetry
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=0]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=1]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=2]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=3]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=4]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=5]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=6]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=7]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=8]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=9]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=10]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=11]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=12]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=13]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=14]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=15]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=16]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=17]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=18]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=19]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=20]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=21]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=22]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=23]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=24]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=25]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=26]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=27]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=28]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=29]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=30]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=31]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=32]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=33]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=34]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=35]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=36]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=37]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=38]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=39]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=40]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=41]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=42]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=43]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=44]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=45]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=46]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=47]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=48]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=49]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=50]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=51]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=52]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=53]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=54]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=55]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=56]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=57]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=58]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=59]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=60]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=61]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=62]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=63]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=64]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=65]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=66]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=67]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=68]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=69]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=70]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=71]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=72]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=73]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=74]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=75]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=76]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=77]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=78]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=79]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=80]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=81]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=82]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=83]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=84]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=85]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=86]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=87]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=88]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=89]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=90]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=91]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=92]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=93]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=94]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=95]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=96]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=97]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=98]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=99]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=100]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=101]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=102]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=103]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=104]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=105]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=106]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=107]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=108]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=109]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=110]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=111]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=112]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=113]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=114]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=115]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=116]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=117]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=118]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=119]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=120]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=121]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=122]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=123]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=124]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=125]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=126]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=127]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=128]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=129]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=130]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=131]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=132]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=133]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=134]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=135]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=136]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=137]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=138]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=139]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=140]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=141]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=142]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=143]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=144]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=145]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=146]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=147]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=148]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=149]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=150]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=151]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=152]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=153]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=154]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=155]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=156]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=157]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=158]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=159]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=160]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=161]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=162]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=163]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=164]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=165]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=166]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=167]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=168]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=169]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=170]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=171]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=172]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=173]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=174]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=175]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=176]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=177]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=178]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=179]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=180]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=181]  RelErr% = nan
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=182]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=183]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=184]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=185]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=186]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=187]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=188]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=189]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=190]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=191]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=192]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=193]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=194]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=195]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=196]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=197]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=198]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=199]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=200]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=201]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=202]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=203]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=204]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=205]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=206]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=207]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=208]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=209]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=210]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=211]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=212]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=213]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=214]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=215]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=216]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=217]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=218]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=219]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=220]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=221]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=222]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=223]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=224]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=225]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=226]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=227]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=228]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=229]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=230]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=231]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=232]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=233]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=234]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=235]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=236]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=237]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=238]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=239]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=240]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts=241]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.densityDiff | ts
  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=843]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=844]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=845]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=846]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=847]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=848]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=849]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=850]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=851]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=852]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=853]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=854]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=855]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=856]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=857]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=858]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=859]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=860]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=861]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=862]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=863]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=864]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=865]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=866]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=867]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=868]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=869]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=870]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=871]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=872]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=873]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=874]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=875]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=876]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=877]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=878]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=879]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=880]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=881]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=882]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=883]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=884]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=885]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=886]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=887]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=888]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=889]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=890]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=891]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=892]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=893]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=894]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=895]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=896]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=897]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=898]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=899]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=900]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=901]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=902]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=903]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=904]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=905]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=906]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=907]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=908]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=909]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=910]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=911]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=912]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=913]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=914]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=915]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=916]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=917]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=918]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=919]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=920]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=921]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=922]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=923]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=924]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=925]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=926]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=927]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=928]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=929]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=930]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=931]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=932]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=933]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=934]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=935]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=936]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=937]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=938]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=939]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=940]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=941]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=942]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=943]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=944]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=945]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=946]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=947]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=948]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=949]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=950]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=951]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=952]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=953]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=954]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=955]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=956]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=957]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=958]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=959]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=960]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=961]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=962]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=963]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=964]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=965]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=966]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=967]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=968]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=969]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=970]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=971]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=972]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=973]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=974]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=975]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=976]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=977]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=978]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=979]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=980]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=981]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=982]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=983]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=984]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=985]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=986]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=987]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=988]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=989]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=990]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=991]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=992]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=993]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=994]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=995]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=996]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=997]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=998]  RelErr% = 0.00
# [Distributional_HistogramAsymmetry_11_False.modeAsymmetry | ts=999]  RelErr% = 0.00

# %%
ha_compares
# Out:
# {'Distributional_HistogramAsymmetry_11_False.densityDiff': {'r': np.float64(1.0),
#   'pval': np.float64(0.0),
#   'res_py': array([-1.562e+03, -7.160e+02,  3.180e+02, -5.800e+01, -4.200e+01,
#           1.160e+02, -1.722e+03, -1.402e+03, -1.140e+03,  1.020e+02,
#          -4.220e+02,  7.100e+02, -3.042e+03, -6.720e+02, -3.500e+02,
#           4.740e+02,  2.394e+03, -8.000e+00,  2.260e+02,  8.000e+00,
#          -4.800e+01,  8.000e+01,  8.860e+02, -1.964e+03, -7.030e+03,
#          -1.606e+03, -1.986e+03,  5.172e+03,  5.662e+03, -2.400e+02,
#          -1.940e+02,  1.480e+02, -8.200e+01,  3.200e+01, -5.400e+01,
#          -3.080e+02, -2.410e+03, -1.870e+03,  9.400e+01, -4.260e+02,
#          -1.300e+03, -6.780e+02, -1.168e+03,  2.000e+01,  4.000e+00,
#           0.000e+00, -4.800e+01,  1.920e+02,  0.000e+00, -1.490e+03,
#           1.220e+02,  2.244e+03, -1.130e+03, -2.200e+02,  3.060e+02,
#          -4.300e+02, -7.220e+02, -9.820e+02, -6.000e+00, -1.800e+01,
#          -1.400e+01, -3.000e+01, -8.000e+00, -1.600e+01,  8.000e+00,
#           0.000e+00,  4.000e+00, -1.400e+01, -4.400e+01, -1.600e+01,
#          -1.200e+02, -1.552e+03,  1.420e+02, -3.960e+02, -9.600e+01,
#           2.400e+01,  2.240e+02, -8.800e+01,  2.360e+02,  6.000e+01,
#          -2.600e+01, -1.240e+02, -1.800e+01,  3.400e+01, -5.800e+01,
#          -2.000e+01, -4.000e+00,  1.800e+01, -5.200e+01,  4.000e+00,
#           1.834e+03,  6.660e+03,  3.940e+02, -8.540e+02,  3.760e+02,
#           3.800e+01, -3.600e+02, -1.280e+02,  9.000e+01,  5.460e+02,
#           1.312e+03,  4.220e+02,  5.960e+02,  1.660e+02,  4.480e+02,
#           1.562e+03, -3.620e+02, -2.034e+03,  1.500e+01,  2.220e+02,
#           1.110e+03,  4.320e+02,  1.540e+02,  2.520e+02, -2.000e+00,
#          -2.040e+02,  1.720e+02, -2.340e+02, -3.240e+02, -9.400e+01,
#           1.340e+02, -1.320e+02,  3.000e+01,  1.300e+02,  1.020e+02,
#          -1.680e+02, -9.800e+01,  2.160e+02, -1.220e+02,  1.560e+02,
#           8.760e+02, -1.360e+02,  7.200e+01, -1.260e+02,  1.240e+02,
#           4.560e+02, -2.440e+02,  5.360e+02, -7.400e+01, -1.800e+02,
#          -3.500e+01, -4.730e+02, -2.000e+02,  2.910e+02,  5.100e+01,
#          -6.200e+01,  3.400e+01, -2.270e+02,  1.890e+02, -8.200e+01,
#           2.980e+02, -1.870e+02,  2.090e+02,  6.900e+01, -7.000e+00,
#           4.000e+01, -8.700e+02,  7.740e+02,  1.822e+03,  1.246e+03,
#          -5.340e+02,  3.000e+01,  4.620e+02,  2.260e+02, -4.132e+03,
#          -1.188e+03, -1.010e+03, -7.060e+02, -7.680e+02, -1.102e+03,
#          -1.028e+03, -2.282e+03, -2.886e+03, -1.100e+03, -4.560e+02,
#          -1.674e+03, -5.260e+02, -2.980e+02, -1.280e+03, -7.980e+02,
#          -3.040e+02, -1.214e+03, -2.492e+03, -9.780e+02, -3.320e+02,
#          -4.940e+02,  3.700e+02, -7.040e+02,  6.800e+01, -3.360e+02,
#           7.560e+02,  8.840e+02,  4.900e+02,  1.608e+03,  1.826e+03,
#           4.680e+02, -1.216e+03, -3.520e+02,  1.740e+02,  1.560e+02,
#           4.240e+02, -1.258e+03, -3.360e+03,  2.000e+02,  2.766e+03]),
#   'max_rel_err': np.float64(0.0)},
#  'Distributional_HistogramAsymmetry_11_False.modeProbPos': {'r': np.float64(0.9999999999999999),
#   'pval': np.float64(0.0),
#   'res_py': array([0.0999    , 0.1274    , 0.0862    , 0.093     , 0.094     ,
#          0.071     , 0.162     , 0.1204    , 0.1528    , 0.57919255,
#          0.2228    , 0.104     , 0.1779    , 0.1872    , 0.216     ,
#          0.432     , 0.435     , 0.128     , 0.1654    , 0.2912    ,
#          0.1464    , 0.133     , 0.094     , 0.0858    , 0.0839    ,
#          0.0706    , 0.163     , 0.3311    , 0.4655    , 0.066     ,
#          0.069     , 0.113     , 0.09      , 0.074     , 0.074     ,
#          0.191     , 0.1786    , 0.0612    , 0.1232    , 0.0874    ,
#          0.0876    , 0.129     , 0.1166    , 0.0696    , 0.0688    ,
#          0.0646    , 0.1521    , 0.1123    , 0.108     , 0.1031    ,
#          0.088     , 0.101     , 0.0798    , 0.157     , 0.171     ,
#          0.0704    , 0.072     , 0.08653333, 0.102     , 0.117     ,
#          0.111     , 0.119     , 0.124     , 0.1294    , 0.096     ,
#          0.06      , 0.05666667, 0.0654    , 0.0502    , 0.167     ,
#          0.069     , 0.101     , 0.16666667, 0.3332    , 0.0766    ,
#          0.0491    , 0.0531    , 0.0509    , 0.0492    , 0.06666667,
#          0.07666667, 0.06333333, 0.07333333, 0.0506    , 0.05      ,
#          0.05      , 0.1095    , 0.1139    , 0.111     , 0.1       ,
#          0.10666667, 0.11333333, 0.1128    , 0.2116    , 0.2277    ,
#          0.2383    , 0.164     , 0.162     , 0.149     , 0.297     ,
#          0.183     , 0.059     , 0.057     , 0.055     , 0.06666667,
#          0.05666667, 0.06666667, 0.07      , 0.0618    , 0.053     ,
#          0.056     , 0.0963    , 0.0563    , 0.109     , 0.06333333,
#          0.05333333, 0.0992    , 0.0734    , 0.0566    , 0.0742    ,
#          0.0738    , 0.1372    , 0.0734    , 0.087     , 0.211     ,
#          0.0736    , 0.0784    , 0.1358    , 0.0908    , 0.1138    ,
#          0.1272    , 0.1186    , 0.1376    , 0.692     , 0.1266    ,
#          0.1114    , 0.14      , 0.16      , 0.0635    , 0.0673    ,
#          0.0652    , 0.0747    , 0.0742    , 0.0988    , 0.077     ,
#          0.0667    , 0.137     , 0.111     , 0.1286    , 0.1484    ,
#          0.1314    , 0.1498    , 0.159     , 0.106     , 0.11      ,
#          0.1424    , 0.116     , 0.0786    , 0.081     , 0.0848    ,
#          0.098     , 0.08      , 0.0546    , 0.0568    , 0.0504    ,
#          0.0582    , 0.068     , 0.075     , 0.0634    , 0.0949    ,
#          0.063     , 0.0652    , 0.0616    , 0.133     , 0.08      ,
#          0.0809    , 0.091     , 0.0766    , 0.0682    , 0.0954    ,
#          0.0598    , 0.0662    , 0.0704    , 0.0762    , 0.09      ,
#          0.1172    , 0.0891    , 0.112     , 0.1074    , 0.1172    ,
#          0.0886    , 0.089     , 0.10952381, 0.13274336, 0.10633484,
#          0.08202791, 0.05155226, 0.09512959, 0.24329004, 0.24274243,
#          0.12021631, 0.19909502, 0.16726404, 0.16822847, 0.24349286,
#          0.27662957, 0.24774368, 0.18191161, 0.14827586, 0.19320453,
#          0.33727311, 0.07610994, 0.07349762, 0.05674218, 0.12300683,
#          0.09135802, 0.13411765, 0.09135802, 0.0831075 , 0.22337662,
#          0.18717949, 0.24419778, 0.16194077, 0.26853707, 0.20277078,
#          0.1       , 0.287832  , 0.33730522, 0.071     , 0.289     ,
#          0.241     , 0.0732    , 0.243     , 0.2874    , 0.077     ,
#          0.151     , 0.0906    , 0.099     , 0.152     , 0.0934    ,
#          0.0978    , 0.1524    , 0.0735    , 0.081     , 0.0666    ,
#          0.0689    , 0.077     , 0.0688    , 0.0834    , 0.1033    ,
#          0.0872    , 0.1014    , 0.106     , 0.1136    , 0.0746    ,
#          0.0703    , 0.0812    , 0.1096    , 0.1078    , 0.0732    ,
#          0.07      , 0.0952    , 0.0732    , 0.097     , 0.116     ,
#          0.1133    , 0.1611    , 0.1566    , 0.0996    , 0.0738    ,
#          0.077     , 0.1088    , 0.0746    , 0.067     , 0.0922    ,
#          0.0925    , 0.088     , 0.088     , 0.0933    , 0.09      ,
#          0.084     , 0.0892    , 0.111     , 0.101     , 0.09      ,
#          0.115     , 0.1166    , 0.0846    , 0.108     , 0.0816    ,
#          0.1084    , 0.0857    , 0.1103    , 0.091     , 0.096     ,
#          0.0794    , 0.1077    , 0.1043    , 0.1133    , 0.113     ,
#          0.103     , 0.102     , 0.11333333, 0.09333333, 0.1068    ,
#          0.0748    , 0.069     , 0.0654    , 0.0886    , 0.0892    ,
#          0.0842    , 0.0748    , 0.1837    , 0.1779    , 0.543     ,
#          0.167     , 0.491     , 0.16666667, 0.1782    , 0.1432    ,
#          0.138     , 0.08      , 0.13333333, 0.12666667, 0.0966    ,
#          0.0631    , 0.0915    , 0.044     , 0.0906    , 0.052     ,
#          0.054     , 0.089     , 0.121     , 0.1       , 0.06      ,
#          0.0864    , 0.25      , 0.068     , 0.167     , 0.1       ,
#          0.10666667, 0.16666667, 0.1666    , 0.166     , 0.0793    ,
#          0.0783    , 0.071     , 0.07      , 0.07666667, 0.06666667,
#          0.09      , 0.08      , 0.0735    , 0.0659    , 0.074     ,
#          0.08333333, 0.06666667, 0.0736    , 0.0646    , 0.0728    ,
#          0.0975    , 0.1109    , 0.1036    , 0.206     , 0.09      ,
#          0.126     , 0.12      , 0.1028    , 0.1032    , 0.0763    ,
#          0.074     , 0.08      , 0.09666667, 0.073     , 0.074     ,
#          0.119     , 0.11      , 0.12      , 0.10666667, 0.116     ,
#          0.0738    , 0.117     , 0.064     , 0.088     , 0.07666667,
#          0.06      , 0.0692    , 0.0702    , 0.068     , 0.067     ,
#          0.071     , 0.073     , 0.073     , 0.07      , 0.0678    ,
#          0.0686    , 0.0486    , 0.0765    , 0.061     , 0.06      ,
#          0.08333333, 0.0504    , 0.0734    , 0.055     , 0.056     ,
#          0.055     , 0.06666667, 0.06333333, 0.07      , 0.06      ,
#          0.06      , 0.06333333, 0.0512    , 0.0684    , 0.0683    ,
#          0.074     , 0.067     , 0.078     , 0.069     , 0.065     ,
#          0.06666667, 0.11333333, 0.09      , 0.06666667, 0.0742    ,
#          0.073     , 0.084     , 0.09      , 0.07      , 0.0784    ,
#          0.0641    , 0.0654    , 0.055     , 0.067     , 0.0582    ,
#          0.0612    , 0.0624    , 0.0661    , 0.054     , 0.068     ,
#          0.06      , 0.05666667, 0.0654    , 0.0502    , 0.167     ,
#          0.069     , 0.101     , 0.16666667, 0.3332    , 0.0766    ,
#          0.0491    , 0.0531    , 0.0509    , 0.0492    , 0.06666667,
#          0.07666667, 0.06333333, 0.07333333, 0.0506    , 0.05      ,
#          0.05      , 0.1095    , 0.1139    , 0.111     , 0.1       ,
#          0.10666667, 0.11333333, 0.1128    , 0.2116    , 0.2277    ,
#          0.2383    , 0.164     , 0.162     , 0.149     , 0.297     ,
#          0.183     , 0.059     , 0.057     , 0.055     , 0.06666667,
#          0.05666667, 0.06666667, 0.07      , 0.0618    , 0.053     ,
#          0.056     , 0.0963    , 0.0563    , 0.109     , 0.06333333,
#          0.05333333, 0.0992    , 0.0734    , 0.0566    , 0.0742    ,
#           2.50000000e-02,  3.70000000e-01,  3.65000000e-01,  4.00000000e-02,
#           2.05000000e-01, -2.30000000e-01, -5.00000000e-03,  3.00000000e-02,
#          -4.50000000e-02, -1.35000000e-01,  2.00000000e-01,  2.30000000e-01,
#           2.35000000e-01, -2.50000000e-02,  1.60000000e-01, -2.00000000e-02,
#           1.40000000e-01, -5.50000000e-02,  1.25000000e-01,  1.25000000e-01,
#          -6.00000000e-02, -4.50000000e-02, -1.70000000e-01, -4.00000000e-02,
#          -3.50000000e-02,  9.50000000e-02, -5.00000000e-02, -5.00000000e-03,
#           1.00000000e-02,  4.30000000e-01,  1.00000000e-01,  3.40000000e-01,
#           4.95000000e-01,  1.65000000e-01,  6.50000000e-02,  1.60000000e-01,
#           1.15000000e-01,  1.20000000e-01,  2.70000000e-01, -5.40000000e-01,
#          -5.50000000e-01,  1.73100000e+00, -7.00000000e-02, -1.02000000e+00]),
#   'max_rel_err': np.float64(0.0)}}

# %%
importlib.reload(Distributional)
from Distributional import HistogramMode

# %%
HistogramMode(empirical1000[103], 11, doSimple=False)
# Out:
# np.float64(0.28800000000000003)

# %%
def eval_comparison_hm(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i])
            matlab_eval = matlab_func(abs(ZScore(matlab.double(x))) if ordered_args[2] else ZScore(matlab.double(x)), ordered_args[0], ordered_args[1]) if isZscore else matlab_func(matlab.double(x), ordered_args[0], ordered_args[1])
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
hm_evals = eval_comparison_hm("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
hm_compares = compare_outputs(hm_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_HistogramMode_5_True_False with params {'numBins': 5, 'doSimple': True, 'doAbs': False} (Z-score=True)
# Adding operation Distributional_HistogramMode_5_True_True with params {'numBins': 5, 'doSimple': True, 'doAbs': True} (Z-score=True)
# Adding operation Distributional_HistogramMode_10_True_False with params {'numBins': 10, 'doSimple': True, 'doAbs': False} (Z-score=True)
# Adding operation Distributional_HistogramMode_10_True_True with params {'numBins': 10, 'doSimple': True, 'doAbs': True} (Z-score=True)
# Adding operation Distributional_HistogramMode_21_True_False with params {'numBins': 21, 'doSimple': True, 'doAbs': False} (Z-score=True)
# Adding operation Distributional_HistogramMode_21_True_True with params {'numBins': 21, 'doSimple': True, 'doAbs': True} (Z-score=True)
# Evalutating Distributional_HistogramMode_5_True_False
# Comparing to DN_HistogramMode
# Evalutating Distributional_HistogramMode_5_True_True
# Comparing to DN_HistogramMode
# Evalutating Distributional_HistogramMode_10_True_False
# Comparing to DN_HistogramMode
# Evalutating Distributional_HistogramMode_10_True_True
# Comparing to DN_HistogramMode
# Evalutating Distributional_HistogramMode_21_True_False
# Comparing to DN_HistogramMode
# Evalutating Distributional_HistogramMode_21_True_True
# Comparing to DN_HistogramMode
# [Distributional_HistogramMode_5_True_False | ts=0]  RelErr% = 0.00
# [Distributional_HistogramMode_5_True_False | ts
  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=787]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=788]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=789]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=790]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=791]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=792]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=793]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=794]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=795]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=796]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=797]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=798]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=799]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=800]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=801]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=802]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=803]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=804]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=805]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=806]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=807]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=808]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=809]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=810]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=811]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=812]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=813]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=814]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=815]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=816]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=817]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=818]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=819]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=820]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=821]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=822]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=823]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=824]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=825]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=826]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=827]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=828]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=829]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=830]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=831]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=832]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=833]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=834]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=835]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=836]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=837]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=838]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=839]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=840]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=841]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=842]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=843]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=844]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=845]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=846]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=847]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=848]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=849]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=850]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=851]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=852]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=853]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=854]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=855]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=856]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=857]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=858]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=859]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=860]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=861]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=862]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=863]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=864]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=865]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=866]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=867]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=868]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=869]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=870]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=871]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=872]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=873]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=874]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=875]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=876]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=877]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=878]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=879]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=880]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=881]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=882]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=883]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=884]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=885]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=886]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=887]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=888]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=889]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=890]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=891]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=892]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=893]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=894]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=895]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=896]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=897]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=898]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=899]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=900]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=901]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=902]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=903]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=904]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=905]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=906]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=907]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=908]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=909]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=910]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=911]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=912]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=913]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=914]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=915]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=916]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=917]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=918]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=919]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=920]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=921]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=922]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=923]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=924]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=925]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=926]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=927]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=928]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=929]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=930]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=931]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=932]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=933]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=934]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=935]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=936]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=937]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=938]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=939]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=940]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=941]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=942]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=943]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=944]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=945]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=946]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=947]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=948]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=949]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=950]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=951]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=952]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=953]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=954]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=955]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=956]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=957]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=958]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=959]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=960]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=961]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=962]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=963]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=964]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=965]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=966]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=967]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=968]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=969]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=970]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=971]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=972]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=973]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=974]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=975]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=976]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=977]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=978]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=979]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=980]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=981]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=982]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=983]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=984]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=985]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=986]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=987]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=988]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=989]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=990]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=991]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=992]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=993]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=994]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=995]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=996]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=997]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=998]  RelErr% = 0.00
# [Distributional_HistogramMode_21_True_True | ts=999]  RelErr% = 0.00

# %%
def eval_comparison_mean(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i])
            matlab_eval = matlab_func(ZScore(matlab.double(x)), *ordered_args) if isZscore else matlab_func(matlab.double(x), *ordered_args)
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
mean_evals = eval_comparison_mean("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
mean_compares = compare_outputs(mean_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_Mean_norm_raw with params {'meanType': 'norm'} (Z-score=False)
# Adding operation Distributional_Mean_harm_raw with params {'meanType': 'harm'} (Z-score=False)
# Adding operation Distributional_Mean_rms_raw with params {'meanType': 'rms'} (Z-score=False)
# Adding operation Distributional_Mean_median_raw with params {'meanType': 'median'} (Z-score=False)
# Adding operation Distributional_Mean_midhinge_raw with params {'meanType': 'midhinge'} (Z-score=False)
# Evalutating Distributional_Mean_norm_raw
# Comparing to DN_Mean
# Evalutating Distributional_Mean_harm_raw
# Comparing to DN_Mean
# /Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Operations/Distributional.py:42: RuntimeWarning: divide by zero encountered in reciprocal
#   # compute bin centers from bin edges
# /Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Operations/Distributional.py:42: RuntimeWarning: divide by zero encountered in scalar divide
#   # compute bin centers from bin edges
# Evalutating Distributional_Mean_rms_raw
# Comparing to DN_Mean
# Evalutating Distributional_Mean_median_raw
# Comparing to DN_Mean
# Evalutating Distributional_Mean_midhinge_raw
# Comparing to DN_Mean
#
# p =
#
#     0.0910
#     0.3652
#
#
# p =
#
#     0.1974
#     0.3588
#
#
# p =
#
#     0.4442
#     0.7019
#
#
# p =
#
#     0.2537
#     0.4879
#
#
# p =
#
#     0.3424
#     0.5602
#
#
# p =
#
#     0.6057
#     0.8340
#
#
# p =
#
#     0.0050
#     0.0638
#
#
# p =
#
#     0.0168
#     0.2117
#
#
# p =
#
#     0.0280
#     0.1291
#
#
# p =
#
#     18
#     20
#
#
# p =
#
#      1
#      3
#
#
# p =
#
#    -1.2370
#     0.3073
#
#
# p =
#
#      2
#     13
#
#
# p =
#
#    -0.3065
#     1.3099
#
#
# p =
#
#     3.1705
#    16.4170
#
#
# p =
#
#      3
#      5
#
#
# p =
#
#      3
#      5
#
#
# p =
#
#    -5.8660
#     6.8500
#
#
# p =
#
#     45
#     55
#
#
# p =
#
#    -0.7621
#     0.7181
#
#
# p =
#
#     0.9873
#     1.0168
#
#
# p =
#
#     2.0198
#     3.7920
#
#
# p =
#
#    59.3825
#   168.0250
#
#
# p =
#
#     1.4901
#     2.1473
#
#
# p =
#
#     0.0000
#     0.0036
#
#
# p =
#
#     0.9237
#     1.7062
#
#
# p =
#
#     2.6709
#     6.9584
#
#
# p =
#
#   -10.2830
#    -0.4707
#
#
# p =
#
#    -1.6930
#    -0.1409
#
#
# p =
#
#     0.6166
#     2.3776
#
#
# p =
#
#     1.0835
#     2.1897
#
#
# p =
#
#     0.7128
#     0.9419
#
#
# p =
#
#     0.0246
#     0.9506
#
#
# p =
#
#     0.0034
#     0.6086
#
#
# p =
#
#     0.5715
#     1.2202
#
#
# p =
#
#     0.4781
#     1.0724
#
#
# p =
#
#     0.1905
#     0.3427
#
#
# p =
#
#     0.1221
#     1.1079
#
#
# p =
#
#     1.8740
#     2.7692
#
#
# p =
#
#    -1.8628
#    -0.3736
#
#
# p =
#
#     0.7567
#     2.9246
#
#
# p =
#
#     0.6270
#     2.3887
#
#
# p =
#
#    -0.0966
#     0.2681
#
#
# p =
#
#    -0.6529
#     0.6634
#
#
# p =
#
#    -0.6580
#     0.6619
#
#
# p =
#
#    -0.6680
#     0.6677
#
#
# p =
#
#    -0.2097
#     0.1186
#
#
# p =
#
#    -0.3644
#     0.1520
#
#
# p =
#
#    -0.0208
#     0.0229
#
#
# p =
#
#    1.0e-03 *
#
#     0.0436
#     0.1364
#
#
# p =
#
#     0.0006
#     0.0015
#
#
# p =
#
#    21.2735
#    98.8405
#
#
# p =
#
#   -39.8915
#    36.0010
#
#
# p =
#
#    31.1190
#    50.5225
#
#
# p =
#
#   -29.1800
#     0.7363
#
#
# p =
#
#   -22.7020
#    11.2385
#
#
# p =
#
#  -127.5350
#   -16.6950
#
#
# p =
#
#   -15.3655
#    15.7380
#
#
# p =
#
#    -0.1492
#     0.1661
#
#
# p =
#
#    -0.2200
#     0.1975
#
#
# p =
#
#    -0.1888
#     0.2066
#
#
# p =
#
#    -0.2414
#     0.2188
#
#
# p =
#
#    -0.7506
#     0.7446
#
#
# p =
#
#    -1.0143
#     1.0377
#
#
# p =
#
#    -1.1923
#     0.6076
#
#
# p =
#
#    -0.8386
#     0.8191
#
#
# p =
#
#    -0.1143
#     0.1526
#
#
# p =
#
#    -0.7238
#     0.7132
#
#
# p =
#
#    -1.1024
#     1.1058
#
#
# p =
#
#    -0.8265
#     0.7969
#
#
# p =
#
#     7.1810
#    79.5910
#
#
# p =
#
#    15.0655
#   141.6800
#
#
# p =
#
#    -0.9512
#     1.2545
#
#
# p =
#
#   -67.6320
#   -53.2315
#
#
# p =
#
#    -1.2620
#     0.8410
#
#
# p =
#
#    40.1450
#   142.5000
#
#
# p =
#
#    -0.8172
#     0.8530
#
#
# p =
#
#    -0.9564
#     0.9224
#
#
# p =
#
#    -0.7913
#     0.8606
#
#
# p =
#
#    -0.7625
#     0.8206
#
#
# p =
#
#    -0.4683
#     0.4767
#
#
# p =
#
#    -0.8419
#     0.7773
#
#
# p =
#
#    -0.4538
#     0.4569
#
#
# p =
#
#    -0.7658
#     0.8216
#
#
# p =
#
#    -0.8904
#     0.6910
#
#
# p =
#
#    -0.4739
#     0.4728
#
#
# p =
#
#    -0.3793
#     0.3764
#
#
# p =
#
#    -0.3856
#     0.3879
#
#
# p =
#
#    -0.3999
#     0.4017
#
#
# p =
#
#    -0.3609
#     0.3493
#
#
# p =
#
#    -0.3719
#     0.3820
#
#
# p =
#
#    -0.3978
#     0.3569
#
#
# p =
#
#    -0.3958
#     0.4014
#
#
# p =
#
#    -1.1014
#     1.1124
#
#
# p =
#
#    -1.1384
#     1.2269
#
#
# p =
#
#    -1.0986
#     1.1453
#
#
# p =
#
#    -1.2064
#     1.1969
#
#
# p =
#
#    -1.2346
#     1.1351
#
#
# p =
#
#    -1.0728
#     1.0547
#
#
# p =
#
#     0.2838
#     0.4693
#
#
# p =
#
#     2.5184
#     3.0756
#
#
# p =
#
#     0.2839
#     0.4667
#
#
# p =
#
#     2.5183
#     3.0753
#
#
# p =
#
#     0.2835
#     0.4718
#
#
# p =
#
#    -5.4221
#     5.3385
#
#
# p =
#
#    -5.1942
#     4.7757
#
#
# p =
#
#    -5.5907
#     5.3021
#
#
# p =
#
#    -5.1310
#     5.2152
#
#
# p =
#
#    -5.2106
#     4.9783
#
#
# p =
#
#    -5.1989
#     4.6784
#
#
# p =
#
#    -0.4099
#     0.3989
#
#
# p =
#
#    -0.3997
#     0.4053
#
#
# p =
#
#    -0.3061
#     0.2982
#
#
# p =
#
#    -0.4052
#     0.4279
#
#
# p =
#
#    -0.4135
#     0.4092
#
#
# p =
#
#    -0.2979
#     0.3108
#
#
# p =
#
#    -0.3940
#     0.4017
#
#
# p =
#
#    -0.3963
#     0.4035
#
#
# p =
#
#    -3.8949
#     4.1905
#
#
# p =
#
#    -0.8743
#     0.8540
#
#
# p =
#
#    -1.3638
#     1.3480
#
#
# p =
#
#    -1.3283
#     1.3386
#
#
# p =
#
#    -0.8365
#     0.8593
#
#
# p =
#
#    -0.8798
#     0.8510
#
#
# p =
#
#    -1.3588
#     1.3390
#
#
# p =
#
#    -0.8355
#     0.8432
#
#
# p =
#
#    -0.8424
#     0.8398
#
#
# p =
#
#    -1.1799
#     1.4259
#
#
# p =
#
#    -1.5035
#     1.4739
#
#
# p =
#
#    -1.1860
#     1.4165
#
#
# p =
#
#    -1.5004
#     1.4847
#
#
# p =
#
#    -1.1424
#     1.4444
#
#
# p =
#
#    -1.5145
#     1.4689
#
#
# p =
#
#    -1.2347
#     1.3944
#
#
# p =
#
#    -1.5273
#     1.5676
#
#
# p =
#
#    -1.2665
#     1.3918
#
#
# p =
#
#    -1.3610
#     0.5593
#
#
# p =
#
#    -1.3556
#     0.5889
#
#
# p =
#
#    -1.3574
#     0.5662
#
#
# p =
#
#    -1.4486
#     0.4499
#
#
# p =
#
#    -1.3843
#     0.4794
#
#
# p =
#
#    -1.3811
#     0.6980
#
#
# p =
#
#    -1.4242
#     0.5887
#
#
# p =
#
#    -1.0843
#     0.5791
#
#
# p =
#
#    -1.3441
#     0.5935
#
#
# p =
#
#    -0.4627
#     0.5960
#
#
# p =
#
#    -0.5781
#     0.6027
#
#
# p =
#
#    -0.6375
#     0.6357
#
#
# p =
#
#    -0.5983
#     0.6469
#
#
# p =
#
#    -0.6934
#     0.6972
#
#
# p =
#
#    -0.7859
#     0.7637
#
#
# p =
#
#    -0.7694
#     0.7747
#
#
# p =
#
#    -0.9074
#    -0.0795
#
#
# p =
#
#    -0.8929
#    -0.0787
#
#
# p =
#
#    -0.0388
#     0.0173
#
#
# p =
#
#    -0.8902
#    -0.0802
#
#
# p =
#
#    -0.0359
#     0.0229
#
#
# p =
#
#    -0.8913
#    -0.0834
#
#
# p =
#
#    -0.8906
#    -0.0783
#
#
# p =
#
#    -0.0220
#     0.0362
#
#
# p =
#
#    -3.1075
#     3.1105
#
#
# p =
#
#   -18.7910
#    18.7940
#
#
# p =
#
#    -3.3832
#     3.4008
#
#
# p =
#
#    -3.2150
#     3.2514
#
#
# p =
#
#   -18.4830
#    18.4975
#
#
# p =
#
#     0.9093
#     5.1051
#
#
# p =
#
#     0.8945
#     5.3803
#
#
# p =
#
#     1.0473
#     4.6074
#
#
# p =
#
#     0.9219
#     5.3277
#
#
# p =
#
#     0.6277
#     2.2550
#
#
# p =
#
#     0.7649
#     5.0057
#
#
# p =
#
#     0.7843
#     5.5171
#
#
# p =
#
#     0.9226
#     5.4500
#
#
# p =
#
#     0.7511
#     5.4747
#
#
# p =
#
#     0.5374
#     5.1535
#
#
# p =
#
#     0.9891
#     5.2613
#
#
# p =
#
#     0.1651
#     0.7869
#
#
# p =
#
#    -0.5176
#     0.4755
#
#
# p =
#
#    -0.5753
#     0.5753
#
#
# p =
#
#     0.4321
#     0.8979
#
#
# p =
#
#    -0.0012
#     0.7339
#
#
# p =
#
#    -0.5753
#     0.5753
#
#
# p =
#
#    -0.5753
#     0.5753
#
#
# p =
#
#    -0.6475
#     0.6391
#
#
# p =
#
#    -0.4268
#     0.2041
#
#
# p =
#
#    -0.4030
#     0.2180
#
#
# p =
#
#    -0.2987
#     0.2921
#
#
# p =
#
#    -0.6054
#     0.0770
#
#
# p =
#
#    -0.3798
#     0.2275
#
#
# p =
#
#    -0.3290
#     0.3139
#
#
# p =
#
#    -0.6114
#     0.0844
#
#
# p =
#
#    -0.8328
#    -0.1245
#
#
# p =
#
#     1.7232
#     4.7774
#
#
# p =
#
#     2.2032
#     4.2839
#
#
# p =
#
#     2.2318
#     4.2942
#
#
# p =
#
#     1.3849
#     4.8464
#
#
# p =
#
#     2.2190
#     4.3796
#
#
# p =
#
#     1.6997
#     4.7797
#
#
# p =
#
#     2.2455
#     4.3109
#
#
# p =
#
#     1.7120
#     4.7941
#
#
# p =
#
#    -0.1869
#     3.5275
#
#
# p =
#
#    -0.2265
#     3.9084
#
#
# p =
#
#    -0.1781
#     3.5802
#
#
# p =
#
#     0.2242
#     2.1302
#
#
# p =
#
#    -0.2550
#     3.3342
#
#
# p =
#
#     0.0514
#     2.8178
#
#
# p =
#
#    -0.4400
#     3.9200
#
#
# p =
#
#    -0.1302
#     3.6437
#
#
# p =
#
#    -0.1333
#     3.7229
#
#
# p =
#
#    -0.3280
#     0.8439
#
#
# p =
#
#    -0.3285
#     0.8795
#
#
# p =
#
#    -0.3548
#     0.9005
#
#
# p =
#
#    -0.3355
#     0.8112
#
#
# p =
#
#    -0.3312
#     0.8379
#
#
# p =
#
#    -0.3462
#     0.8452
#
#
# p =
#
#    -0.3022
#     0.4089
#
#
# p =
#
#    -0.3143
#     0.4169
#
#
# p =
#
#    -0.3039
#     0.4072
#
#
# p =
#
#    -0.3147
#     0.4114
#
#
# p =
#
#    -0.3054
#     0.4042
#
#
# p =
#
#    -1.1910
#     1.0576
#
#
# p =
#
#    -1.2100
#     1.1538
#
#
# p =
#
#    -1.2775
#     0.6218
#
#
# p =
#
#    -1.2117
#     0.9857
#
#
# p =
#
#    -0.9845
#     1.1204
#
#
# p =
#
#    -1.2835
#     0.6101
#
#
# p =
#
#    -1.1679
#     1.0751
#
#
# p =
#
#    -1.2248
#     0.9774
#
#
# p =
#
#    -1.0566
#     0.2098
#
#
# p =
#
#    -1.1025
#     0.2018
#
#
# p =
#
#     0.2457
#     0.9983
#
#
# p =
#
#     0.2472
#     1.0179
#
#
# p =
#
#    -1.0559
#     0.2206
#
#
# p =
#
#     0.2406
#     0.9727
#
#
# p =
#
#     0.2441
#     1.0104
#
#
# p =
#
#    -1.0675
#     0.2086
#
#
# p =
#
#     0.2514
#     0.7469
#
#
# p =
#
#     0.1923
#     0.7773
#
#
# p =
#
#     0.2636
#     0.7588
#
#
# p =
#
#     0.2760
#     0.7852
#
#
# p =
#
#     0.1942
#     0.7862
#
#
# p =
#
#     0.2528
#     0.7447
#
#
# p =
#
#     0.1972
#     0.7801
#
#
# p =
#
#        65396
#       199045
#
#
# p =
#
#    1.0e+05 *
#
#     0.6688
#     1.9509
#
#
# p =
#
#        63667
#       197820
#
#
# p =
#
#    1.0e+05 *
#
#     0.5909
#     1.8245
#
#
# p =
#
#    1.0e+05 *
#
#     0.6353
#     2.0399
#
#
# p =
#
#    1.0e+05 *
#
#     0.5853
#     1.9229
#
#
# p =
#
#        66223
#       196365
#
#
# p =
#
#    1.0e+05 *
#
#     0.6741
#     1.9617
#
#
# p =
#
#    1.0e+05 *
#
#     0.6815
#     1.9882
#
#
# p =
#
#    1.0e+05 *
#
#     0.6509
#     1.9572
#
#
# p =
#
#    -0.5795
#     0.5860
#
#
# p =
#
#    -0.6066
#     0.5926
#
#
# p =
#
#    -0.6071
#     0.5580
#
#
# p =
#
#    -0.6094
#     0.5712
#
#
# p =
#
#    -0.6079
#     0.5174
#
#
# p =
#
#    -0.5997
#     0.5807
#
#
# p =
#
#    -0.5798
#     0.5762
#
#
# p =
#
#    -0.5704
#     0.5798
#
#
# p =
#
#    -0.7011
#     0.3242
#
#
# p =
#
#    -0.5413
#     0.5719
#
#
# p =
#
#    -0.6238
#     0.4288
#
#
# p =
#
#    -0.2479
#     0.6426
#
#
# p =
#
#    -0.2475
#     0.6593
#
#
# p =
#
#    -0.2427
#     0.6418
#
#
# p =
#
#    -0.3048
#     0.6481
#
#
# p =
#
#    -0.3173
#     0.6680
#
#
# p =
#
#    -0.2393
#     0.6436
#
#
# p =
#
#     0.1397
#     0.4578
#
#
# p =
#
#     0.1475
#     0.4735
#
#
# p =
#
#     0.2277
#     0.5924
#
#
# p =
#
#     0.2198
#     0.5787
#
#
# p =
#
#     0.2244
#     0.5943
#
#
# p =
#
#     0.1981
#     0.5399
#
#
# p =
#
#     0.2172
#     0.5821
#
#
# p =
#
#     0.0642
#     0.3706
#
#
# p =
#
#     0.1333
#     0.8932
#
#
# p =
#
#     0.0615
#     0.3526
#
#
# p =
#
#     0.0562
#     0.3410
#
#
# p =
#
#     0.1302
#     0.9712
#
#
# p =
#
#     0.0634
#     0.3665
#
#
# p =
#
#     0.1413
#     0.8732
#
#
# p =
#
#     0.9992
#     4.2111
#
#
# p =
#
#     0.5146
#     5.3942
#
#
# p =
#
#     0.3726
#     5.8438
#
#
# p =
#
#     0.9992
#     4.2111
#
#
# p =
#
#     0.0420
#     8.4375
#
#
# p =
#
#     0.1153
#     7.4228
#
#
# p =
#
#     0.2477
#     0.7423
#
#
# p =
#
#     0.2567
#     0.7580
#
#
# p =
#
#     0.2503
#     0.7551
#
#
# p =
#
#     0.2488
#     0.7534
#
#
# p =
#
#     0.2655
#     0.7331
#
#
# p =
#
#     0.2553
#     0.7500
#
#
# p =
#
#     0.2783
#     0.7473
#
#
# p =
#
#     0.2111
#     0.7578
#
#
# p =
#
#     0.2508
#     0.7462
#
#
# p =
#
#     0.2482
#     0.7526
#
#
# p =
#
#     0.2489
#     0.7433
#
#
# p =
#
#     0.3910
#     0.6896
#
#
# p =
#
#     0.3910
#     0.6897
#
#
# p =
#
#     0.3910
#     0.6898
#
#
# p =
#
#     0.3497
#     0.6490
#
#
# p =
#
#     0.3508
#     0.6499
#
#
# p =
#
#     0.3099
#     0.6088
#
#
# p =
#
#     0.3910
#     0.6897
#
#
# p =
#
#     0.3106
#     1.2748
#
#
# p =
#
#     0.3079
#     1.2801
#
#
# p =
#
#     0.3087
#     1.2760
#
#
# p =
#
#     0.3177
#     1.2605
#
#
# p =
#
#     0.3119
#     1.2450
#
#
# p =
#
#     0.3095
#     1.3739
#
#
# p =
#
#     0.3064
#     1.2957
#
#
# p =
#
#     0.3104
#     1.2774
#
#
# p =
#
#     0.4016
#     0.7434
#
#
# p =
#
#     0.3384
#     0.7667
#
#
# p =
#
#     0.2623
#     0.7573
#
#
# p =
#
#     0.3494
#     0.7361
#
#
# p =
#
#     0.3098
#     0.7624
#
#
# p =
#
#     0.3468
#     0.7781
#
#
# p =
#
#     0.2771
#     0.7541
#
#
# p =
#
#     0.4219
#     0.7381
#
#
# p =
#
#     0.3662
#     0.7580
#
#
# p =
#
#     0.3546
#     0.7563
#
#
# p =
#
#    -0.3733
#     0.0587
#
#
# p =
#
#    -0.6085
#    -0.0060
#
#
# p =
#
#    -0.3587
#     0.0662
#
#
# p =
#
#    -0.6002
#    -0.0073
#
#
# p =
#
#    -0.6084
#    -0.0069
#
#
# p =
#
#    -0.3646
#     0.0547
#
#
# p =
#
#     0.1167
#     0.6605
#
#
# p =
#
#    -0.6050
#     0.0030
#
#
# p =
#
#    -1.2966
#     1.2600
#
#
# p =
#
#    -1.3318
#     1.3300
#
#
# p =
#
#    -1.7953
#     1.6667
#
#
# p =
#
#    -1.3120
#     1.3304
#
#
# p =
#
#    -2.1605
#     2.1581
#
#
# p =
#
#    -2.6679
#     2.1689
#
#
# p =
#
#    -1.5850
#     1.6200
#
#
# p =
#
#    -2.4791
#     2.4538
#
#
# p =
#
#    -2.0722
#     2.0788
#
#
# p =
#
#    -5.8261
#     5.8604
#
#
# p =
#
#    -6.8227
#     7.6503
#
#
# p =
#
#    -0.8132
#     0.8137
#
#
# p =
#
#    -1.4383
#     1.4310
#
#
# p =
#
#    1.0e+03 *
#
#    -2.3109
#     8.1593
#
#
# p =
#
#  -183.2700
#  -181.2100
#
#
# p =
#
#    -0.8125
#     0.8128
#
#
# p =
#
#    1.0e-04 *
#
#    -0.6031
#     0.6041
#
#
# p =
#
#    1.0e+03 *
#
#    -1.7024
#    -0.0169
#
#
# p =
#
#    1.0e+03 *
#
#    -0.6337
#     2.6332
#
#
# p =
#
#    -1.5002
#     0.1789
#
#
# p =
#
#    -1.5574
#     0.1040
#
#
# p =
#
#    -1.5650
#     0.0727
#
#
# p =
#
#    -1.5764
#     0.0414
#
#
# p =
#
#    -1.6517
#     0.1059
#
#
# p =
#
#    -0.0813
#     0.9308
#
#
# p =
#
#    -4.1468
#     6.7546
#
#
# p =
#
#    16.9150
#    30.5555
#
#
# p =
#
#    -0.3090
#     0.3159
#
#
# p =
#
#    -0.4157
#     0.4295
#
#
# p =
#
#    -0.5169
#     0.5380
#
#
# p =
#
#    -0.3552
#     0.3447
#
#
# p =
#
#    -0.4364
#     0.4474
#
#
# p =
#
#    -0.5430
#     0.5206
#
#
# p =
#
#    -0.5102
#     0.5122
#
#
# p =
#
#    -0.4735
#     0.4170
#
#
# p =
#
#    -0.4848
#     0.5599
#
#
# p =
#
#    -0.4966
#     0.4947
#
#
# p =
#
#    -0.6887
#     0.7183
#
#
# p =
#
#    -0.6523
#     0.6631
#
#
# p =
#
#    -0.6528
#     0.6500
#
#
# p =
#
#    -0.6481
#     0.6456
#
#
# p =
#
#    -0.6520
#     0.6325
#
#
# p =
#
#    -0.5984
#     0.6399
#
#
# p =
#
#    -0.5324
#     0.5633
#
#
# p =
#
#    -0.5312
#     0.5382
#
#
# p =
#
#    -0.5048
#     0.5136
#
#
# p =
#
#     0.0234
#     0.1264
#
#
# p =
#
#    -3.7432
#     3.9280
#
#
# p =
#
#     0.0278
#     0.4749
#
#
# p =
#
#    -4.3279
#     2.9442
#
#
# p =
#
#    -3.1448
#     3.7047
#
#
# p =
#
#    -4.6197
#     3.0189
#
#
# p =
#
#    -3.8603
#     4.2215
#
#
# p =
#
#    -4.5911
#     3.0689
#
#
# p =
#
#    -0.8957
#     0.9479
#
#
# p =
#
#    -0.2219
#     0.0409
#
#
# p =
#
#    -0.2182
#     0.0411
#
#
# p =
#
#    -0.7260
#     0.5938
#
#
# p =
#
#    -1.1170
#     1.1319
#
#
# p =
#
#    -0.4799
#    -0.0441
#
#
# p =
#
#    -0.1834
#     0.4571
#
#
# p =
#
#    -0.5013
#     0.0860
#
#
# p =
#
#    -1.1206
#     0.4217
#
#
# p =
#
#    -0.8523
#    -0.0020
#
#
# p =
#
#    -0.8550
#     0.0012
#
#
# p =
#
#    -1.5165
#     1.5114
#
#
# p =
#
#    -1.4486
#     1.4476
#
#
# p =
#
#    -1.5168
#     1.5173
#
#
# p =
#
#    -1.5693
#     1.5613
#
#
# p =
#
#    -1.5772
#     1.5697
#
#
# p =
#
#    -1.4484
#     1.4478
#
#
# p =
#
#    -1.5086
#     1.5225
#
#
# p =
#
#    -0.3107
#     0.9587
#
#
# p =
#
#    82.2000
#    86.2000
#
#
# p =
#
#    21.2000
#    24.4000
#
#
# p =
#
#     1.1570
#    54.6000
#
#
# p =
#
#     1.5190
#     2.1974
#
#
# p =
#
#     0.3880
#     0.4844
#
#
# p =
#
#     0.3970
#     0.5514
#
#
# p =
#
#     1.6100
#     4.5000
#
#
# p =
#
#     2.3000
#     4.7500
#
#
# p =
#
#      4
#     31
#
#
# p =
#
#     3.5000
#     7.0000
#
#
# p =
#
#     8.7500
#    18.5000
#
#
# p =
#
#     0.7500
#     2.8925
#
#
# p =
#
#      2
#      6
#
#
# p =
#
#     6.1600
#    14.3500
#
#
# p =
#
#     1.7300
#     8.5000
#
#
# p =
#
#     1.5000
#     8.2500
#
#
# p =
#
#     5.0000
#    14.5000
#
#
# p =
#
#   220.7500
#   505.0000
#
#
# p =
#
#    61.9253
#   142.0000
#
#
# p =
#
#    111
#    193
#
#
# p =
#
#    1.0e+03 *
#
#     2.2042
#     5.5870
#
#
# p =
#
#    1.0e+03 *
#
#     0.7758
#     1.7801
#
#
# p =
#
#   230.8750
#   419.8750
#
#
# p =
#
#    292
#    492
#
#
# p =
#
#    1.0e+03 *
#
#     2.3249
#     3.2391
#
#
# p =
#
#   402.5000
#   898.2500
#
#
# p =
#
#   349.9100
#   419.2175
#
#
# p =
#
#        56300
#       412100
#
#
# p =
#
#         2800
#       100100
#
#
# p =
#
#     65793000
#    132990000
#
#
# p =
#
#         1300
#        27975
#
#
# p =
#
#      6579075
#     14037500
#
#
# p =
#
#     46398500
#     83507500
#
#
# p =
#
#            0
#        30000
#
#
# p =
#
#       351225
#      1206900
#
#
# p =
#
#     18200000
#     48600000
#
#
# p =
#
#    -3.7457
#     3.7715
#
#
# p =
#
#    -2.0023
#     2.1176
#
#
# p =
#
#    -1.6524
#     2.3752
#
#
# p =
#
#     1.6611
#    10.0130
#
#
# p =
#
#    -1.6570
#     2.3910
#
#
# p =
#
#    -2.1055
#     1.9742
#
#
# p =
#
#    -7.5322
#     7.3064
#
#
# p =
#
#    19.3505
#    27.9120
#
#
# p =
#
#    -7.0240
#     6.9331
#
#
# p =
#
#    -7.4206
#     7.3338
#
#
# p =
#
#    19.3870
#    27.7095
#
#
# p =
#
#    -7.0111
#     6.9585
#
#
# p =
#
#    -7.4057
#     7.3419
#
#
# p =
#
#    19.4255
#    27.6175
#
#
# p =
#
#    -1.1590
#     1.1022
#
#
# p =
#
#    -1.3701
#     1.0485
#
#
# p =
#
#    -1.2911
#     1.2691
#
#
# p =
#
#    -0.1521
#     0.1495
#
#
# p =
#
#    -1.1362
#     1.1591
#
#
# p =
#
#    -1.2925
#     1.2683
#
#
# p =
#
#    -1.0058
#     1.0021
#
#
# p =
#
#   156.9200
#   303.1200
#
#
# p =
#
#    -1.0139
#     1.0360
#
#
# p =
#
#   157.7850
#   302.0100
#
#
# p =
#
#    -0.7592
#     0.7723
#
#
# p =
#
#    -0.7775
#     0.7315
#
#
# p =
#
#    -0.9320
#     0.9057
#
#
# p =
#
#   144.6100
#   383.6950
#
#
# p =
#
#    -0.9392
#     0.9314
#
#
# p =
#
#    -0.2802
#     0.2734
#
#
# p =
#
#    -0.2545
#     0.2492
#
#
# p =
#
#    -0.3171
#     0.3260
#
#
# p =
#
#    -0.7235
#     1.0409
#
#
# p =
#
#    -0.3598
#     0.3375
#
#
# p =
#
#    -0.3177
#     0.3261
#
#
# p =
#
#    -0.9223
#     1.0082
#
#
# p =
#
#    -0.2740
#     0.2726
#
#
# p =
#
#    -0.6441
#     1.0732
#
#
# p =
#
#    -0.8409
#     0.9958
#
#
# p =
#
#    -0.6934
#     0.8675
#
#
# p =
#
#    -0.8117
#     0.8079
#
#
# p =
#
#    -1.6509
#     2.1212
#
#
# p =
#
#    -1.5112
#     2.1568
#
#
# p =
#
#   -43.2820
#   516.2100
#
#
# p =
#
#    -1.9886
#     1.6919
#
#
# p =
#
#    -1.3932
#     2.3469
#
#
# p =
#
#    -8.0047
#    -8.0025
#
#
# p =
#
#    -8.0047
#    -8.0025
#
#
# p =
#
#    -0.6163
#     0.6322
#
#
# p =
#
#    -0.5621
#     0.5035
#
#
# p =
#
#    -8.0047
#    -8.0025
#
#
# p =
#
#    -8.0047
#    -8.0025
#
#
# p =
#
#    -0.6131
#     0.6340
#
#
# p =
#
#    -0.5585
#     0.5016
#
#
# p =
#
#    -0.5598
#     0.5002
#
#
# p =
#
#    -6.4443
#     0.1244
#
#
# p =
#
#    -6.4631
#     0.3154
#
#
# p =
#
#    -6.4276
#     0.5595
#
#
# p =
#
#    -6.4617
#     0.3217
#
#
# p =
#
#    -6.4228
#    -0.8837
#
#
# p =
#
#    -6.3982
#    -0.8785
#
#
# p =
#
#    -6.2792
#     0.9262
#
#
# p =
#
#    -6.4418
#     0.2560
#
#
# p =
#
#    -6.4281
#     0.1896
#
#
# p =
#
#    -0.1934
#     0.1990
#
#
# p =
#
#    -0.1485
#     0.1461
#
#
# p =
#
#    -0.3185
#     0.2408
#
#
# p =
#
#    -0.1908
#     0.1981
#
#
# p =
#
#    -0.2186
#     0.2167
#
#
# p =
#
#    -0.2058
#     0.1094
#
#
# p =
#
#    -0.2341
#     0.2297
#
#
# p =
#
#    -0.1364
#     0.1369
#
#
# p =
#
#   -24.5650
#    40.5715
#
#
# p =
#
#    -6.6744
#    21.0725
#
#
# p =
#
#   -14.6150
#    -4.4794
#
#
# p =
#
#  -207.8350
#    11.5835
#
#
# p =
#
#   -55.6545
#   -26.8160
#
#
# p =
#
#  -222.9850
#    61.9200
#
#
# p =
#
#   -17.7505
#    -0.2720
#
#
# p =
#
#    -7.0172
#    -1.8740
#
#
# p =
#
#    -2.1427
#     2.2597
#
#
# p =
#
#    -0.7465
#     0.6974
#
#
# p =
#
#    -0.7566
#     0.6967
#
#
# p =
#
#    -0.7526
#     0.6862
#
#
# p =
#
#    -0.7521
#     0.6757
#
#
# p =
#
#    -4.2727
#     5.7022
#
#
# p =
#
#    -4.4181
#     5.6891
#
#
# p =
#
#    -0.7473
#     0.6791
#
#
# p =
#
#    -0.2908
#     0.7771
#
#
# p =
#
#    -0.2914
#     0.7598
#
#
# p =
#
#    -0.5868
#     0.3324
#
#
# p =
#
#    -1.2774
#     1.2483
#
#
# p =
#
#    -0.2927
#     0.7788
#
#
# p =
#
#    -1.2773
#     1.2536
#
#
# p =
#
#    -1.2525
#     1.2472
#
#
# p =
#
#     0.4340
#     1.5579
#
#
# p =
#
#     0.3036
#     0.8171
#
#
# p =
#
#    -1.4546
#    -0.9137
#
#
# p =
#
#     0.2752
#     0.8590
#
#
# p =
#
#     0.2762
#     0.8472
#
#
# p =
#
#     0.2960
#     0.8384
#
#
# p =
#
#     0.4306
#     1.5610
#
#
# p =
#
#    -1.6140
#     1.6606
#
#
# p =
#
#    -2.3544
#     2.0055
#
#
# p =
#
#     4.2456
#     8.3587
#
#
# p =
#
#     4.3147
#     8.2196
#
#
# p =
#
#     4.2658
#     8.3561
#
#
# p =
#
#     4.2089
#     8.4818
#
#
# p =
#
#    -2.4536
#     1.8173
#
#
# p =
#
#    -2.4278
#     1.7904
#
#
# p =
#
#    -1.9373
#     1.9449
#
#
# p =
#
#    -0.9591
#     0.9588
#
#
# p =
#
#    -0.9568
#     0.9652
#
#
# p =
#
#    -0.9568
#     0.9640
#
#
# p =
#
#    -0.9585
#     0.9599
#
#
# p =
#
#    -0.1139
#     0.1197
#
#
# p =
#
#    -0.9575
#     0.9607
#
#
# p =
#
#    -0.8083
#     0.8307
#
#
# p =
#
#    -1.1380
#     1.1792
#
#
# p =
#
#    -0.8169
#     0.8268
#
#
# p =
#
#    -1.3329
#     1.3394
#
#
# p =
#
#    -0.6314
#     0.6245
#
#
# p =
#
#    -1.5041
#     0.1909
#
#
# p =
#
#    -1.5051
#     0.1812
#
#
# p =
#
#    -1.4941
#     0.1780
#
#
# p =
#
#    -0.8134
#     0.7870
#
#
# p =
#
#    -0.8438
#     0.7618
#
#
# p =
#
#    -0.7736
#     0.7453
#
#
# p =
#
#    -0.7860
#     0.7452
#
#
# p =
#
#    -0.7719
#     0.7422
#
#
# p =
#
#    -0.7811
#     0.7429
#
#
# p =
#
#    -0.1258
#     0.4802
#
#
# p =
#
#    -0.4123
#     3.9423
#
#
# p =
#
#    -0.1366
#     0.4802
#
#
# p =
#
#    -0.4197
#     3.9113
#
#
# p =
#
#    -0.1556
#     0.4805
#
#
# p =
#
#    -1.0457
#     1.2235
#
#
# p =
#
#    -0.4325
#     3.7943
#
#
# p =
#
#    -0.1712
#     0.4808
#
#
# p =
#
#    -0.1284
#     0.4807
#
#
# p =
#
#    -2.2410
#     2.1557
#
#
# p =
#
#    -2.2309
#     2.1380
#
#
# p =
#
#    -2.1471
#     2.2475
#
#
# p =
#
#    -2.0899
#     2.2801
#
#
# p =
#
#    -2.1530
#     2.2343
#
#
# p =
#
#    -2.1162
#     2.2847
#
#
# p =
#
#    -8.8731
#     0.4193
#
#
# p =
#
#    -2.3744
#     3.5829
#
#
# p =
#
#    -8.8679
#     0.4388
#
#
# p =
#
#    -8.8285
#     0.4656
#
#
# p =
#
#    -9.5540
#     0.3493
#
#
# p =
#
#    -2.6322
#     3.0153
#
#
# p =
#
#    -8.7690
#     0.5006
#
#
# p =
#
#    -8.7463
#     0.5449
#
#
# p =
#
#     0.8000
#     1.1900
#
#
# p =
#
#     0.8400
#     1.1650
#
#
# p =
#
#     0.8500
#     1.1400
#
#
# p =
#
#     0.8400
#     1.0200
#
#
# p =
#
#     0.6000
#     0.9000
#
#
# p =
#
#     0.9000
#     1.0800
#
#
# p =
#
#     0.9500
#     1.0600
#
#
# p =
#
#    73.2500
#   125.0000
#
#
# p =
#
#    10.3920
#    38.7800
#
#
# p =
#
#     81
#    115
#
#
# p =
#
#    -0.9325
#     0.8617
#
#
# p =
#
#    24.7770
#    64.6475
#
#
# p =
#
#     69
#    121
#
#
# p =
#
#    21.6195
#    99.8030
#
#
# p =
#
#     0.0626
#     3.2205
#
#
# p =
#
#     0.1878
#     2.1181
#
#
# p =
#
#     72
#    124
#
#
# p =
#
#    19.0005
#    64.5345
#
#
# p =
#
#    11.7090
#    66.6865
#
#
# p =
#
#    16.0500
#    39.3000
#
#
# p =
#
#    37.9000
#    63.4000
#
#
# p =
#
#    15.4000
#    23.0000
#
#
# p =
#
#     8.3000
#    14.0000
#
#
# p =
#
#     8.8400
#     9.6100
#
#
# p =
#
#     5.2000
#    13.8000
#
#
# p =
#
#   172.9500
#   354.3000
#
#
# p =
#
#    -0.2481
#     0.6469
#
#
# p =
#
#    -0.2399
#     0.6403
#
#
# p =
#
#    -1.9975
#    -1.1854
#
#
# p =
#
#    -0.8703
#    -0.1010
#
#
# p =
#
#    -4.0275
#    -2.6279
#
#
# p =
#
#     1.0720
#     1.9436
#
#
# p =
#
#    -0.9445
#     0.1877
#
#
# p =
#
#    -3.4580
#    -2.1364
#
#
# p =
#
#    -0.4116
#     0.8429
#
#
# p =
#
#     0.9666
#     1.3079
#
#
# p =
#
#    -1.8341
#     2.0376
#
#
# p =
#
#    -2.3884
#     1.6281
#
#
# p =
#
#    -1.8447
#     2.1536
#
#
# p =
#
#    -1.9301
#     2.0592
#
#
# p =
#
#    -1.9642
#     2.0401
#
#
# p =
#
#    -1.6281
#     2.3961
#
#
# p =
#
#    -1.8943
#     1.9984
#
#
# p =
#
#     1.6281
#     2.3961
#
#
# p =
#
#     0.4623
#     0.8560
#
#
# p =
#
#     0.1562
#     0.9574
#
#
# p =
#
#     0.1557
#     0.9578
#
#
# p =
#
#     0.3211
#     0.9087
#
#
# p =
#
#     0.1970
#     0.8843
#
#
# p =
#
#     10
#     24
#
#
# p =
#
#    14.9250
#    71.7750
#
#
# p =
#
#    15.5750
#    68.9250
#
#
# p =
#
#    17.7000
#    76.2250
#
#
# p =
#
#    15.9000
#    68.3000
#
#
# p =
#
#    -0.0078
#     0.0078
#
#
# p =
#
#    -0.4688
#     0.5000
#
#
# p =
#
#    1.0e-03 *
#
#    -0.2064
#     0.2913
#
#
# p =
#
#    -0.0054
#     0.0050
#
#
# p =
#
#      0
#      0
#
#
# p =
#
#    1.0e-03 *
#
#    -0.3130
#     0.2746
#
#
# p =
#
#    -0.0687
#     0.0694
#
#
# p =
#
#    -0.0132
#     0.0135
#
#
# p =
#
#    -0.0352
#     0.0424
#
#
# p =
#
#    -0.0090
#     0.0089
#
#
# p =
#
#         1010
#         3945
#
#
# p =
#
#     0.0200
#     2.9350
#
#
# p =
#
#    34.7730
#    57.1860
#
#
# p =
#
#    -5.0364
#     4.9848
#
#
# p =
#
#    -5.0738
#     5.0465
#
#
# p =
#
#   -28.9825
#    30.7390
#
#
# p =
#
#   -18.5950
#    17.8100
#
#
# p =
#
#    -5.7349
#     5.6781
#
#
# p =
#
#    -0.0537
#     0.0520
#
#
# p =
#
#    1.0e-03 *
#
#    -0.1133
#     0.4899
#
#
# p =
#
#    1.0e-03 *
#
#     0.0819
#     0.3518
#
#
# p =
#
#    1.0e-03 *
#
#     0.1519
#     0.2882
#
#
# p =
#
#    -0.2422
#     0.2533
#
#
# p =
#
#     0.8370
#     1.1480
#
#
# p =
#
#     0.8370
#     1.1970
#
#
# p =
#
#     0.8140
#     1.1560
#
#
# p =
#
#     0.8700
#     1.1510
#
#
# p =
#
#     0.7965
#     1.1840
#
#
# p =
#
#     0.8030
#     1.1522
#
#
# p =
#
#    -0.2745
#     0.2860
#
#
# p =
#
#    -0.0203
#     0.0201
#
#
# p =
#
#    -0.0035
#     0.0031
#
#
# p =
#
#    -0.0098
#     0.0073
#
#
# p =
#
#    -0.0302
#     0.0294
#
#
# p =
#
#    -0.0016
#     0.0017
#
#
# p =
#
#    -0.0628
#     0.0604
#
#
# p =
#
#    -0.0139
#     0.0144
#
#
# p =
#
#    -0.0026
#     0.0023
#
#
# p =
#
#    -0.0292
#     0.0287
#
#
# p =
#
#    -0.0215
#     0.0229
#
#
# p =
#
#    -0.0317
#     0.0317
#
#
# p =
#
#    -0.0060
#     0.0062
#
#
# p =
#
#    -0.0094
#     0.0095
#
#
# p =
#
#    -0.0484
#     0.0477
#
#
# p =
#
#   405.1200
#   634.0300
#
#
# p =
#
#   405.1600
#   634.0850
#
#
# p =
#
#    41.6000
#   190.8000
#
#
# p =
#
#    1.0e+03 *
#
#     0.1698
#     1.2934
#
#
# p =
#
#   263.9750
#   576.6500
#
#
# p =
#
#     0.5225
#     1.1100
#
#
# p =
#
#    1.0e+04 *
#
#     1.0131
#     1.0162
#
#
# p =
#
#    -0.5300
#     0.5400
#
#
# p =
#
#    -1.0100
#     1.2100
#
#
# p =
#
#        10191
#        10244
#
#
# p =
#
#        10162
#        10198
#
#
# p =
#
#    -0.8300
#     0.9000
#
#
# p =
#
#    -0.6400
#     0.6475
#
#
# p =
#
#        10100
#        10160
#
#
# p =
#
#    14.4200
#    39.9450
#
#
# p =
#
#     5.8150
#    19.0850
#
#
# p =
#
#    67.7000
#   148.5000
#
#
# p =
#
#     5.9650
#    22.0850
#
#
# p =
#
#    -0.9352
#     0.8750
#
#
# p =
#
#    -0.3324
#     0.3473
#
#
# p =
#
#    -0.3792
#     0.3592
#
#
# p =
#
#    -0.3886
#     0.4010
#
#
# p =
#
#    -0.3379
#     0.3459
#
#
# p =
#
#    -0.3329
#     0.3401
#
#
# p =
#
#    -0.3514
#     0.3496
#
#
# p =
#
#    -0.0096
#     0.0069
#
#
# p =
#
#    -0.0069
#     0.0059
#
#
# p =
#
#    -0.0065
#     0.0054
#
#
# p =
#
#    -0.0096
#     0.0089
#
#
# p =
#
#    -0.0233
#     0.0288
#
#
# p =
#
#    -0.0077
#     0.0066
#
#
# p =
#
#    -0.0091
#     0.0084
#
#
# p =
#
#    -0.0057
#     0.0048
#
#
# p =
#
#    -0.0126
#     0.0119
#
#
# p =
#
#    -0.0059
#     0.0056
#
#
# p =
#
#    -0.1030
#     0.0980
#
#
# p =
#
#    -0.8598
#     0.8725
#
#
# p =
#
#    -0.6381
#     0.6753
#
#
# p =
#
#    -0.0973
#     0.0935
#
#
# p =
#
#    -1.3687
#     1.4264
#
#
# p =
#
#    39.6000
#    96.8500
#
#
# p =
#
#     5.1000
#     7.4100
#
#
# p =
#
#    35.7500
#    83.7500
#
#
# p =
#
#    -0.0236
#     0.0277
#
#
# p =
#
#    -0.0067
#     0.0073
#
#
# p =
#
#    -0.0127
#     0.0135
#
#
# p =
#
#    -0.0096
#     0.0106
#
#
# p =
#
#    30.8000
#    67.4500
#
#
# p =
#
#    1.0e+03 *
#
#    -1.2300
#     1.2145
#
#
# p =
#
#       -11546
#        11390
#
#
# p =
#
#    1.0e+03 *
#
#    -2.0575
#     1.8880
#
#
# p =
#
#   -738
#    786
#
#
# p =
#
#  -894.5000
#   865.0000
#
#
# p =
#
#        -1299
#         1173
#
#
# p =
#
#  -740.0000
#   679.5000
#
#
# p =
#
#        -1974
#         2057
#
#
# p =
#
#    1.0e+03 *
#
#    -1.7965
#     1.7175
#
#
# p =
#
#    1.0e+03 *
#
#    -3.1345
#     2.9000
#
#
# p =
#
#    1.0e+03 *
#
#    -4.5595
#     4.6480
#
#
# p =
#
#    1.0e+03 *
#
#    -5.6685
#     5.8500
#
#
# p =
#
#        -4797
#         4992
#
#
# p =
#
#  -800.5000
#   746.0000
#
#
# p =
#
#    1.0e+03 *
#
#    -1.4155
#     1.3265
#
#
# p =
#
#    1.0e+03 *
#
#    -1.2720
#     1.2475
#
#
# p =
#
#    -0.0025
#     0.0025
#
#
# p =
#
#    -0.0026
#     0.0028
#
#
# p =
#
#     23
#     83
#
#
# p =
#
#     23
#     84
#
#
# p =
#
#     1.2905
#     1.3295
#
#
# p =
#
#     1.2785
#     1.2890
#
#
# p =
#
#     1.2525
#     1.2820
#
#
# p =
#
#     1.2585
#     1.2800
#
#
# p =
#
#     1.2775
#     1.2900
#
#
# p =
#
#     1.2790
#     1.3270
#
#
# p =
#
#    -0.0795
#     0.1020
#
#
# p =
#
#    -0.0890
#     0.0912
#
#
# p =
#
#    -0.0872
#     0.0890
#
#
# p =
#
#    -0.1278
#     0.1413
#
#
# p =
#
#    -0.0779
#     0.0799
#
#
# p =
#
#    -0.0646
#     0.0717
#
#
# p =
#
#    -0.1051
#     0.1033
#
#
# p =
#
#    -0.1037
#     0.1064
#
#
# p =
#
#    -18
#     20
#
#
# p =
#
#    -4.7949
#     5.6235
#
#
# p =
#
#     1.2455
#     4.3860
#
#
# p =
#
#    -2.8881
#     3.3571
#
#
# p =
#
#     0.0370
#     5.7150
#
#
# p =
#
#    -2.5474
#     3.3783
#
#
# p =
#
#    -2.0831
#     1.3599
#
#
# p =
#
#      7
#     22
#
#
# p =
#
#      5
#     18
#
#
# p =
#
#      1
#      5
#
#
# p =
#
#     0.2000
#     1.0000
#
#
# p =
#
#     4.3000
#    12.9250
#
#
# p =
#
#     5.7000
#    14.4000
#
#
# p =
#
#     0.8650
#     1.2825
#
#
# p =
#
#     5.2000
#    21.4000
#
#
# p =
#
#     0.9260
#     1.2283
#
#
# p =
#
#     0.9358
#     1.4690
#
#
# p =
#
#     2.3000
#    12.0000
#
#
# p =
#
#     5.5000
#    20.2000
#
#
# p =
#
#     0.8340
#     1.4880
#
#
# p =
#
#     7.1000
#    26.3000
#
#
# p =
#
#     0.8928
#     1.1150
#
#
# p =
#
#    13.5000
#    34.6000
#
#
# p =
#
#    10.3000
#    35.0000
#
#
# p =
#
#     7.2000
#    23.6000
#
#
# p =
#
#     8.2000
#    31.1000
#
#
# p =
#
#      5
#      7
#
#
# p =
#
#      5
#      7
#
#
# p =
#
#     0.9100
#     1.2880
#
#
# p =
#
#     0.9350
#     1.1740
#
#
# p =
#
#     9.7000
#    30.0000
#
#
# p =
#
#     0.9130
#     1.2750
#
#
# p =
#
#     0.8500
#     1.1040
#
#
# p =
#
#     1.6500
#     3.2400
#
#
# p =
#
#     2.9500
#     3.3500
#
#
# p =
#
#     3.1100
#     3.5500
#
#
# p =
#
#     5.4000
#    11.2500
#
#
# p =
#
#     1.5500
#     3.8000
#
#
# p =
#
#     0.8000
#     3.1000
#
#
# p =
#
#     2.3000
#     4.6000
#
#
# p =
#
#     6.5000
#    13.1000
#
#
# p =
#
#    230
#    250
#
#
# p =
#
#   221.5000
#   268.0000
#
#
# p =
#
#    315
#    370
#
#
# p =
#
#    158
#    175
#
#
# p =
#
#   261.0000
#   311.3750
#
#
# p =
#
#    47.5470
#    63.1525
#
#
# p =
#
#    49.3418
#    65.6838
#
#
# p =
#
#      1434950
#      1532900
#
#
# p =
#
#   101.3300
#   102.8200
#
#
# p =
#
#   453.0200
#   483.3300
#
#
# p =
#
#    -5.4610
#     0.2759
#
#
# p =
#
#    -3.6500
#    -1.8000
#
#
# p =
#
#    -3.6228
#     3.0000
#
#
# p =
#
#   -16.0865
#     0.3879
#
#
# p =
#
#   277.7800
#   313.1300
#
#
# p =
#
#     3.3967
#     7.8073
#
#
# p =
#
#   -13.1555
#     6.7055
#
#
# p =
#
#   -10.9460
#    15.9410
#
#
# p =
#
#   -11.5412
#     5.6630
#
#
# p =
#
#      0
#      2
#
#
# p =
#
#     0.2000
#     0.9000
#
#
# p =
#
#    -0.4000
#     1.0000
#
#
# p =
#
#    -0.1000
#     1.4000
#
#
# p =
#
#     0.2000
#     1.4000
#
#
# p =
#
#     0.6000
#     2.5000
#
#
# p =
#
#     0.7000
#     3.3000
#
#
# p =
#
#     0.7000
#     3.4000
#
#
# p =
#
#    1.0e+03 *
#
#     1.6830
#     2.3435
#
#
# p =
#
#     71
#    178
#
#
# p =
#
#     20
#     77
#
#
# p =
#
#     10
#    113
#
#
# p =
#
#     40
#    147
#
#
# p =
#
#      7
#     51
#
#
# p =
#
#     23
#     86
#
#
# p =
#
#     30
#    103
#
#
# p =
#
#     37
#    108
#
#
# p =
#
#     88
#    241
#
#
# p =
#
#     31
#    116
#
#
# p =
#
#      5
#     18
#
#
# p =
#
#     23
#     44
#
#
# p =
#
#      3
#     20
#
#
# p =
#
#     12
#     31
#
#
# p =
#
#     13
#     60
#
#
# p =
#
#     5.2500
#    16.0000
#
#
# p =
#
#      5
#     23
#
#
# p =
#
#      8
#     21
#
#
# p =
#
#     12
#     30
#
#
# p =
#
#     8.6100
#    26.3800
#
#
# p =
#
#    71.3000
#   151.3000
#
#
# p =
#
#    37.0000
#    87.9000
#
#
# p =
#
#    55.5500
#   114.0000
#
#
# p =
#
#    35.8500
#    74.8000
#
#
# p =
#
#        10104
#        10204
#
#
# p =
#
#        10113
#        10169
#
#
# p =
#
#        10112
#        10167
#
#
# p =
#
#    77.0000
#   225.7500
#
#
# p =
#
#    76.0000
#   229.5000
#
#
# p =
#
#     71
#    218
#
#
# p =
#
#     74
#    215
#
#
# p =
#
#    -0.0264
#     0.0296
#
#
# p =
#
#    -0.0420
#     0.0473
#
#
# p =
#
#    -0.0041
#     0.0095
#
#
# p =
#
#    -0.0298
#     0.0239
#
#
# p =
#
#    -0.0303
#     0.0284
#
#
# p =
#
#    -0.0059
#     0.0157
#
#
# p =
#
#    -0.0189
#     0.0103
#
#
# p =
#
#    -0.0273
#     0.0282
#
#
# p =
#
#    -0.0058
#     0.0060
#
#
# p =
#
#    1.0e-03 *
#
#    -0.1687
#     0.0247
#
#
# p =
#
#  -116.0000
#   -37.5000
#
#
# p =
#
#   -178
#      5
#
#
# p =
#
#   -91.0000
#   -42.5000
#
#
# p =
#
#    -60
#    -47
#
#
# p =
#
#   -132
#    -35
#
#
# p =
#
#    -97
#    -30
#
#
# p =
#
#  -100.5000
#   -17.0000
#
#
# p =
#
#   -133
#    -30
#
#
# p =
#
#   -110
#    -26
#
#
# p =
#
#    -51
#    -30
#
#
# p =
#
#    -70
#    -44
#
#
# p =
#
#    -50
#    -35
#
#
# p =
#
#    -52
#    -28
#
#
# p =
#
#    -53
#    -31
#
#
# p =
#
#   -130
#    -32
#
#
# p =
#
#    -78
#    -55
#
#
# p =
#
#    31.3700
#    33.8600
#
#
# p =
#
#     3.8500
#   905.4650
#
#
# p =
#
#     2.5300
#   914.2100
#
#
# p =
#
#          0
#   780.1750
#
#
# p =
#
#          0
#   754.4900
#
#
# p =
#
#     4.9500
#   704.1100
#
#
# p =
#
#   262.5000
#   276.9950
#
#
# p =
#
#   345.9650
#   349.2200
#
#
# p =
#
#   148.3100
#   155.8950
#
#
# p =
#
#   266.1250
#   273.4950
#
#
# p =
#
#   278.6650
#   284.8150
#
#
# p =
#
#   286.8500
#   292.7300
#
#
# p =
#
#   177.3500
#   181.8600
#
#
# p =
#
#   384.7900
#   392.4300
#
#
# p =
#
#   355.6450
#   366.2550
#
#
# p =
#
#   155.2000
#   162.6000
#
#
# p =
#
#   358.9150
#   362.3950
#
#
# p =
#
#    52.1970
#    63.0655
#
#
# p =
#
#   347.2900
#   353.9850
#
#
# p =
#
#   175.6150
#   179.6200
#
#
# p =
#
#    -1.7500
#     4.4500
#
#
# p =
#
#          0
#     2.3000
#
#
# p =
#
#      0
#      2
#
#
# p =
#
#    -0.3960
#     0.3790
#
#
# p =
#
#          0
#     1.7500
#
#
# p =
#
#          0
#     1.7500
#
#
# p =
#
#      0
#      2
#
#
# p =
#
#    -0.5000
#     1.5000
#
#
# p =
#
#     -1
#      4
#
#
# p =
#
#    -0.1000
#     1.9000
#
#
# p =
#
#    -0.2290
#     0.2100
#
#
# p =
#
#    -0.5000
#     2.2500
#
#
# p =
#
#     0.0002
#     0.0010
#
#
# p =
#
#     0.0100
#     0.0108
#
#
# p =
#
#    1.0e-03 *
#
#    -0.3337
#     0.3951
#
#
# p =
#
#    -0.0035
#     0.0037
#
#
# p =
#
#    -0.0012
#     0.0011
#
#
# p =
#
#    1.0e-03 *
#
#    -0.9866
#     0.9569
#
#
# p =
#
#    1.0e-03 *
#
#    -0.1838
#     0.1733
#
#
# p =
#
#    -0.0024
#     0.0030
#
#
# p =
#
#    1.0e-03 *
#
#    -0.4305
#     0.4265
#
#
# p =
#
#    1.0e-03 *
#
#    -0.2866
#     0.2867
#
#
# p =
#
#    1.0e-03 *
#
#    -0.1711
#     0.1715
#
#
# p =
#
#    1.0e-03 *
#
#    -0.4161
#     0.3998
#
#
# p =
#
#    1.0e-03 *
#
#    -0.5550
#     0.5408
#
#
# p =
#
#    1.0e-03 *
#
#    -0.6443
#     0.5623
#
#
# p =
#
#    1.0e-03 *
#
#    -0.1508
#     0.1611
#
#
# p =
#
#    1.0e-03 *
#
#    -0.3243
#     0.3177
#
#
# p =
#
#    1.0e-03 *
#
#    -0.1394
#     0.1537
#
#
# p =
#
#    -0.0353
#     0.0486
#
#
# p =
#
#    -0.0073
#     0.0072
#
#
# p =
#
#    -0.0186
#     0.0220
#
#
# p =
#
#    -0.0075
#     0.0242
#
#
# p =
#
#   -91.5000
#   -74.0000
#
#
# p =
#
#   -205
#     90
#
#
# p =
#
#  -277.5000
#   -25.0000
#
#
# p =
#
#    -51
#    -15
#
#
# p =
#
#    -29
#     -1
#
#
# p =
#
#    -43
#     13
#
#
# p =
#
#    -31
#     -2
#
#
# p =
#
#    -31
#     -1
#
#
# p =
#
#    -67
#     11
#
#
# p =
#
#    -93
#     67
#
#
# p =
#
#    -21
#     -5
#
#
# p =
#
#    -31
#     -7
#
#
# p =
#
#    -37
#     -5
#
#
# p =
#
#    -31
#     -1
#
#
# p =
#
#    -39
#      3
#
#
# p =
#
#    -31
#      5
#
#
# p =
#
#    -37
#     13
#
#
# p =
#
#    -31
#      9
#
#
# p =
#
#    -37
#     -7
#
#
# p =
#
#    -29
#      9
#
#
# p =
#
#    -23
#     -5
#
#
# p =
#
#    -23
#     -3
#
#
# p =
#
#    -29
#     -5
#
#
# p =
#
#     0.5938
#     0.6406
#
#
# p =
#
#     0.7969
#     0.8359
#
#
# p =
#
#     0.6328
#     0.7266
#
#
# p =
#
#     0.6719
#     0.7188
#
#
# p =
#
#     0.7656
#     0.8516
#
#
# p =
#
#     0.5859
#     0.6484
#
#
# p =
#
#     0.7734
#     0.8125
#
#
# p =
#
#     0.8438
#     0.8828
#
#
# p =
#
#     1.0859
#     1.1641
#
#
# p =
#
#     0.9062
#     0.9844
#
#
# p =
#
#     0.9688
#     1.0312
#
#
# p =
#
#     0.9062
#     0.9609
#
#
# p =
#
#     0.8438
#     0.9453
#
#
# p =
#
#     0.7891
#     0.8359
#
#
# p =
#
#     0.7266
#     0.7812
#
#
# p =
#
#     1.0391
#     1.1094
#
#
# p =
#
#   -596
#   -271
#
#
# p =
#
#    -43
#     58
#
#
# p =
#
#   -663
#   -474
#
#
# p =
#
#         1802
#         1805
#
#
# p =
#
#         1438
#         1439
#
# [Distributional_Mean_norm_raw | ts=0]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=1]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=2]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=3]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=4]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=5]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=6]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=7]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=8]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=9]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=10]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=11]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=12]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=13]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=14]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=15]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=16]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=17]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=18]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=19]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=20]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=21]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=22]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=23]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=24]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=25]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=26]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=27]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=28]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=29]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=30]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=31]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=32]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=33]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=34]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=35]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=36]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=37]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=38]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=39]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=40]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=41]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=42]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=43]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=44]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=45]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=46]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=47]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=48]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=49]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=50]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=51]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=52]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=53]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=54]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=55]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=56]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=57]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=58]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=59]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=60]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=61]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=62]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=63]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=64]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=65]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=66]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=67]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=68]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=69]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=70]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=71]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=72]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=73]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=74]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=75]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=76]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=77]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=78]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=79]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=80]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=81]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=82]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=83]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=84]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=85]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=86]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=87]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=88]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=89]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=90]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=91]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=92]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=93]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=94]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=95]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=96]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=97]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=98]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=99]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=100]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=101]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=102]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=103]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=104]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=105]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=106]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=107]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=108]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=109]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=110]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=111]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=112]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=113]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=114]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=115]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=116]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=117]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=118]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=119]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=120]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=121]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=122]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=123]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=124]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=125]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=126]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=127]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=128]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=129]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=130]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=131]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=132]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=133]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=134]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=135]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=136]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=137]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=138]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=139]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=140]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=141]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=142]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=143]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=144]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=145]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=146]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=147]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=148]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=149]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=150]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=151]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=152]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=153]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=154]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=155]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=156]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=157]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=158]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=159]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=160]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=161]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=162]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=163]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=164]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=165]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=166]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=167]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=168]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=169]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=170]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=171]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=172]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=173]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=174]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=175]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=176]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=177]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=178]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=179]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=180]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=181]  RelErr% = nan
# [Distributional_Mean_norm_raw | ts=182]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=183]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=184]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=185]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=186]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=187]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=188]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=189]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=190]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=191]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=192]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=193]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=194]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=195]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=196]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=197]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=198]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=199]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=200]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=201]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=202]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=203]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=204]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=205]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=206]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=207]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=208]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=209]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=210]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=211]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=212]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=213]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=214]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=215]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=216]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=217]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=218]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=219]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=220]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=221]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=222]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=223]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=224]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=225]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=226]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=227]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=228]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=229]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=230]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=231]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=232]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=233]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=234]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=235]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=236]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=237]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=238]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=239]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=240]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=241]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=242]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=243]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=244]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=245]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=246]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=247]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=248]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=249]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=250]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=251]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=252]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=253]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=254]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=255]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=256]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=257]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=258]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=259]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=260]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=261]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=262]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=263]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=264]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=265]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=266]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=267]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=268]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=269]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=270]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=271]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=272]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=273]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=274]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=275]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=276]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=277]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=278]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=279]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=280]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=281]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=282]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=283]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=284]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=285]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=286]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=287]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=288]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=289]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=290]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=291]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=292]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=293]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=294]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=295]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=296]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=297]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=298]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=299]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=300]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=301]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=302]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=303]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=304]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=305]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=306]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=307]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=308]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=309]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=310]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=311]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=312]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=313]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=314]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=315]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=316]  RelErr% = 0.00
# [Distributional_Mean_norm_raw | ts=317]  RelErr% = 0.00
# ...
# [Distributional_Mean_midhinge_raw | ts=734]  RelErr% = 1.04
# [Distributional_Mean_midhinge_raw | ts=735]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=736]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=737]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=738]  RelErr% = 3.83
# [Distributional_Mean_midhinge_raw | ts=739]  RelErr% = 1.13
# [Distributional_Mean_midhinge_raw | ts=740]  RelErr% = 1.24
# [Distributional_Mean_midhinge_raw | ts=741]  RelErr% = 0.47
# [Distributional_Mean_midhinge_raw | ts=742]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=743]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=744]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=745]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=746]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=747]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=748]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=749]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=750]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=751]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=752]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=753]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=754]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=755]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=756]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=757]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=758]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=759]  RelErr% = 1.58
# [Distributional_Mean_midhinge_raw | ts=760]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=761]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=762]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=763]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=764]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=765]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=766]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=767]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=768]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=769]  RelErr% = 0.89
# [Distributional_Mean_midhinge_raw | ts=770]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=771]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=772]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=773]  RelErr% = 1.30
# [Distributional_Mean_midhinge_raw | ts=774]  RelErr% = 1.06
# [Distributional_Mean_midhinge_raw | ts=775]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=776]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=777]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=778]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=779]  RelErr% = 0.03
# [Distributional_Mean_midhinge_raw | ts=780]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=781]  RelErr% = 0.02
# [Distributional_Mean_midhinge_raw | ts=782]  RelErr% = 0.25
# [Distributional_Mean_midhinge_raw | ts=783]  RelErr% = 0.16
# [Distributional_Mean_midhinge_raw | ts=784]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=785]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=786]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=787]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=788]  RelErr% = 0.15
# [Distributional_Mean_midhinge_raw | ts=789]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=790]  RelErr% = 0.02
# [Distributional_Mean_midhinge_raw | ts=791]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=792]  RelErr% = 0.01
# [Distributional_Mean_midhinge_raw | ts=793]  RelErr% = 0.01
# [Distributional_Mean_midhinge_raw | ts=794]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=795]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=796]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=797]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=798]  RelErr% = 0.01
# [Distributional_Mean_midhinge_raw | ts=799]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=800]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=801]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=802]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=803]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=804]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=805]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=806]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=807]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=808]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=809]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=810]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=811]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=812]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=813]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=814]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=815]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=816]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=817]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=818]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=819]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=820]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=821]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=822]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=823]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=824]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=825]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=826]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=827]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=828]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=829]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=830]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=831]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=832]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=833]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=834]  RelErr% = 0.13
# [Distributional_Mean_midhinge_raw | ts=835]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=836]  RelErr% = 0.32
# [Distributional_Mean_midhinge_raw | ts=837]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=838]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=839]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=840]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=841]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=842]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=843]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=844]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=845]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=846]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=847]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=848]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=849]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=850]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=851]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=852]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=853]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=854]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=855]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=856]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=857]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=858]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=859]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=860]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=861]  RelErr% = 1.18
# [Distributional_Mean_midhinge_raw | ts=862]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=863]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=864]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=865]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=866]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=867]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=868]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=869]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=870]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=871]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=872]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=873]  RelErr% = 0.08
# [Distributional_Mean_midhinge_raw | ts=874]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=875]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=876]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=877]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=878]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=879]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=880]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=881]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=882]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=883]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=884]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=885]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=886]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=887]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=888]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=889]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=890]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=891]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=892]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=893]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=894]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=895]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=896]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=897]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=898]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=899]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=900]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=901]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=902]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=903]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=904]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=905]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=906]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=907]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=908]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=909]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=910]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=911]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=912]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=913]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=914]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=915]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=916]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=917]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=918]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=919]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=920]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=921]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=922]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=923]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=924]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=925]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=926]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=927]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=928]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=929]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=930]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=931]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=932]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=933]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=934]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=935]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=936]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=937]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=938]  RelErr% = 0.04
# [Distributional_Mean_midhinge_raw | ts=939]  RelErr% = 1.01
# [Distributional_Mean_midhinge_raw | ts=940]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=941]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=942]  RelErr% = 0.14
# [Distributional_Mean_midhinge_raw | ts=943]  RelErr% = 1.32
# [Distributional_Mean_midhinge_raw | ts=944]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=945]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=946]  RelErr% = 0.80
# [Distributional_Mean_midhinge_raw | ts=947]  RelErr% = 0.16
# [Distributional_Mean_midhinge_raw | ts=948]  RelErr% = 0.45
# [Distributional_Mean_midhinge_raw | ts=949]  RelErr% = 0.56
# [Distributional_Mean_midhinge_raw | ts=950]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=951]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=952]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=953]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=954]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=955]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=956]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=957]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=958]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=959]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=960]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=961]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=962]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=963]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=964]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=965]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=966]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=967]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=968]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=969]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=970]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=971]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=972]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=973]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=974]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=975]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=976]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=977]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=978]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=979]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=980]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=981]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=982]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=983]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=984]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=985]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=986]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=987]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=988]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=989]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=990]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=991]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=992]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=993]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=994]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=995]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=996]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=997]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=998]  RelErr% = 0.00
# [Distributional_Mean_midhinge_raw | ts=999]  RelErr% = 0.00

# %%
[mean_compares[p]['r'] for p in mean_compares]
# Out:
# [np.float64(1.0),
#  np.float64(0.9999999999999994),
#  np.float64(0.9999999999999998),
#  np.float64(1.0),
#  np.float64(0.9999999999926217)]

# %%
minmax_evals = eval_comparison_mean("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/distributional.yaml", empirical1000)
minmax_compares = compare_outputs(minmax_evals)
# Out:
# Loading configuration file: distributional.yaml
#
# *** Importing module Distributional ***
#
# Adding operation Distributional_MinMax_max with params {'minOrMax': 'max'} (Z-score=True)
# Adding operation Distributional_MinMax_min with params {'minOrMax': 'min'} (Z-score=True)
# Evalutating Distributional_MinMax_max
# Comparing to DN_MinMax
# Evalutating Distributional_MinMax_min
# Comparing to DN_MinMax
# [Distributional_MinMax_max | ts=0]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=1]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=2]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=3]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=4]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=5]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=6]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=7]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=8]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=9]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=10]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=11]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=12]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=13]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=14]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=15]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=16]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=17]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=18]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=19]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=20]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=21]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=22]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=23]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=24]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=25]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=26]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=27]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=28]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=29]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=30]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=31]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=32]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=33]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=34]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=35]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=36]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=37]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=38]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=39]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=40]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=41]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=42]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=43]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=44]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=45]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=46]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=47]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=48]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=49]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=50]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=51]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=52]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=53]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=54]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=55]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=56]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=57]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=58]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=59]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=60]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=61]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=62]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=63]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=64]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=65]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=66]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=67]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=68]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=69]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=70]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=71]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=72]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=73]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=74]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=75]  RelErr% = 0.00
# [Distributional_MinMax_max | ts=76]  RelErr% = 0.00
# [Distributional_MinMax_max | ts