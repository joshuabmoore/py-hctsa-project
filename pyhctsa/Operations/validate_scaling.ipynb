# %%
import numpy as np
import pandas as pd
import matlab.engine
import yaml
import time
import nolitsa
import importlib
import pathlib
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
from scipy.stats import pearsonr
from loguru import logger
from Entropy import ApproximateEntropy
from functools import partial, wraps
from itertools import product
import os
from typing import Union
from numbers import Number
from utilities import ZScore

# %%
import importlib
import Nonlinear
importlib.reload(Nonlinear)
# Out:
# <module 'Nonlinear' from '/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Operations/Nonlinear.py'>

# %%
def compare_outputs(outputs, exclude_keys=None):
    """
    Compare MATLAB and Python feature outputs, computing relative errors
    and Pearson correlations.

    Parameters
    ----------
    outputs : dict
        Nested dictionary of feature values with structure:
        {
            feature_name: {
                ts_id: {
                    'matlab': scalar_or_dict,
                    'python': scalar_or_dict
                }
            }
        }
    exclude_keys : set or list, optional
        Set or list of keys (feature names or feature.subkey) to exclude from comparison.

    Returns
    -------
    results : dict
        Dictionary mapping feature (or subfeature) names to correlation and stats:
        {
            'feature.subkey': {
                'r': float,
                'pval': float,
                'res_py': ndarray,
                'res_matlab': ndarray,
                'max_rel_err': float
            }
        }
    """
    if exclude_keys is None:
        exclude_keys = set()
    else:
        exclude_keys = set(exclude_keys)

    flat = {}
    for feat, ts_dict in outputs.items():
        for ts, run in ts_dict.items():
            ml = run['matlab']
            py = run['python']
            if isinstance(ml, dict) and isinstance(py, dict):
                for k, mlv in ml.items():
                    slot = f"{feat}.{k}"
                    if slot in exclude_keys or k not in py:
                        continue
                    pyv = py[k]
                    flat.setdefault(slot, {})[ts] = (mlv, pyv)
            elif isinstance(ml, Number) and isinstance(py, Number):
                if feat in exclude_keys:
                    continue
                flat.setdefault(feat, {})[ts] = (ml, py)
            else:
                raise ValueError(f"Feature {feat}@{ts} is neither both scalars nor both dicts.")

    results = {}
    for slot, tsmap in flat.items():
        ml_vals, py_vals = [], []
        rel_errors = []

        for ts, (mlv, pyv) in tsmap.items():
            ml_vals.append(mlv)
            py_vals.append(pyv)

            both_finite = np.isfinite(mlv) and np.isfinite(pyv)
            both_nan = np.isnan(mlv) and np.isnan(pyv)
            both_posinf = (mlv == np.inf) and (pyv == np.inf)
            both_neginf = (mlv == -np.inf) and (pyv == -np.inf)

            if both_finite:
                if mlv == 0:
                    rel_err = np.nan
                else:
                    rel_err = abs(mlv - pyv) / abs(mlv) * 100
                    rel_errors.append(rel_err)
                print(f"[{slot} | ts={ts}]  RelErr% = {rel_err:.2f}")
            elif both_nan or both_posinf or both_neginf:
                print(f"[{slot} | ts={ts}]  RelErr% = MATCH (both non-finite)")
            else:
                print(f"[{slot} | ts={ts}]  RelErr% = NaN (mismatch in finiteness)")

        ml_arr = np.array(ml_vals, dtype=float)
        py_arr = np.array(py_vals, dtype=float)
        finite_mask = np.isfinite(ml_arr) & np.isfinite(py_arr)

        if finite_mask.sum() > 1 and ml_arr[finite_mask].std() and py_arr[finite_mask].std():
            r, p = pearsonr(ml_arr[finite_mask], py_arr[finite_mask])
        else:
            r, p = np.nan, np.nan

        max_rel_err = np.nanmax(rel_errors) if rel_errors else np.nan

        results[slot] = {
            'r': r,
            'pval': p,
            'res_py': py_arr,
            'res_matlab': ml_arr,
            'max_rel_err': max_rel_err
        }

    return results

# %%
empirical1000 = []
with open("../../../empirical1000/hctsa_timeseries-data.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        # Convert each element from string to float (or int if appropriate)
        try:
            time_series = [float(value) for value in row if value != '']
            empirical1000.append(time_series)
        except ValueError as e:
            print(f"Skipping row due to conversion error: {row}")
            continue

# %%
from Scaling import FastDFA

# %%
FastDFA(np.array(empirical1000[100]))
# Out:
# np.float64(1.2568977625781386)

# %%
def load_yaml(file):
    print(f"Loading configuration file: {file.split('/')[-1]}")
    funcs = {}
    with open(file) as f:
        yf = yaml.load(f, Loader=yaml.FullLoader)

    for module_name in yf:
        print(f"\n*** Importing module {module_name} *** \n")
        module = importlib.import_module(module_name)
        for function_name in yf[module_name]:
            # Get the function's configuration dictionary
            function_config = yf[module_name][function_name]
            # If no configs section exists or if it's empty, use a list with single empty dict
            if ('configs' not in function_config or function_config.get('configs') is None or 
                function_config.get('configs') == []):
                configs = [{}]
            else:
                configs = function_config.get('configs', [{}])

            for params in configs:
                # Handle the case where params is None
                if params is None:
                    params = {}
                    
                zscore_first = params.pop("zscore", False)
                param_keys, param_vals = zip(*params.items()) if params else ([], [])
                
                param_combinations = [dict(zip(param_keys, values)) 
                                   for values in product(*[v if isinstance(v, list) 
                                                        else [v] for v in param_vals])]
                
                # If no parameter combinations were generated, add empty dict
                if not param_combinations:
                    param_combinations = [{}]
                
                # create a function for each parameter combination
                for param_set in param_combinations:
                    feature_name = (f"{module_name}_{function_name}_" + 
                                  "_".join(f"{v}" for k, v in param_set.items())
                                  if param_set else f"{module_name}_{function_name}")
                    if not zscore_first:
                        feature_name += "_raw"
                    
                    print(f"Adding operation {feature_name} with params {param_set} "
                          f"(Z-score={zscore_first})")
                    
                    base_func = partial(getattr(module, function_name), **param_set)
                    if zscore_first:
                        base_func = zscore_decorator(base_func)
                    
                    # return the MATLAB callable corresponding to the python implementation for direct comparison
                    # make sure to check whethe the data needs to be zscored when calling the MATLAB func, cannot be wrapped as it is not a python function
                    # so needs to be done manually when calling the function.
                    hctsa_name = function_config.get('hctsa_name')
                    hctsa_callable = eval(f"eng.{hctsa_name}")

                    # keep ordered args only for testing YAML otherwise bloats
                    funcs[feature_name] = {'callable': base_func, 'params': param_set, 'hctsa_name': function_config.get('hctsa_name'), 
                                           'matlab_callable': hctsa_callable, 'isZscore': zscore_first, 'ordered_args': function_config.get('ordered_args')}
                    
    return funcs

# %%
def eval_comparison(yaml, data):
    func_dict = load_yaml(yaml)
    func_res = dict()
    for func in func_dict:
        print(f"Evalutating {func}")
        f = func_dict[func]
        python_func = f['callable']
        matlab_func = f['matlab_callable']
        hctsa_name = f['hctsa_name']
        isZscore = f['isZscore']
        params = f['params']
        ordered_args = []
        if params:
            order = f['ordered_args']
            ordered_args = [params[k] for k in order]
            
        print(f"Comparing to {hctsa_name}")
        res = dict()
        for i in range(len(data)):
            x = np.array(data[i]).reshape(-1, 1)
            matlab_eval = matlab_func(ZScore(matlab.double(x)), *ordered_args) if isZscore else matlab_func(matlab.double(x), ordered_args)
            python_eval = python_func(x)
            res[i] = {'matlab': matlab_eval, 'python': python_eval}
        func_res[func] = res
    return func_res

# %%
eng = matlab.engine.start_matlab()

# %%
proj_root = pathlib.Path("/Users/jmoo2880/Documents/hctsa")
eng.addpath(eng.genpath(str(proj_root)), nargout=0)
def zscore_decorator(func):
    @wraps(func)
    def wrapper(y, *args, **kwargs):
        y = ZScore(y)
        return func(y, *args, **kwargs)
    return wrapper

def range_constructor(loader, node):
    start, end = loader.construct_sequence(node)
    return list(range(start, end+1))
yaml.add_constructor("!range", range_constructor)

# %%
fdfa_res = eval_comparison("/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Configurations/scaling.yaml", empirical1000)
# Out:
# Loading configuration file: scaling.yaml
#
# *** Importing module Scaling ***
#
# Adding operation Scaling_FastDFA with params {} (Z-score=True)
# Evalutating Scaling_FastDFA
# Comparing to SC_fastdfa

# %%
fdfa_res['Scaling_FastDFA'][190]
# Out:
# {'matlab': 0.8588145412460522, 'python': np.float64(0.8588145412460509)}

# %%
fdfa_res_compare = compare_outputs(fdfa_res)
# Out:
# [Scaling_FastDFA | ts=0]  RelErr% = 0.00
# [Scaling_FastDFA | ts=1]  RelErr% = 0.00
# [Scaling_FastDFA | ts=2]  RelErr% = 0.00
# [Scaling_FastDFA | ts=3]  RelErr% = 0.00
# [Scaling_FastDFA | ts=4]  RelErr% = 0.00
# [Scaling_FastDFA | ts=5]  RelErr% = 0.00
# [Scaling_FastDFA | ts=6]  RelErr% = 0.00
# [Scaling_FastDFA | ts=7]  RelErr% = 0.00
# [Scaling_FastDFA | ts=8]  RelErr% = 0.00
# [Scaling_FastDFA | ts=9]  RelErr% = 0.00
# [Scaling_FastDFA | ts=10]  RelErr% = 0.00
# [Scaling_FastDFA | ts=11]  RelErr% = 0.00
# [Scaling_FastDFA | ts=12]  RelErr% = 0.00
# [Scaling_FastDFA | ts=13]  RelErr% = 0.00
# [Scaling_FastDFA | ts=14]  RelErr% = 0.00
# [Scaling_FastDFA | ts=15]  RelErr% = 0.00
# [Scaling_FastDFA | ts=16]  RelErr% = 0.00
# [Scaling_FastDFA | ts=17]  RelErr% = 0.00
# [Scaling_FastDFA | ts=18]  RelErr% = 0.00
# [Scaling_FastDFA | ts=19]  RelErr% = 0.00
# [Scaling_FastDFA | ts=20]  RelErr% = 0.00
# [Scaling_FastDFA | ts=21]  RelErr% = 0.00
# [Scaling_FastDFA | ts=22]  RelErr% = 0.00
# [Scaling_FastDFA | ts=23]  RelErr% = 0.00
# [Scaling_FastDFA | ts=24]  RelErr% = 0.00
# [Scaling_FastDFA | ts=25]  RelErr% = 0.00
# [Scaling_FastDFA | ts=26]  RelErr% = 0.00
# [Scaling_FastDFA | ts=27]  RelErr% = 0.00
# [Scaling_FastDFA | ts=28]  RelErr% = 0.00
# [Scaling_FastDFA | ts=29]  RelErr% = 0.00
# [Scaling_FastDFA | ts=30]  RelErr% = 0.00
# [Scaling_FastDFA | ts=31]  RelErr% = 0.00
# [Scaling_FastDFA | ts=32]  RelErr% = 0.00
# [Scaling_FastDFA | ts=33]  RelErr% = 0.00
# [Scaling_FastDFA | ts=34]  RelErr% = 0.00
# [Scaling_FastDFA | ts=35]  RelErr% = 0.00
# [Scaling_FastDFA | ts=36]  RelErr% = 0.00
# [Scaling_FastDFA | ts=37]  RelErr% = 0.00
# [Scaling_FastDFA | ts=38]  RelErr% = 0.00
# [Scaling_FastDFA | ts=39]  RelErr% = 0.00
# [Scaling_FastDFA | ts=40]  RelErr% = 0.00
# [Scaling_FastDFA | ts=41]  RelErr% = 0.00
# [Scaling_FastDFA | ts=42]  RelErr% = 0.00
# [Scaling_FastDFA | ts=43]  RelErr% = 0.00
# [Scaling_FastDFA | ts=44]  RelErr% = 0.00
# [Scaling_FastDFA | ts=45]  RelErr% = 0.00
# [Scaling_FastDFA | ts=46]  RelErr% = 0.00
# [Scaling_FastDFA | ts=47]  RelErr% = 0.00
# [Scaling_FastDFA | ts=48]  RelErr% = 0.00
# [Scaling_FastDFA | ts=49]  RelErr% = 0.00
# [Scaling_FastDFA | ts=50]  RelErr% = 0.00
# [Scaling_FastDFA | ts=51]  RelErr% = 0.00
# [Scaling_FastDFA | ts=52]  RelErr% = 0.00
# [Scaling_FastDFA | ts=53]  RelErr% = 0.00
# [Scaling_FastDFA | ts=54]  RelErr% = 0.00
# [Scaling_FastDFA | ts=55]  RelErr% = 0.00
# [Scaling_FastDFA | ts=56]  RelErr% = 0.00
# [Scaling_FastDFA | ts=57]  RelErr% = 0.00
# [Scaling_FastDFA | ts=58]  RelErr% = 0.00
# [Scaling_FastDFA | ts=59]  RelErr% = 0.00
# [Scaling_FastDFA | ts=60]  RelErr% = 0.00
# [Scaling_FastDFA | ts=61]  RelErr% = 0.00
# [Scaling_FastDFA | ts=62]  RelErr% = 0.00
# [Scaling_FastDFA | ts=63]  RelErr% = 0.00
# [Scaling_FastDFA | ts=64]  RelErr% = 0.00
# [Scaling_FastDFA | ts=65]  RelErr% = 0.00
# [Scaling_FastDFA | ts=66]  RelErr% = 0.00
# [Scaling_FastDFA | ts=67]  RelErr% = 0.00
# [Scaling_FastDFA | ts=68]  RelErr% = 0.00
# [Scaling_FastDFA | ts=69]  RelErr% = 0.00
# [Scaling_FastDFA | ts=70]  RelErr% = 0.00
# [Scaling_FastDFA | ts=71]  RelErr% = 0.00
# [Scaling_FastDFA | ts=72]  RelErr% = 0.00
# [Scaling_FastDFA | ts=73]  RelErr% = 0.00
# [Scaling_FastDFA | ts=74]  RelErr% = 0.00
# [Scaling_FastDFA | ts=75]  RelErr% = 0.00
# [Scaling_FastDFA | ts=76]  RelErr% = 0.00
# [Scaling_FastDFA | ts=77]  RelErr% = 0.00
# [Scaling_FastDFA | ts=78]  RelErr% = 0.00
# [Scaling_FastDFA | ts=79]  RelErr% = 0.00
# [Scaling_FastDFA | ts=80]  RelErr% = 0.00
# [Scaling_FastDFA | ts=81]  RelErr% = 0.00
# [Scaling_FastDFA | ts=82]  RelErr% = 0.00
# [Scaling_FastDFA | ts=83]  RelErr% = 0.00
# [Scaling_FastDFA | ts=84]  RelErr% = 0.00
# [Scaling_FastDFA | ts=85]  RelErr% = 0.00
# [Scaling_FastDFA | ts=86]  RelErr% = 0.00
# [Scaling_FastDFA | ts=87]  RelErr% = 0.00
# [Scaling_FastDFA | ts=88]  RelErr% = 0.00
# [Scaling_FastDFA | ts=89]  RelErr% = 0.00
# [Scaling_FastDFA | ts=90]  RelErr% = 0.00
# [Scaling_FastDFA | ts=91]  RelErr% = 0.00
# [Scaling_FastDFA | ts=92]  RelErr% = 0.00
# [Scaling_FastDFA | ts=93]  RelErr% = 0.00
# [Scaling_FastDFA | ts=94]  RelErr% = 0.00
# [Scaling_FastDFA | ts=95]  RelErr% = 0.00
# [Scaling_FastDFA | ts=96]  RelErr% = 0.00
# [Scaling_FastDFA | ts=97]  RelErr% = 0.00
# [Scaling_FastDFA | ts=98]  RelErr% = 0.00
# [Scaling_FastDFA | ts=99]  RelErr% = 0.00
# [Scaling_FastDFA | ts=100]  RelErr% = 0.00
# [Scaling_FastDFA | ts=101]  RelErr% = 0.00
# [Scaling_FastDFA | ts=102]  RelErr% = 0.00
# [Scaling_FastDFA | ts=103]  RelErr% = 0.00
# [Scaling_FastDFA | ts=104]  RelErr% = 0.00
# [Scaling_FastDFA | ts=105]  RelErr% = 0.00
# [Scaling_FastDFA | ts=106]  RelErr% = 0.00
# [Scaling_FastDFA | ts=107]  RelErr% = 0.00
# [Scaling_FastDFA | ts=108]  RelErr% = 0.00
# [Scaling_FastDFA | ts=109]  RelErr% = 0.00
# [Scaling_FastDFA | ts=110]  RelErr% = 0.00
# [Scaling_FastDFA | ts=111]  RelErr% = 0.00
# [Scaling_FastDFA | ts=112]  RelErr% = 0.00
# [Scaling_FastDFA | ts=113]  RelErr% = 0.00
# [Scaling_FastDFA | ts=114]  RelErr% = 0.00
# [Scaling_FastDFA | ts=115]  RelErr% = 0.00
# [Scaling_FastDFA | ts=116]  RelErr% = 0.00
# [Scaling_FastDFA | ts=117]  RelErr% = 0.00
# [Scaling_FastDFA | ts=118]  RelErr% = 0.00
# [Scaling_FastDFA | ts=119]  RelErr% = 0.00
# [Scaling_FastDFA | ts=120]  RelErr% = 0.00
# [Scaling_FastDFA | ts=121]  RelErr% = 0.00
# [Scaling_FastDFA | ts=122]  RelErr% = 0.00
# [Scaling_FastDFA | ts=123]  RelErr% = 0.00
# [Scaling_FastDFA | ts=124]  RelErr% = 0.00
# [Scaling_FastDFA | ts=125]  RelErr% = 0.00
# [Scaling_FastDFA | ts=126]  RelErr% = 0.00
# [Scaling_FastDFA | ts=127]  RelErr% = 0.00
# [Scaling_FastDFA | ts=128]  RelErr% = 0.00
# [Scaling_FastDFA | ts=129]  RelErr% = 0.00
# [Scaling_FastDFA | ts=130]  RelErr% = 0.00
# [Scaling_FastDFA | ts=131]  RelErr% = 0.00
# [Scaling_FastDFA | ts=132]  RelErr% = 0.00
# [Scaling_FastDFA | ts=133]  RelErr% = 0.00
# [Scaling_FastDFA | ts=134]  RelErr% = 0.00
# [Scaling_FastDFA | ts=135]  RelErr% = 0.00
# [Scaling_FastDFA | ts=136]  RelErr% = 0.00
# [Scaling_FastDFA | ts=137]  RelErr% = 0.00
# [Scaling_FastDFA | ts=138]  RelErr% = 0.00
# [Scaling_FastDFA | ts=139]  RelErr% = 0.00
# [Scaling_FastDFA | ts=140]  RelErr% = 0.00
# [Scaling_FastDFA | ts=141]  RelErr% = 0.00
# [Scaling_FastDFA | ts=142]  RelErr% = 0.00
# [Scaling_FastDFA | ts=143]  RelErr% = 0.00
# [Scaling_FastDFA | ts=144]  RelErr% = 0.00
# [Scaling_FastDFA | ts=145]  RelErr% = 0.00
# [Scaling_FastDFA | ts=146]  RelErr% = 0.00
# [Scaling_FastDFA | ts=147]  RelErr% = 0.00
# [Scaling_FastDFA | ts=148]  RelErr% = 0.00
# [Scaling_FastDFA | ts=149]  RelErr% = 0.00
# [Scaling_FastDFA | ts=150]  RelErr% = 0.00
# [Scaling_FastDFA | ts=151]  RelErr% = 0.00
# [Scaling_FastDFA | ts=152]  RelErr% = 0.00
# [Scaling_FastDFA | ts=153]  RelErr% = 0.00
# [Scaling_FastDFA | ts=154]  RelErr% = 0.00
# [Scaling_FastDFA | ts=155]  RelErr% = 0.00
# [Scaling_FastDFA | ts=156]  RelErr% = 0.00
# [Scaling_FastDFA | ts=157]  RelErr% = 0.00
# [Scaling_FastDFA | ts=158]  RelErr% = 0.00
# [Scaling_FastDFA | ts=159]  RelErr% = 0.00
# [Scaling_FastDFA | ts=160]  RelErr% = 0.00
# [Scaling_FastDFA | ts=161]  RelErr% = 0.00
# [Scaling_FastDFA | ts=162]  RelErr% = 0.00
# [Scaling_FastDFA | ts=163]  RelErr% = 0.00
# [Scaling_FastDFA | ts=164]  RelErr% = 0.00
# [Scaling_FastDFA | ts=165]  RelErr% = 0.00
# [Scaling_FastDFA | ts=166]  RelErr% = 0.00
# [Scaling_FastDFA | ts=167]  RelErr% = 0.00
# [Scaling_FastDFA | ts=168]  RelErr% = 0.00
# [Scaling_FastDFA | ts=169]  RelErr% = 0.00
# [Scaling_FastDFA | ts=170]  RelErr% = 0.00
# [Scaling_FastDFA | ts=171]  RelErr% = 0.00
# [Scaling_FastDFA | ts=172]  RelErr% = 0.00
# [Scaling_FastDFA | ts=173]  RelErr% = 0.00
# [Scaling_FastDFA | ts=174]  RelErr% = 0.00
# [Scaling_FastDFA | ts=175]  RelErr% = 0.00
# [Scaling_FastDFA | ts=176]  RelErr% = 0.00
# [Scaling_FastDFA | ts=177]  RelErr% = 0.00
# [Scaling_FastDFA | ts=178]  RelErr% = 0.00
# [Scaling_FastDFA | ts=179]  RelErr% = 0.00
# [Scaling_FastDFA | ts=180]  RelErr% = 0.00
# [Scaling_FastDFA | ts=181]  RelErr% = 0.00
# [Scaling_FastDFA | ts=182]  RelErr% = 0.00
# [Scaling_FastDFA | ts=183]  RelErr% = 0.00
# [Scaling_FastDFA | ts=184]  RelErr% = 0.00
# [Scaling_FastDFA | ts=185]  RelErr% = 0.00
# [Scaling_FastDFA | ts=186]  RelErr% = 0.00
# [Scaling_FastDFA | ts=187]  RelErr% = 0.00
# [Scaling_FastDFA | ts=188]  RelErr% = 0.00
# [Scaling_FastDFA | ts=189]  RelErr% = 0.00
# [Scaling_FastDFA | ts=190]  RelErr% = 0.00
# [Scaling_FastDFA | ts=191]  RelErr% = 0.00
# [Scaling_FastDFA | ts=192]  RelErr% = 0.00
# [Scaling_FastDFA | ts=193]  RelErr% = 0.00
# [Scaling_FastDFA | ts=194]  RelErr% = 0.00
# [Scaling_FastDFA | ts=195]  RelErr% = 0.00
# [Scaling_FastDFA | ts=196]  RelErr% = 0.00
# [Scaling_FastDFA | ts=197]  RelErr% = 0.00
# [Scaling_FastDFA | ts=198]  RelErr% = 0.00
# [Scaling_FastDFA | ts=199]  RelErr% = 0.00
# [Scaling_FastDFA | ts=200]  RelErr% = 0.00
# [Scaling_FastDFA | ts=201]  RelErr% = 0.00
# [Scaling_FastDFA | ts=202]  RelErr% = 0.00
# [Scaling_FastDFA | ts=203]  RelErr% = 0.00
# [Scaling_FastDFA | ts=204]  RelErr% = 0.00
# [Scaling_FastDFA | ts=205]  RelErr% = 0.00
# [Scaling_FastDFA | ts=206]  RelErr% = 0.00
# [Scaling_FastDFA | ts=207]  RelErr% = 0.00
# [Scaling_FastDFA | ts=208]  RelErr% = 0.00
# [Scaling_FastDFA | ts=209]  RelErr% = 0.00
# [Scaling_FastDFA | ts=210]  RelErr% = 0.00
# [Scaling_FastDFA | ts=211]  RelErr% = 0.00
# [Scaling_FastDFA | ts=212]  RelErr% = 0.00
# [Scaling_FastDFA | ts=213]  RelErr% = 0.00
# [Scaling_FastDFA | ts=214]  RelErr% = 0.00
# [Scaling_FastDFA | ts=215]  RelErr% = 0.00
# [Scaling_FastDFA | ts=216]  RelErr% = 0.00
# [Scaling_FastDFA | ts=217]  RelErr% = 0.00
# [Scaling_FastDFA | ts=218]  RelErr% = 0.00
# [Scaling_FastDFA | ts=219]  RelErr% = 0.00
# [Scaling_FastDFA | ts=220]  RelErr% = 0.00
# [Scaling_FastDFA | ts=221]  RelErr% = 0.00
# [Scaling_FastDFA | ts=222]  RelErr% = 0.00
# [Scaling_FastDFA | ts=223]  RelErr% = 0.00
# [Scaling_FastDFA | ts=224]  RelErr% = 0.00
# [Scaling_FastDFA | ts=225]  RelErr% = 0.00
# [Scaling_FastDFA | ts=226]  RelErr% = 0.00
# [Scaling_FastDFA | ts=227]  RelErr% = 0.00
# [Scaling_FastDFA | ts=228]  RelErr% = 0.00
# [Scaling_FastDFA | ts=229]  RelErr% = 0.00
# [Scaling_FastDFA | ts=230]  RelErr% = 0.00
# [Scaling_FastDFA | ts=231]  RelErr% = 0.00
# [Scaling_FastDFA | ts=232]  RelErr% = 0.00
# [Scaling_FastDFA | ts=233]  RelErr% = 0.00
# [Scaling_FastDFA | ts=234]  RelErr% = 0.00
# [Scaling_FastDFA | ts=235]  RelErr% = 0.00
# [Scaling_FastDFA | ts=236]  RelErr% = 0.00
# [Scaling_FastDFA | ts=237]  RelErr% = 0.00
# [Scaling_FastDFA | ts=238]  RelErr% = 0.00
# [Scaling_FastDFA | ts=239]  RelErr% = 0.00
# [Scaling_FastDFA | ts=240]  RelErr% = 0.00
# [Scaling_FastDFA | ts=241]  RelErr% = 0.00
# [Scaling_FastDFA | ts=242]  RelErr% = 0.00
# [Scaling_FastDFA | ts=243]  RelErr% = 0.00
# [Scaling_FastDFA | ts=244]  RelErr% = 0.00
# [Scaling_FastDFA | ts=245]  RelErr% = 0.00
# [Scaling_FastDFA | ts=246]  RelErr% = 0.00
# [Scaling_FastDFA | ts=247]  RelErr% = 0.00
# [Scaling_FastDFA | ts=248]  RelErr% = 0.00
# [Scaling_FastDFA | ts=249]  RelErr% = 0.00
# [Scaling_FastDFA | ts=250]  RelErr% = 0.00
# [Scaling_FastDFA | ts=251]  RelErr% = 0.00
# [Scaling_FastDFA | ts=252]  RelErr% = 0.00
# [Scaling_FastDFA | ts=253]  RelErr% = 0.00
# [Scaling_FastDFA | ts=254]  RelErr% = 0.00
# [Scaling_FastDFA | ts=255]  RelErr% = 0.00
# [Scaling_FastDFA | ts=256]  RelErr% = 0.00
# [Scaling_FastDFA | ts=257]  RelErr% = 0.00
# [Scaling_FastDFA | ts=258]  RelErr% = 0.00
# [Scaling_FastDFA | ts=259]  RelErr% = 0.00
# [Scaling_FastDFA | ts=260]  RelErr% = 0.00
# [Scaling_FastDFA | ts=261]  RelErr% = 0.00
# [Scaling_FastDFA | ts=262]  RelErr% = 0.00
# [Scaling_FastDFA | ts=263]  RelErr% = 0.00
# [Scaling_FastDFA | ts=264]  RelErr% = 0.00
# [Scaling_FastDFA | ts=265]  RelErr% = 0.00
# [Scaling_FastDFA | ts=266]  RelErr% = 0.00
# [Scaling_FastDFA | ts=267]  RelErr% = 0.00
# [Scaling_FastDFA | ts=268]  RelErr% = 0.00
# [Scaling_FastDFA | ts=269]  RelErr% = 0.00
# [Scaling_FastDFA | ts=270]  RelErr% = 0.00
# [Scaling_FastDFA | ts=271]  RelErr% = 0.00
# [Scaling_FastDFA | ts=272]  RelErr% = 0.00
# [Scaling_FastDFA | ts=273]  RelErr% = 0.00
# [Scaling_FastDFA | ts=274]  RelErr% = 0.00
# [Scaling_FastDFA | ts=275]  RelErr% = 0.00
# [Scaling_FastDFA | ts=276]  RelErr% = 0.00
# [Scaling_FastDFA | ts=277]  RelErr% = 0.00
# [Scaling_FastDFA | ts=278]  RelErr% = 0.00
# [Scaling_FastDFA | ts=279]  RelErr% = 0.00
# [Scaling_FastDFA | ts=280]  RelErr% = 0.00
# [Scaling_FastDFA | ts=281]  RelErr% = 0.00
# [Scaling_FastDFA | ts=282]  RelErr% = 0.00
# [Scaling_FastDFA | ts=283]  RelErr% = 0.00
# [Scaling_FastDFA | ts=284]  RelErr% = 0.00
# [Scaling_FastDFA | ts=285]  RelErr% = 0.00
# [Scaling_FastDFA | ts=286]  RelErr% = 0.00
# [Scaling_FastDFA | ts=287]  RelErr% = 0.00
# [Scaling_FastDFA | ts=288]  RelErr% = 0.00
# [Scaling_FastDFA | ts=289]  RelErr% = 0.00
# [Scaling_FastDFA | ts=290]  RelErr% = 0.00
# [Scaling_FastDFA | ts=291]  RelErr% = 0.00
# [Scaling_FastDFA | ts=292]  RelErr% = 0.00
# [Scaling_FastDFA | ts=293]  RelErr% = 0.00
# [Scaling_FastDFA | ts=294]  RelErr% = 0.00
# [Scaling_FastDFA | ts=295]  RelErr% = 0.00
# [Scaling_FastDFA | ts=296]  RelErr% = 0.00
# [Scaling_FastDFA | ts=297]  RelErr% = 0.00
# [Scaling_FastDFA | ts=298]  RelErr% = 0.00
# [Scaling_FastDFA | ts=299]  RelErr% = 0.00
# [Scaling_FastDFA | ts=300]  RelErr% = 0.00
# [Scaling_FastDFA | ts=301]  RelErr% = 0.00
# [Scaling_FastDFA | ts=302]  RelErr% = 0.00
# [Scaling_FastDFA | ts=303]  RelErr% = 0.00
# [Scaling_FastDFA | ts=304]  RelErr% = 0.00
# [Scaling_FastDFA | ts=305]  RelErr% = 0.00
# [Scaling_FastDFA | ts=306]  RelErr% = 0.00
# [Scaling_FastDFA | ts=307]  RelErr% = 0.00
# [Scaling_FastDFA | ts=308]  RelErr% = 0.00
# [Scaling_FastDFA | ts=309]  RelErr% = 0.00
# [Scaling_FastDFA | ts=310]  RelErr% = 0.00
# [Scaling_FastDFA | ts=311]  RelErr% = 0.00
# [Scaling_FastDFA | ts=312]  RelErr% = 0.00
# [Scaling_FastDFA | ts=313]  RelErr% = 0.00
# [Scaling_FastDFA | ts=314]  RelErr% = 0.00
# [Scaling_FastDFA | ts=315]  RelErr% = 0.00
# [Scaling_FastDFA | ts=316]  RelErr% = 0.00
# [Scaling_FastDFA | ts=317]  RelErr% = 0.00
# [Scaling_FastDFA | ts=318]  RelErr% = 0.00
# [Scaling_FastDFA | ts=319]  RelErr% = 0.00
# [Scaling_FastDFA | ts=320]  RelErr% = 0.00
# [Scaling_FastDFA | ts=321]  RelErr% = 0.00
# [Scaling_FastDFA | ts=322]  RelErr% = 0.00
# [Scaling_FastDFA | ts=323]  RelErr% = 0.00
# [Scaling_FastDFA | ts=324]  RelErr% = 0.00
# [Scaling_FastDFA | ts=325]  RelErr% = 0.00
# [Scaling_FastDFA | ts=326]  RelErr% = 0.00
# [Scaling_FastDFA | ts=327]  RelErr% = 0.00
# [Scaling_FastDFA | ts=328]  RelErr% = 0.00
# [Scaling_FastDFA | ts=329]  RelErr% = 0.00
# [Scaling_FastDFA | ts=330]  RelErr% = 0.00
# [Scaling_FastDFA | ts=331]  RelErr% = 0.00
# [Scaling_FastDFA | ts=332]  RelErr% = 0.00
# [Scaling_FastDFA | ts=333]  RelErr% = 0.00
# [Scaling_FastDFA | ts=334]  RelErr% = 0.00
# [Scaling_FastDFA | ts=335]  RelErr% = 0.00
# [Scaling_FastDFA | ts=336]  RelErr% = 0.00
# [Scaling_FastDFA | ts=337]  RelErr% = 0.00
# [Scaling_FastDFA | ts=338]  RelErr% = 0.00
# [Scaling_FastDFA | ts=339]  RelErr% = 0.00
# [Scaling_FastDFA | ts=340]  RelErr% = 0.00
# [Scaling_FastDFA | ts=341]  RelErr% = 0.00
# [Scaling_FastDFA | ts=342]  RelErr% = 0.00
# [Scaling_FastDFA | ts=343]  RelErr% = 0.00
# [Scaling_FastDFA | ts=344]  RelErr% = 0.00
# [Scaling_FastDFA | ts=345]  RelErr% = 0.00
# [Scaling_FastDFA | ts=346]  RelErr% = 0.00
# [Scaling_FastDFA | ts=347]  RelErr% = 0.00
# [Scaling_FastDFA | ts=348]  RelErr% = 0.00
# [Scaling_FastDFA | ts=349]  RelErr% = 0.00
# [Scaling_FastDFA | ts=350]  RelErr% = 0.00
# [Scaling_FastDFA | ts=351]  RelErr% = 0.00
# [Scaling_FastDFA | ts=352]  RelErr% = 0.00
# [Scaling_FastDFA | ts=353]  RelErr% = 0.00
# [Scaling_FastDFA | ts=354]  RelErr% = 0.00
# [Scaling_FastDFA | ts=355]  RelErr% = 0.00
# [Scaling_FastDFA | ts=356]  RelErr% = 0.00
# [Scaling_FastDFA | ts=357]  RelErr% = 0.00
# [Scaling_FastDFA | ts=358]  RelErr% = 0.00
# [Scaling_FastDFA | ts=359]  RelErr% = 0.00
# [Scaling_FastDFA | ts=360]  RelErr% = 0.00
# [Scaling_FastDFA | ts=361]  RelErr% = 0.00
# [Scaling_FastDFA | ts=362]  RelErr% = 0.00
# [Scaling_FastDFA | ts=363]  RelErr% = 0.00
# [Scaling_FastDFA | ts=364]  RelErr% = 0.00
# [Scaling_FastDFA | ts=365]  RelErr% = 0.00
# [Scaling_FastDFA | ts=366]  RelErr% = 0.00
# [Scaling_FastDFA | ts=367]  RelErr% = 0.00
# [Scaling_FastDFA | ts=368]  RelErr% = 0.00
# [Scaling_FastDFA | ts=369]  RelErr% = 0.00
# [Scaling_FastDFA | ts=370]  RelErr% = 0.00
# [Scaling_FastDFA | ts=371]  RelErr% = 0.00
# [Scaling_FastDFA | ts=372]  RelErr% = 0.00
# [Scaling_FastDFA | ts=373]  RelErr% = 0.00
# [Scaling_FastDFA | ts=374]  RelErr% = 0.00
# [Scaling_FastDFA | ts=375]  RelErr% = 0.00
# [Scaling_FastDFA | ts=376]  RelErr% = 0.00
# [Scaling_FastDFA | ts=377]  RelErr% = 0.00
# [Scaling_FastDFA | ts=378]  RelErr% = 0.00
# [Scaling_FastDFA | ts=379]  RelErr% = 0.00
# [Scaling_FastDFA | ts=380]  RelErr% = 0.00
# [Scaling_FastDFA | ts=381]  RelErr% = 0.00
# [Scaling_FastDFA | ts=382]  RelErr% = 0.00
# [Scaling_FastDFA | ts=383]  RelErr% = 0.00
# [Scaling_FastDFA | ts=384]  RelErr% = 0.00
# [Scaling_FastDFA | ts=385]  RelErr% = 0.00
# [Scaling_FastDFA | ts=386]  RelErr% = 0.00
# [Scaling_FastDFA | ts=387]  RelErr% = 0.00
# [Scaling_FastDFA | ts=388]  RelErr% = 0.00
# [Scaling_FastDFA | ts=389]  RelErr% = 0.00
# [Scaling_FastDFA | ts=390]  RelErr% = 0.00
# [Scaling_FastDFA | ts=391]  RelErr% = 0.00
# [Scaling_FastDFA | ts=392]  RelErr% = 0.00
# [Scaling_FastDFA | ts=393]  RelErr% = 0.00
# [Scaling_FastDFA | ts=394]  RelErr% = 0.00
# [Scaling_FastDFA | ts=395]  RelErr% = 0.00
# [Scaling_FastDFA | ts=396]  RelErr% = 0.00
# [Scaling_FastDFA | ts=397]  RelErr% = 0.00
# [Scaling_FastDFA | ts=398]  RelErr% = 0.00
# [Scaling_FastDFA | ts=399]  RelErr% = 0.00
# [Scaling_FastDFA | ts=400]  RelErr% = 0.00
# [Scaling_FastDFA | ts=401]  RelErr% = 0.00
# [Scaling_FastDFA | ts=402]  RelErr% = 0.00
# [Scaling_FastDFA | ts=403]  RelErr% = 0.00
# [Scaling_FastDFA | ts=404]  RelErr% = 0.00
# [Scaling_FastDFA | ts=405]  RelErr% = 0.00
# [Scaling_FastDFA | ts=406]  RelErr% = 0.00
# [Scaling_FastDFA | ts=407]  RelErr% = 0.00
# [Scaling_FastDFA | ts=408]  RelErr% = 0.00
# [Scaling_FastDFA | ts=409]  RelErr% = 0.00
# [Scaling_FastDFA | ts=410]  RelErr% = 0.00
# [Scaling_FastDFA | ts=411]  RelErr% = 0.00
# [Scaling_FastDFA | ts=412]  RelErr% = 0.00
# [Scaling_FastDFA | ts=413]  RelErr% = 0.00
# [Scaling_FastDFA | ts=414]  RelErr% = 0.00
# [Scaling_FastDFA | ts=415]  RelErr% = 0.00
# [Scaling_FastDFA | ts=416]  RelErr% = 0.00
# [Scaling_FastDFA | ts=417]  RelErr% = 0.00
# [Scaling_FastDFA | ts=418]  RelErr% = 0.00
# [Scaling_FastDFA | ts=419]  RelErr% = 0.00
# [Scaling_FastDFA | ts=420]  RelErr% = 0.00
# [Scaling_FastDFA | ts=421]  RelErr% = 0.00
# [Scaling_FastDFA | ts=422]  RelErr% = 0.00
# [Scaling_FastDFA | ts=423]  RelErr% = 0.00
# [Scaling_FastDFA | ts=424]  RelErr% = 0.00
# [Scaling_FastDFA | ts=425]  RelErr% = 0.00
# [Scaling_FastDFA | ts=426]  RelErr% = 0.00
# [Scaling_FastDFA | ts=427]  RelErr% = 0.00
# [Scaling_FastDFA | ts=428]  RelErr% = 0.00
# [Scaling_FastDFA | ts=429]  RelErr% = 0.00
# [Scaling_FastDFA | ts=430]  RelErr% = 0.00
# [Scaling_FastDFA | ts=431]  RelErr% = 0.00
# [Scaling_FastDFA | ts=432]  RelErr% = 0.00
# [Scaling_FastDFA | ts=433]  RelErr% = 0.00
# [Scaling_FastDFA | ts=434]  RelErr% = 0.00
# [Scaling_FastDFA | ts=435]  RelErr% = 0.00
# [Scaling_FastDFA | ts=436]  RelErr% = 0.00
# [Scaling_FastDFA | ts=437]  RelErr% = 0.00
# [Scaling_FastDFA | ts=438]  RelErr% = 0.00
# [Scaling_FastDFA | ts=439]  RelErr% = 0.00
# [Scaling_FastDFA | ts=440]  RelErr% = 0.00
# [Scaling_FastDFA | ts=441]  RelErr% = 0.00
# [Scaling_FastDFA | ts=442]  RelErr% = 0.00
# [Scaling_FastDFA | ts=443]  RelErr% = 0.00
# [Scaling_FastDFA | ts=444]  RelErr% = 0.00
# [Scaling_FastDFA | ts=445]  RelErr% = 0.00
# [Scaling_FastDFA | ts=446]  RelErr% = 0.00
# [Scaling_FastDFA | ts=447]  RelErr% = 0.00
# [Scaling_FastDFA | ts=448]  RelErr% = 0.00
# [Scaling_FastDFA | ts=449]  RelErr% = 0.00
# [Scaling_FastDFA | ts=450]  RelErr% = 0.00
# [Scaling_FastDFA | ts=451]  RelErr% = 0.00
# [Scaling_FastDFA | ts=452]  RelErr% = 0.00
# [Scaling_FastDFA | ts=453]  RelErr% = 0.00
# [Scaling_FastDFA | ts=454]  RelErr% = 0.00
# [Scaling_FastDFA | ts=455]  RelErr% = 0.00
# [Scaling_FastDFA | ts=456]  RelErr% = 0.00
# [Scaling_FastDFA | ts=457]  RelErr% = 0.00
# [Scaling_FastDFA | ts=458]  RelErr% = 0.00
# [Scaling_FastDFA | ts=459]  RelErr% = 0.00
# [Scaling_FastDFA | ts=460]  RelErr% = 0.00
# [Scaling_FastDFA | ts=461]  RelErr% = 0.00
# [Scaling_FastDFA | ts=462]  RelErr% = 0.00
# [Scaling_FastDFA | ts=463]  RelErr% = 0.00
# [Scaling_FastDFA | ts=464]  RelErr% = 0.00
# [Scaling_FastDFA | ts=465]  RelErr% = 0.00
# [Scaling_FastDFA | ts=466]  RelErr% = 0.00
# [Scaling_FastDFA | ts=467]  RelErr% = 0.00
# [Scaling_FastDFA | ts=468]  RelErr% = 0.00
# [Scaling_FastDFA | ts=469]  RelErr% = 0.00
# [Scaling_FastDFA | ts=470]  RelErr% = 0.00
# [Scaling_FastDFA | ts=471]  RelErr% = 0.00
# [Scaling_FastDFA | ts=472]  RelErr% = 0.00
# [Scaling_FastDFA | ts=473]  RelErr% = 0.00
# [Scaling_FastDFA | ts=474]  RelErr% = 0.00
# [Scaling_FastDFA | ts=475]  RelErr% = 0.00
# [Scaling_FastDFA | ts=476]  RelErr% = 0.00
# [Scaling_FastDFA | ts=477]  RelErr% = 0.00
# [Scaling_FastDFA | ts=478]  RelErr% = 0.00
# [Scaling_FastDFA | ts=479]  RelErr% = 0.00
# [Scaling_FastDFA | ts=480]  RelErr% = 0.00
# [Scaling_FastDFA | ts=481]  RelErr% = 0.00
# [Scaling_FastDFA | ts=482]  RelErr% = 0.00
# [Scaling_FastDFA | ts=483]  RelErr% = 0.00
# [Scaling_FastDFA | ts=484]  RelErr% = 0.00
# [Scaling_FastDFA | ts=485]  RelErr% = 0.00
# [Scaling_FastDFA | ts=486]  RelErr% = 0.00
# [Scaling_FastDFA | ts=487]  RelErr% = 0.00
# [Scaling_FastDFA | ts=488]  RelErr% = 0.00
# [Scaling_FastDFA | ts=489]  RelErr% = 0.00
# [Scaling_FastDFA | ts=490]  RelErr% = 0.00
# [Scaling_FastDFA | ts=491]  RelErr% = 0.00
# [Scaling_FastDFA | ts=492]  RelErr% = 0.00
# [Scaling_FastDFA | ts=493]  RelErr% = 0.00
# [Scaling_FastDFA | ts=494]  RelErr% = 0.00
# [Scaling_FastDFA | ts=495]  RelErr% = 0.00
# [Scaling_FastDFA | ts=496]  RelErr% = 0.00
# [Scaling_FastDFA | ts=497]  RelErr% = 0.00
# [Scaling_FastDFA | ts=498]  RelErr% = 0.00
# [Scaling_FastDFA | ts=499]  RelErr% = 0.00
# [Scaling_FastDFA | ts=500]  RelErr% = 0.00
# [Scaling_FastDFA | ts=501]  RelErr% = 0.00
# [Scaling_FastDFA | ts=502]  RelErr% = 0.00
# [Scaling_FastDFA | ts=503]  RelErr% = 0.00
# [Scaling_FastDFA | ts=504]  RelErr% = 0.00
# [Scaling_FastDFA | ts=505]  RelErr% = 0.00
# [Scaling_FastDFA | ts=506]  RelErr% = 0.00
# [Scaling_FastDFA | ts=507]  RelErr% = 0.00
# [Scaling_FastDFA | ts=508]  RelErr% = 0.00
# [Scaling_FastDFA | ts=509]  RelErr% = 0.00
# [Scaling_FastDFA | ts=510]  RelErr% = 0.00
# [Scaling_FastDFA | ts=511]  RelErr% = 0.00
# [Scaling_FastDFA | ts=512]  RelErr% = 0.00
# [Scaling_FastDFA | ts=513]  RelErr% = 0.00
# [Scaling_FastDFA | ts=514]  RelErr% = 0.00
# [Scaling_FastDFA | ts=515]  RelErr% = 0.00
# [Scaling_FastDFA | ts=516]  RelErr% = 0.00
# [Scaling_FastDFA | ts=517]  RelErr% = 0.00
# [Scaling_FastDFA | ts=518]  RelErr% = 0.00
# [Scaling_FastDFA | ts=519]  RelErr% = 0.00
# [Scaling_FastDFA | ts=520]  RelErr% = 0.00
# [Scaling_FastDFA | ts=521]  RelErr% = 0.00
# [Scaling_FastDFA | ts=522]  RelErr% = 0.00
# [Scaling_FastDFA | ts=523]  RelErr% = 0.00
# [Scaling_FastDFA | ts=524]  RelErr% = 0.00
# [Scaling_FastDFA | ts=525]  RelErr% = 0.00
# [Scaling_FastDFA | ts=526]  RelErr% = 0.00
# [Scaling_FastDFA | ts=527]  RelErr% = 0.00
# [Scaling_FastDFA | ts=528]  RelErr% = 0.00
# [Scaling_FastDFA | ts=529]  RelErr% = 0.00
# [Scaling_FastDFA | ts=530]  RelErr% = 0.00
# [Scaling_FastDFA | ts=531]  RelErr% = 0.00
# [Scaling_FastDFA | ts=532]  RelErr% = 0.00
# [Scaling_FastDFA | ts=533]  RelErr% = 0.00
# [Scaling_FastDFA | ts=534]  RelErr% = 0.00
# [Scaling_FastDFA | ts=535]  RelErr% = 0.00
# [Scaling_FastDFA | ts=536]  RelErr% = 0.00
# [Scaling_FastDFA | ts=537]  RelErr% = 0.00
# [Scaling_FastDFA | ts=538]  RelErr% = 0.00
# [Scaling_FastDFA | ts=539]  RelErr% = 0.00
# [Scaling_FastDFA | ts=540]  RelErr% = 0.00
# [Scaling_FastDFA | ts=541]  RelErr% = 0.00
# [Scaling_FastDFA | ts=542]  RelErr% = 0.00
# [Scaling_FastDFA | ts=543]  RelErr% = 0.00
# [Scaling_FastDFA | ts=544]  RelErr% = 0.00
# [Scaling_FastDFA | ts=545]  RelErr% = 0.00
# [Scaling_FastDFA | ts=546]  RelErr% = 0.00
# [Scaling_FastDFA | ts=547]  RelErr% = 0.00
# [Scaling_FastDFA | ts=548]  RelErr% = 0.00
# [Scaling_FastDFA | ts=549]  RelErr% = 0.00
# [Scaling_FastDFA | ts=550]  RelErr% = 0.00
# [Scaling_FastDFA | ts=551]  RelErr% = 0.00
# [Scaling_FastDFA | ts=552]  RelErr% = 0.00
# [Scaling_FastDFA | ts=553]  RelErr% = 0.00
# [Scaling_FastDFA | ts=554]  RelErr% = 0.00
# [Scaling_FastDFA | ts=555]  RelErr% = 0.00
# [Scaling_FastDFA | ts=556]  RelErr% = 0.00
# [Scaling_FastDFA | ts=557]  RelErr% = 0.00
# [Scaling_FastDFA | ts=558]  RelErr% = 0.00
# [Scaling_FastDFA | ts=559]  RelErr% = 0.00
# [Scaling_FastDFA | ts=560]  RelErr% = 0.00
# [Scaling_FastDFA | ts=561]  RelErr% = 0.00
# [Scaling_FastDFA | ts=562]  RelErr% = 0.00
# [Scaling_FastDFA | ts=563]  RelErr% = 0.00
# [Scaling_FastDFA | ts=564]  RelErr% = 0.00
# [Scaling_FastDFA | ts=565]  RelErr% = 0.00
# [Scaling_FastDFA | ts=566]  RelErr% = 0.00
# [Scaling_FastDFA | ts=567]  RelErr% = 0.00
# [Scaling_FastDFA | ts=568]  RelErr% = 0.00
# [Scaling_FastDFA | ts=569]  RelErr% = 0.00
# [Scaling_FastDFA | ts=570]  RelErr% = 0.00
# [Scaling_FastDFA | ts=571]  RelErr% = 0.00
# [Scaling_FastDFA | ts=572]  RelErr% = 0.00
# [Scaling_FastDFA | ts=573]  RelErr% = 0.00
# [Scaling_FastDFA | ts=574]  RelErr% = 0.00
# [Scaling_FastDFA | ts=575]  RelErr% = 0.00
# [Scaling_FastDFA | ts=576]  RelErr% = 0.00
# [Scaling_FastDFA | ts=577]  RelErr% = 0.00
# [Scaling_FastDFA | ts=578]  RelErr% = 0.00
# [Scaling_FastDFA | ts=579]  RelErr% = 0.00
# [Scaling_FastDFA | ts=580]  RelErr% = 0.00
# [Scaling_FastDFA | ts=581]  RelErr% = 0.00
# [Scaling_FastDFA | ts=582]  RelErr% = 0.00
# [Scaling_FastDFA | ts=583]  RelErr% = 0.00
# [Scaling_FastDFA | ts=584]  RelErr% = 0.00
# [Scaling_FastDFA | ts=585]  RelErr% = 0.00
# [Scaling_FastDFA | ts=586]  RelErr% = 0.00
# [Scaling_FastDFA | ts=587]  RelErr% = 0.00
# [Scaling_FastDFA | ts=588]  RelErr% = 0.00
# [Scaling_FastDFA | ts=589]  RelErr% = 0.00
# [Scaling_FastDFA | ts=590]  RelErr% = 0.00
# [Scaling_FastDFA | ts=591]  RelErr% = 0.00
# [Scaling_FastDFA | ts=592]  RelErr% = 0.00
# [Scaling_FastDFA | ts=593]  RelErr% = 0.00
# [Scaling_FastDFA | ts=594]  RelErr% = 0.00
# [Scaling_FastDFA | ts=595]  RelErr% = 0.00
# [Scaling_FastDFA | ts=596]  RelErr% = 0.00
# [Scaling_FastDFA | ts=597]  RelErr% = 0.00
# [Scaling_FastDFA | ts=598]  RelErr% = 0.00
# [Scaling_FastDFA | ts=599]  RelErr% = 0.00
# [Scaling_FastDFA | ts=600]  RelErr% = 0.00
# [Scaling_FastDFA | ts=601]  RelErr% = 0.00
# [Scaling_FastDFA | ts=602]  RelErr% = 0.00
# [Scaling_FastDFA | ts=603]  RelErr% = 0.00
# [Scaling_FastDFA | ts=604]  RelErr% = 0.00
# [Scaling_FastDFA | ts=605]  RelErr% = 0.00
# [Scaling_FastDFA | ts=606]  RelErr% = 0.00
# [Scaling_FastDFA | ts=607]  RelErr% = 0.00
# [Scaling_FastDFA | ts=608]  RelErr% = 0.00
# [Scaling_FastDFA | ts=609]  RelErr% = 0.00
# [Scaling_FastDFA | ts=610]  RelErr% = 0.00
# [Scaling_FastDFA | ts=611]  RelErr% = 0.00
# [Scaling_FastDFA | ts=612]  RelErr% = 0.00
# [Scaling_FastDFA | ts=613]  RelErr% = 0.00
# [Scaling_FastDFA | ts=614]  RelErr% = 0.00
# [Scaling_FastDFA | ts=615]  RelErr% = 0.00
# [Scaling_FastDFA | ts=616]  RelErr% = 0.00
# [Scaling_FastDFA | ts=617]  RelErr% = 0.00
# [Scaling_FastDFA | ts=618]  RelErr% = 0.00
# [Scaling_FastDFA | ts=619]  RelErr% = 0.00
# [Scaling_FastDFA | ts=620]  RelErr% = 0.00
# [Scaling_FastDFA | ts=621]  RelErr% = 0.00
# [Scaling_FastDFA | ts=622]  RelErr% = 0.00
# [Scaling_FastDFA | ts=623]  RelErr% = 0.00
# [Scaling_FastDFA | ts=624]  RelErr% = 0.00
# [Scaling_FastDFA | ts=625]  RelErr% = 0.00
# [Scaling_FastDFA | ts=626]  RelErr% = 0.00
# [Scaling_FastDFA | ts=627]  RelErr% = 0.00
# [Scaling_FastDFA | ts=628]  RelErr% = 0.00
# [Scaling_FastDFA | ts=629]  RelErr% = 0.00
# [Scaling_FastDFA | ts=630]  RelErr% = 0.00
# [Scaling_FastDFA | ts=631]  RelErr% = 0.00
# [Scaling_FastDFA | ts=632]  RelErr% = 0.00
# [Scaling_FastDFA | ts=633]  RelErr% = 0.00
# [Scaling_FastDFA | ts=634]  RelErr% = 0.00
# [Scaling_FastDFA | ts=635]  RelErr% = 0.00
# [Scaling_FastDFA | ts=636]  RelErr% = 0.00
# [Scaling_FastDFA | ts=637]  RelErr% = 0.00
# [Scaling_FastDFA | ts=638]  RelErr% = 0.00
# [Scaling_FastDFA | ts=639]  RelErr% = 0.00
# [Scaling_FastDFA | ts=640]  RelErr% = 0.00
# [Scaling_FastDFA | ts=641]  RelErr% = 0.00
# [Scaling_FastDFA | ts=642]  RelErr% = 0.00
# [Scaling_FastDFA | ts=643]  RelErr% = 0.00
# [Scaling_FastDFA | ts=644]  RelErr% = 0.00
# [Scaling_FastDFA | ts=645]  RelErr% = 0.00
# [Scaling_FastDFA | ts=646]  RelErr% = 0.00
# [Scaling_FastDFA | ts=647]  RelErr% = 0.00
# [Scaling_FastDFA | ts=648]  RelErr% = 0.00
# [Scaling_FastDFA | ts=649]  RelErr% = 0.00
# [Scaling_FastDFA | ts=650]  RelErr% = 0.00
# [Scaling_FastDFA | ts=651]  RelErr% = 0.00
# [Scaling_FastDFA | ts=652]  RelErr% = 0.00
# [Scaling_FastDFA | ts=653]  RelErr% = 0.00
# [Scaling_FastDFA | ts=654]  RelErr% = 0.00
# [Scaling_FastDFA | ts=655]  RelErr% = 0.00
# [Scaling_FastDFA | ts=656]  RelErr% = 0.00
# [Scaling_FastDFA | ts=657]  RelErr% = 0.00
# [Scaling_FastDFA | ts=658]  RelErr% = 0.00
# [Scaling_FastDFA | ts=659]  RelErr% = 0.00
# [Scaling_FastDFA | ts=660]  RelErr% = 0.00
# [Scaling_FastDFA | ts=661]  RelErr% = 0.00
# [Scaling_FastDFA | ts=662]  RelErr% = 0.00
# [Scaling_FastDFA | ts=663]  RelErr% = 0.00
# [Scaling_FastDFA | ts=664]  RelErr% = 0.00
# [Scaling_FastDFA | ts=665]  RelErr% = 0.00
# [Scaling_FastDFA | ts=666]  RelErr% = 0.00
# [Scaling_FastDFA | ts=667]  RelErr% = 0.00
# [Scaling_FastDFA | ts=668]  RelErr% = 0.00
# [Scaling_FastDFA | ts=669]  RelErr% = 0.00
# [Scaling_FastDFA | ts=670]  RelErr% = 0.00
# [Scaling_FastDFA | ts=671]  RelErr% = 0.00
# [Scaling_FastDFA | ts=672]  RelErr% = 0.00
# [Scaling_FastDFA | ts=673]  RelErr% = 0.00
# [Scaling_FastDFA | ts=674]  RelErr% = 0.00
# [Scaling_FastDFA | ts=675]  RelErr% = 0.00
# [Scaling_FastDFA | ts=676]  RelErr% = 0.00
# [Scaling_FastDFA | ts=677]  RelErr% = 0.00
# [Scaling_FastDFA | ts=678]  RelErr% = 0.00
# [Scaling_FastDFA | ts=679]  RelErr% = 0.00
# [Scaling_FastDFA | ts=680]  RelErr% = 0.00
# [Scaling_FastDFA | ts=681]  RelErr% = 0.00
# [Scaling_FastDFA | ts=682]  RelErr% = 0.00
# [Scaling_FastDFA | ts=683]  RelErr% = 0.00
# [Scaling_FastDFA | ts=684]  RelErr% = 0.00
# [Scaling_FastDFA | ts=685]  RelErr% = 0.00
# [Scaling_FastDFA | ts=686]  RelErr% = 0.00
# [Scaling_FastDFA | ts=687]  RelErr% = 0.00
# [Scaling_FastDFA | ts=688]  RelErr% = 0.00
# [Scaling_FastDFA | ts=689]  RelErr% = 0.00
# [Scaling_FastDFA | ts=690]  RelErr% = 0.00
# [Scaling_FastDFA | ts=691]  RelErr% = 0.00
# [Scaling_FastDFA | ts=692]  RelErr% = 0.00
# [Scaling_FastDFA | ts=693]  RelErr% = 0.00
# [Scaling_FastDFA | ts=694]  RelErr% = 0.00
# [Scaling_FastDFA | ts=695]  RelErr% = 0.00
# [Scaling_FastDFA | ts=696]  RelErr% = 0.00
# [Scaling_FastDFA | ts=697]  RelErr% = 0.00
# [Scaling_FastDFA | ts=698]  RelErr% = 0.00
# [Scaling_FastDFA | ts=699]  RelErr% = 0.00
# [Scaling_FastDFA | ts=700]  RelErr% = 0.00
# [Scaling_FastDFA | ts=701]  RelErr% = 0.00
# [Scaling_FastDFA | ts=702]  RelErr% = 0.00
# [Scaling_FastDFA | ts=703]  RelErr% = 0.00
# [Scaling_FastDFA | ts=704]  RelErr% = 0.00
# [Scaling_FastDFA | ts=705]  RelErr% = 0.00
# [Scaling_FastDFA | ts=706]  RelErr% = 0.00
# [Scaling_FastDFA | ts=707]  RelErr% = 0.00
# [Scaling_FastDFA | ts=708]  RelErr% = 0.00
# [Scaling_FastDFA | ts=709]  RelErr% = 0.00
# [Scaling_FastDFA | ts=710]  RelErr% = 0.00
# [Scaling_FastDFA | ts=711]  RelErr% = 0.00
# [Scaling_FastDFA | ts=712]  RelErr% = 0.00
# [Scaling_FastDFA | ts=713]  RelErr% = 0.00
# [Scaling_FastDFA | ts=714]  RelErr% = 0.00
# [Scaling_FastDFA | ts=715]  RelErr% = 0.00
# [Scaling_FastDFA | ts=716]  RelErr% = 0.00
# [Scaling_FastDFA | ts=717]  RelErr% = 0.00
# [Scaling_FastDFA | ts=718]  RelErr% = 0.00
# [Scaling_FastDFA | ts=719]  RelErr% = 0.00
# [Scaling_FastDFA | ts=720]  RelErr% = 0.00
# [Scaling_FastDFA | ts=721]  RelErr% = 0.00
# [Scaling_FastDFA | ts=722]  RelErr% = 0.00
# [Scaling_FastDFA | ts=723]  RelErr% = 0.00
# [Scaling_FastDFA | ts=724]  RelErr% = 0.00
# [Scaling_FastDFA | ts=725]  RelErr% = 0.00
# [Scaling_FastDFA | ts=726]  RelErr% = 0.00
# [Scaling_FastDFA | ts=727]  RelErr% = 0.00
# [Scaling_FastDFA | ts=728]  RelErr% = 0.00
# [Scaling_FastDFA | ts=729]  RelErr% = 0.00
# [Scaling_FastDFA | ts=730]  RelErr% = 0.00
# [Scaling_FastDFA | ts=731]  RelErr% = 0.00
# [Scaling_FastDFA | ts=732]  RelErr% = 0.00
# [Scaling_FastDFA | ts=733]  RelErr% = 0.00
# [Scaling_FastDFA | ts=734]  RelErr% = 0.00
# [Scaling_FastDFA | ts=735]  RelErr% = 0.00
# [Scaling_FastDFA | ts=736]  RelErr% = 0.00
# [Scaling_FastDFA | ts=737]  RelErr% = 0.00
# [Scaling_FastDFA | ts=738]  RelErr% = 0.00
# [Scaling_FastDFA | ts=739]  RelErr% = 0.00
# [Scaling_FastDFA | ts=740]  RelErr% = 0.00
# [Scaling_FastDFA | ts=741]  RelErr% = 0.00
# [Scaling_FastDFA | ts=742]  RelErr% = 0.00
# [Scaling_FastDFA | ts=743]  RelErr% = 0.00
# [Scaling_FastDFA | ts=744]  RelErr% = 0.00
# [Scaling_FastDFA | ts=745]  RelErr% = 0.00
# [Scaling_FastDFA | ts=746]  RelErr% = 0.00
# [Scaling_FastDFA | ts=747]  RelErr% = 0.00
# [Scaling_FastDFA | ts=748]  RelErr% = 0.00
# [Scaling_FastDFA | ts=749]  RelErr% = 0.00
# [Scaling_FastDFA | ts=750]  RelErr% = 0.00
# [Scaling_FastDFA | ts=751]  RelErr% = 0.00
# [Scaling_FastDFA | ts=752]  RelErr% = 0.00
# [Scaling_FastDFA | ts=753]  RelErr% = 0.00
# [Scaling_FastDFA | ts=754]  RelErr% = 0.00
# [Scaling_FastDFA | ts=755]  RelErr% = 0.00
# [Scaling_FastDFA | ts=756]  RelErr% = 0.00
# [Scaling_FastDFA | ts=757]  RelErr% = 0.00
# [Scaling_FastDFA | ts=758]  RelErr% = 0.00
# [Scaling_FastDFA | ts=759]  RelErr% = 0.00
# [Scaling_FastDFA | ts=760]  RelErr% = 0.00
# [Scaling_FastDFA | ts=761]  RelErr% = 0.00
# [Scaling_FastDFA | ts=762]  RelErr% = 0.00
# [Scaling_FastDFA | ts=763]  RelErr% = 0.00
# [Scaling_FastDFA | ts=764]  RelErr% = 0.00
# [Scaling_FastDFA | ts=765]  RelErr% = 0.00
# [Scaling_FastDFA | ts=766]  RelErr% = 0.00
# [Scaling_FastDFA | ts=767]  RelErr% = 0.00
# [Scaling_FastDFA | ts=768]  RelErr% = 0.00
# [Scaling_FastDFA | ts=769]  RelErr% = 0.00
# [Scaling_FastDFA | ts=770]  RelErr% = 0.00
# [Scaling_FastDFA | ts=771]  RelErr% = 0.00
# [Scaling_FastDFA | ts=772]  RelErr% = 0.00
# [Scaling_FastDFA | ts=773]  RelErr% = 0.00
# [Scaling_FastDFA | ts=774]  RelErr% = 0.00
# [Scaling_FastDFA | ts=775]  RelErr% = 0.00
# [Scaling_FastDFA | ts=776]  RelErr% = 0.00
# [Scaling_FastDFA | ts=777]  RelErr% = 0.00
# [Scaling_FastDFA | ts=778]  RelErr% = 0.00
# [Scaling_FastDFA | ts=779]  RelErr% = 0.00
# [Scaling_FastDFA | ts=780]  RelErr% = 0.00
# [Scaling_FastDFA | ts=781]  RelErr% = 0.00
# [Scaling_FastDFA | ts=782]  RelErr% = 0.00
# [Scaling_FastDFA | ts=783]  RelErr% = 0.00
# [Scaling_FastDFA | ts=784]  RelErr% = 0.00
# [Scaling_FastDFA | ts=785]  RelErr% = 0.00
# [Scaling_FastDFA | ts=786]  RelErr% = 0.00
# [Scaling_FastDFA | ts=787]  RelErr% = 0.00
# [Scaling_FastDFA | ts=788]  RelErr% = 0.00
# [Scaling_FastDFA | ts=789]  RelErr% = 0.00
# [Scaling_FastDFA | ts=790]  RelErr% = 0.00
# [Scaling_FastDFA | ts=791]  RelErr% = 0.00
# [Scaling_FastDFA | ts=792]  RelErr% = 0.00
# [Scaling_FastDFA | ts=793]  RelErr% = 0.00
# [Scaling_FastDFA | ts=794]  RelErr% = 0.00
# [Scaling_FastDFA | ts=795]  RelErr% = 0.00
# [Scaling_FastDFA | ts=796]  RelErr% = 0.00
# [Scaling_FastDFA | ts=797]  RelErr% = 0.00
# [Scaling_FastDFA | ts=798]  RelErr% = 0.00
# [Scaling_FastDFA | ts=799]  RelErr% = 0.00
# [Scaling_FastDFA | ts=800]  RelErr% = 0.00
# [Scaling_FastDFA | ts=801]  RelErr% = 0.00
# [Scaling_FastDFA | ts=802]  RelErr% = 0.00
# [Scaling_FastDFA | ts=803]  RelErr% = 0.00
# [Scaling_FastDFA | ts=804]  RelErr% = 0.00
# [Scaling_FastDFA | ts=805]  RelErr% = 0.00
# [Scaling_FastDFA | ts=806]  RelErr% = 0.00
# [Scaling_FastDFA | ts=807]  RelErr% = 0.00
# [Scaling_FastDFA | ts=808]  RelErr% = 0.00
# [Scaling_FastDFA | ts=809]  RelErr% = 0.00
# [Scaling_FastDFA | ts=810]  RelErr% = 0.00
# [Scaling_FastDFA | ts=811]  RelErr% = 0.00
# [Scaling_FastDFA | ts=812]  RelErr% = 0.00
# [Scaling_FastDFA | ts=813]  RelErr% = 0.00
# [Scaling_FastDFA | ts=814]  RelErr% = 0.00
# [Scaling_FastDFA | ts=815]  RelErr% = 0.00
# [Scaling_FastDFA | ts=816]  RelErr% = 0.00
# [Scaling_FastDFA | ts=817]  RelErr% = 0.00
# [Scaling_FastDFA | ts=818]  RelErr% = 0.00
# [Scaling_FastDFA | ts=819]  RelErr% = 0.00
# [Scaling_FastDFA | ts=820]  RelErr% = 0.00
# [Scaling_FastDFA | ts=821]  RelErr% = 0.00
# [Scaling_FastDFA | ts=822]  RelErr% = 0.00
# [Scaling_FastDFA | ts=823]  RelErr% = 0.00
# [Scaling_FastDFA | ts=824]  RelErr% = 0.00
# [Scaling_FastDFA | ts=825]  RelErr% = 0.00
# [Scaling_FastDFA | ts=826]  RelErr% = 0.00
# [Scaling_FastDFA | ts=827]  RelErr% = 0.00
# [Scaling_FastDFA | ts=828]  RelErr% = 0.00
# [Scaling_FastDFA | ts=829]  RelErr% = 0.00
# [Scaling_FastDFA | ts=830]  RelErr% = 0.00
# [Scaling_FastDFA | ts=831]  RelErr% = 0.00
# [Scaling_FastDFA | ts=832]  RelErr% = 0.00
# [Scaling_FastDFA | ts=833]  RelErr% = 0.00
# [Scaling_FastDFA | ts=834]  RelErr% = 0.00
# [Scaling_FastDFA | ts=835]  RelErr% = 0.00
# [Scaling_FastDFA | ts=836]  RelErr% = 0.00
# [Scaling_FastDFA | ts=837]  RelErr% = 0.00
# [Scaling_FastDFA | ts=838]  RelErr% = 0.00
# [Scaling_FastDFA | ts=839]  RelErr% = 0.00
# [Scaling_FastDFA | ts=840]  RelErr% = 0.00
# [Scaling_FastDFA | ts=841]  RelErr% = 0.00
# [Scaling_FastDFA | ts=842]  RelErr% = 0.00
# [Scaling_FastDFA | ts=843]  RelErr% = 0.00
# [Scaling_FastDFA | ts=844]  RelErr% = 0.00
# [Scaling_FastDFA | ts=845]  RelErr% = 0.00
# [Scaling_FastDFA | ts=846]  RelErr% = 0.00
# [Scaling_FastDFA | ts=847]  RelErr% = 0.00
# [Scaling_FastDFA | ts=848]  RelErr% = 0.00
# [Scaling_FastDFA | ts=849]  RelErr% = 0.00
# [Scaling_FastDFA | ts=850]  RelErr% = 0.00
# [Scaling_FastDFA | ts=851]  RelErr% = 0.00
# [Scaling_FastDFA | ts=852]  RelErr% = 0.00
# [Scaling_FastDFA | ts=853]  RelErr% = 0.00
# [Scaling_FastDFA | ts=854]  RelErr% = 0.00
# [Scaling_FastDFA | ts=855]  RelErr% = 0.00
# [Scaling_FastDFA | ts=856]  RelErr% = 0.00
# [Scaling_FastDFA | ts=857]  RelErr% = 0.00
# [Scaling_FastDFA | ts=858]  RelErr% = 0.00
# [Scaling_FastDFA | ts=859]  RelErr% = 0.00
# [Scaling_FastDFA | ts=860]  RelErr% = 0.00
# [Scaling_FastDFA | ts=861]  RelErr% = 0.00
# [Scaling_FastDFA | ts=862]  RelErr% = 0.00
# [Scaling_FastDFA | ts=863]  RelErr% = 0.00
# [Scaling_FastDFA | ts=864]  RelErr% = 0.00
# [Scaling_FastDFA | ts=865]  RelErr% = 0.00
# [Scaling_FastDFA | ts=866]  RelErr% = 0.00
# [Scaling_FastDFA | ts=867]  RelErr% = 0.00
# [Scaling_FastDFA | ts=868]  RelErr% = 0.00
# [Scaling_FastDFA | ts=869]  RelErr% = 0.00
# [Scaling_FastDFA | ts=870]  RelErr% = 0.00
# [Scaling_FastDFA | ts=871]  RelErr% = 0.00
# [Scaling_FastDFA | ts=872]  RelErr% = 0.00
# [Scaling_FastDFA | ts=873]  RelErr% = 0.00
# [Scaling_FastDFA | ts=874]  RelErr% = 0.00
# [Scaling_FastDFA | ts=875]  RelErr% = 0.00
# [Scaling_FastDFA | ts=876]  RelErr% = 0.00
# [Scaling_FastDFA | ts=877]  RelErr% = 0.00
# [Scaling_FastDFA | ts=878]  RelErr% = 0.00
# [Scaling_FastDFA | ts=879]  RelErr% = 0.00
# [Scaling_FastDFA | ts=880]  RelErr% = 0.00
# [Scaling_FastDFA | ts=881]  RelErr% = 0.00
# [Scaling_FastDFA | ts=882]  RelErr% = 0.00
# [Scaling_FastDFA | ts=883]  RelErr% = 0.00
# [Scaling_FastDFA | ts=884]  RelErr% = 0.00
# [Scaling_FastDFA | ts=885]  RelErr% = 0.00
# [Scaling_FastDFA | ts=886]  RelErr% = 0.00
# [Scaling_FastDFA | ts=887]  RelErr% = 0.00
# [Scaling_FastDFA | ts=888]  RelErr% = 0.00
# [Scaling_FastDFA | ts=889]  RelErr% = 0.00
# [Scaling_FastDFA | ts=890]  RelErr% = 0.00
# [Scaling_FastDFA | ts=891]  RelErr% = 0.00
# [Scaling_FastDFA | ts=892]  RelErr% = 0.00
# [Scaling_FastDFA | ts=893]  RelErr% = 0.00
# [Scaling_FastDFA | ts=894]  RelErr% = 0.00
# [Scaling_FastDFA | ts=895]  RelErr% = 0.00
# [Scaling_FastDFA | ts=896]  RelErr% = 0.00
# [Scaling_FastDFA | ts=897]  RelErr% = 0.00
# [Scaling_FastDFA | ts=898]  RelErr% = 0.00
# [Scaling_FastDFA | ts=899]  RelErr% = 0.00
# [Scaling_FastDFA | ts=900]  RelErr% = 0.00
# [Scaling_FastDFA | ts=901]  RelErr% = 0.00
# [Scaling_FastDFA | ts=902]  RelErr% = 0.00
# [Scaling_FastDFA | ts=903]  RelErr% = 0.00
# [Scaling_FastDFA | ts=904]  RelErr% = 0.00
# [Scaling_FastDFA | ts=905]  RelErr% = 0.00
# [Scaling_FastDFA | ts=906]  RelErr% = 0.00
# [Scaling_FastDFA | ts=907]  RelErr% = 0.00
# [Scaling_FastDFA | ts=908]  RelErr% = 0.00
# [Scaling_FastDFA | ts=909]  RelErr% = 0.00
# [Scaling_FastDFA | ts=910]  RelErr% = 0.00
# [Scaling_FastDFA | ts=911]  RelErr% = 0.00
# [Scaling_FastDFA | ts=912]  RelErr% = 0.00
# [Scaling_FastDFA | ts=913]  RelErr% = 0.00
# [Scaling_FastDFA | ts=914]  RelErr% = 0.00
# [Scaling_FastDFA | ts=915]  RelErr% = 0.00
# [Scaling_FastDFA | ts=916]  RelErr% = 0.00
# [Scaling_FastDFA | ts=917]  RelErr% = 0.00
# [Scaling_FastDFA | ts=918]  RelErr% = 0.00
# [Scaling_FastDFA | ts=919]  RelErr% = 0.00
# [Scaling_FastDFA | ts=920]  RelErr% = 0.00
# [Scaling_FastDFA | ts=921]  RelErr% = 0.00
# [Scaling_FastDFA | ts=922]  RelErr% = 0.00
# [Scaling_FastDFA | ts=923]  RelErr% = 0.00
# [Scaling_FastDFA | ts=924]  RelErr% = 0.00
# [Scaling_FastDFA | ts=925]  RelErr% = 0.00
# [Scaling_FastDFA | ts=926]  RelErr% = 0.00
# [Scaling_FastDFA | ts=927]  RelErr% = 0.00
# [Scaling_FastDFA | ts=928]  RelErr% = 0.00
# [Scaling_FastDFA | ts=929]  RelErr% = 0.00
# [Scaling_FastDFA | ts=930]  RelErr% = 0.00
# [Scaling_FastDFA | ts=931]  RelErr% = 0.00
# [Scaling_FastDFA | ts=932]  RelErr% = 0.00
# [Scaling_FastDFA | ts=933]  RelErr% = 0.00
# [Scaling_FastDFA | ts=934]  RelErr% = 0.00
# [Scaling_FastDFA | ts=935]  RelErr% = 0.00
# [Scaling_FastDFA | ts=936]  RelErr% = 0.00
# [Scaling_FastDFA | ts=937]  RelErr% = 0.00
# [Scaling_FastDFA | ts=938]  RelErr% = 0.00
# [Scaling_FastDFA | ts=939]  RelErr% = 0.00
# [Scaling_FastDFA | ts=940]  RelErr% = 0.00
# [Scaling_FastDFA | ts=941]  RelErr% = 0.00
# [Scaling_FastDFA | ts=942]  RelErr% = 0.00
# [Scaling_FastDFA | ts=943]  RelErr% = 0.00
# [Scaling_FastDFA | ts=944]  RelErr% = 0.00
# [Scaling_FastDFA | ts=945]  RelErr% = 0.00
# [Scaling_FastDFA | ts=946]  RelErr% = 0.00
# [Scaling_FastDFA | ts=947]  RelErr% = 0.00
# [Scaling_FastDFA | ts=948]  RelErr% = 0.00
# [Scaling_FastDFA | ts=949]  RelErr% = 0.00
# [Scaling_FastDFA | ts=950]  RelErr% = 0.00
# [Scaling_FastDFA | ts=951]  RelErr% = 0.00
# [Scaling_FastDFA | ts=952]  RelErr% = 0.00
# [Scaling_FastDFA | ts=953]  RelErr% = 0.00
# [Scaling_FastDFA | ts=954]  RelErr% = 0.00
# [Scaling_FastDFA | ts=955]  RelErr% = 0.00
# [Scaling_FastDFA | ts=956]  RelErr% = 0.00
# [Scaling_FastDFA | ts=957]  RelErr% = 0.00
# [Scaling_FastDFA | ts=958]  RelErr% = 0.00
# [Scaling_FastDFA | ts=959]  RelErr% = 0.00
# [Scaling_FastDFA | ts=960]  RelErr% = 0.00
# [Scaling_FastDFA | ts=961]  RelErr% = 0.00
# [Scaling_FastDFA | ts=962]  RelErr% = 0.00
# [Scaling_FastDFA | ts=963]  RelErr% = 0.00
# [Scaling_FastDFA | ts=964]  RelErr% = 0.00
# [Scaling_FastDFA | ts=965]  RelErr% = 0.00
# [Scaling_FastDFA | ts=966]  RelErr% = 0.00
# [Scaling_FastDFA | ts=967]  RelErr% = 0.00
# [Scaling_FastDFA | ts=968]  RelErr% = 0.00
# [Scaling_FastDFA | ts=969]  RelErr% = 0.00
# [Scaling_FastDFA | ts=970]  RelErr% = 0.00
# [Scaling_FastDFA | ts=971]  RelErr% = 0.00
# [Scaling_FastDFA | ts=972]  RelErr% = 0.00
# [Scaling_FastDFA | ts=973]  RelErr% = 0.00
# [Scaling_FastDFA | ts=974]  RelErr% = 0.00
# [Scaling_FastDFA | ts=975]  RelErr% = 0.00
# [Scaling_FastDFA | ts=976]  RelErr% = 0.00
# [Scaling_FastDFA | ts=977]  RelErr% = 0.00
# [Scaling_FastDFA | ts=978]  RelErr% = 0.00
# [Scaling_FastDFA | ts=979]  RelErr% = 0.00
# [Scaling_FastDFA | ts=980]  RelErr% = 0.00
# [Scaling_FastDFA | ts=981]  RelErr% = 0.00
# [Scaling_FastDFA | ts=982]  RelErr% = 0.00
# [Scaling_FastDFA | ts=983]  RelErr% = 0.00
# [Scaling_FastDFA | ts=984]  RelErr% = 0.00
# [Scaling_FastDFA | ts=985]  RelErr% = 0.00
# [Scaling_FastDFA | ts=986]  RelErr% = 0.00
# [Scaling_FastDFA | ts=987]  RelErr% = 0.00
# [Scaling_FastDFA | ts=988]  RelErr% = 0.00
# [Scaling_FastDFA | ts=989]  RelErr% = 0.00
# [Scaling_FastDFA | ts=990]  RelErr% = 0.00
# [Scaling_FastDFA | ts=991]  RelErr% = 0.00
# [Scaling_FastDFA | ts=992]  RelErr% = 0.00
# [Scaling_FastDFA | ts=993]  RelErr% = 0.00
# [Scaling_FastDFA | ts=994]  RelErr% = 0.00
# [Scaling_FastDFA | ts=995]  RelErr% = 0.00
# [Scaling_FastDFA | ts=996]  RelErr% = 0.00
# [Scaling_FastDFA | ts=997]  RelErr% = 0.00
# [Scaling_FastDFA | ts=998]  RelErr% = 0.00
# [Scaling_FastDFA | ts=999]  RelErr% = 0.00

# %%
from typing import Iterable, Tuple, Union, Optional

def ms_embed(
    z: Union[np.ndarray, Iterable[float]],
    v: Optional[Union[int, Iterable[int]]] = None,
    w: Optional[int] = None,
    *,
    split: bool = False,
    auto_neg: bool = True
) -> Union[np.ndarray, Tuple[np.ndarray, np.ndarray]]:
  
    # ---- 1. Parse & normalise lag specification ----------------------------
    if w is not None:                       # three-argument MATLAB call
        if not isinstance(v, int) or v < 1:
            raise ValueError("When `w` is given, `v` must be a positive integer (embedding dimension).")
        lags = np.arange(0, v * w, w, dtype=int)
    elif v is None:                         # single-argument MATLAB call
        lags = np.array([0, 1, 2], dtype=int)
    else:                                   # explicit lag list
        lags = np.asarray(v, dtype=int).copy()

    if split and auto_neg and np.min(lags) >= 0:
        lags = np.insert(lags, 0, -1)

    lags.sort()
    min_lag, max_lag = lags[0], lags[-1]
    dim = len(lags)

    # ---- 2. Validate & reshape input series --------------------------------
    z = np.asarray(z, dtype=float).ravel()        # ensure 1-D row vector
    n = z.size
    if n <= max_lag - min_lag:
        raise ValueError(
            "Time series is too short for the requested lag window "
            f"(length={n}, window={max_lag - min_lag})."
        )

    # ---- 3. Build the embedding matrix -------------------------------------
    window = max_lag - min_lag
    m = n - window
    # Equivalent to MATLAB: t = (1:m) + max_lag  (but zero-based)
    t_idx = np.arange(m) + max_lag

    X = np.empty((dim, m), dtype=z.dtype)
    for i, lag in enumerate(lags):
        X[i] = z[t_idx - lag]

    # ---- 4. Split into positive/negative if requested ----------------------
    if split:
        neg_mask = lags < 0
        Y_neg = X[neg_mask]
        X_pos = X[~neg_mask]
        return X_pos, Y_neg
    return X

# %%
X = ms_embed(empirical1000[0], 3, 1)

# %%
from pyhctsa.Toolboxes.Michael_Small.ms_nearest_wrapper import ms_nearest_py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pyhctsa.Toolboxes.Michael_Small.ms_nearest_wrapper import ms_nearest_py
#
# ImportError: cannot import name 'ms_nearest_py' from 'pyhctsa.Toolboxes.Michael_Small.ms_nearest_wrapper' (/Users/jmoo2880/Documents/py-hctsa-project/pyhctsa/Toolboxes/Michael_Small/ms_nearest_wrapper.py)

# %%
importlib.reload(Nonlinear)
from Nonlinear import FNN

# %%
FNN(empirical1000[513], justBest=False, tau='ac')
# Out:
# {'pfnn_1': np.float64(0.9798994974874372),
#  'pfnn_2': np.float64(0.4301507537688442),
#  'pfnn_3': np.float64(0.08274470232088799),
#  'pfnn_4': np.float64(0.013171225937183385),
#  'pfnn_5': np.float64(0.003051881993896236),
#  'pfnn_6': np.float64(0.0),
#  'pfnn_7': np.float64(0.0),
#  'pfnn_8': np.float64(0.0),
#  'pfnn_9': np.float64(0.0),
#  'pfnn_10': np.float64(0.0),
#  'meanpfnn': np.float64(0.15090180615082488),
#  'stdpfnn': np.float64(0.3205115054420895),
#  'firstunder02': np.int64(3),
#  'firstunder01': np.int64(3),
#  'firstunder005': np.int64(4),
#  'firstunder002': np.int64(4),
#  'firstunder001': np.int64(5),
#  'max1stepchange': np.float64(0.5497487437185931)}
